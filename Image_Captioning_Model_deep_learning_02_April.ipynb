# %%
import pandas as pd

# %%
# !pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od

od.download(
    "https://www.kaggle.com/datasets/adityajn105/flickr8k")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: wasimmmalik
# Your Kaggle Key: ··········
# Downloading flickr8k.zip to ./flickr8k
# 100%|██████████| 1.04G/1.04G [00:06<00:00, 169MB/s]

# %%
data = pd.read_csv("/content/flickr8k/captions.txt",delimiter  = ',')

# %%
data.columns
# Out:
# Index(['image', 'caption'], dtype='object')

# %%
data.head(5)
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
from os import listdir
from pickle import dump
from keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model

# %%
# extrat Features
def extract_features(directory):
    
    model = VGG16()
    
    #remove last layer
    model.layers.pop()
    
    model = Model(inputs = model.inputs , outputs = model.layers[-1].output)
    
    print(model.summary())
    
    features = dict()
    i = 0
    for name in listdir(directory):
        
        # load and image
        filename = directory + '/' + name
        print(f"counter -> {i} {name}")
        print(f"type {filename[-4:]}")
        i = i+1
        if name[-4:] != ".jpg":
          continue
        image = load_img(filename , target_size=(224 , 224))
        
        image = img_to_array(image)
        
        image = image.reshape((1 , image.shape[0] , image.shape[1] ,image.shape[2]))
        
        image = preprocess_input(image)
        
        feature = model.predict(image , verbose = 0)
        
        # get image id
        image_id = name.split(".")[0]
        
        # store features
        features[image_id] = feature
        
        print(name)
        
    return features

# %%
directory = '/content/flickr8k/Images'
features = extract_features(directory)
print('extracted features :',len(features))
dump(features , open('features.pkl' , 'wb'))
# Out:
# Streaming output truncated to the last 5000 lines.
# 3684518763_f3490b647a.jpg
# counter -> 6425 2312746782_4528a5b818.jpg
# type .jpg
# 2312746782_4528a5b818.jpg
# counter -> 6426 2272426567_9e9fb79db0.jpg
# type .jpg
# 2272426567_9e9fb79db0.jpg
# counter -> 6427 3628017876_4ac27e687b.jpg
# type .jpg
# 3628017876_4ac27e687b.jpg
# counter -> 6428 3405100926_e96308ce89.jpg
# type .jpg
# 3405100926_e96308ce89.jpg
# counter -> 6429 3682038869_585075b5ff.jpg
# type .jpg
# 3682038869_585075b5ff.jpg
# counter -> 6430 2932740428_b15384f389.jpg
# type .jpg
# 2932740428_b15384f389.jpg
# counter -> 6431 398413603_166896900f.jpg
# type .jpg
# 398413603_166896900f.jpg
# counter -> 6432 58363928_6f7074608c.jpg
# type .jpg
# 58363928_6f7074608c.jpg
# counter -> 6433 2009636597_e3f4fe19fb.jpg
# type .jpg
# 2009636597_e3f4fe19fb.jpg
# counter -> 6434 2233426944_0959835ced.jpg
# type .jpg
# 2233426944_0959835ced.jpg
# counter -> 6435 3524612244_64f00afec5.jpg
# type .jpg
# 3524612244_64f00afec5.jpg
# counter -> 6436 3500115252_9404c066a8.jpg
# type .jpg
# 3500115252_9404c066a8.jpg
# counter -> 6437 2219805467_370ee1b7aa.jpg
# type .jpg
# 2219805467_370ee1b7aa.jpg
# counter -> 6438 3348191949_b0b925e5f1.jpg
# type .jpg
# 3348191949_b0b925e5f1.jpg
# counter -> 6439 3475111806_f0d2927707.jpg
# type .jpg
# 3475111806_f0d2927707.jpg
# counter -> 6440 3093970461_825b0cac2f.jpg
# type .jpg
# 3093970461_825b0cac2f.jpg
# counter -> 6441 3104909823_0f41dd8be6.jpg
# type .jpg
# 3104909823_0f41dd8be6.jpg
# counter -> 6442 3639845565_be547c38ba.jpg
# type .jpg
# 3639845565_be547c38ba.jpg
# counter -> 6443 3266399073_40820596d5.jpg
# type .jpg
# 3266399073_40820596d5.jpg
# counter -> 6444 2255266906_8222af18b9.jpg
# type .jpg
# 2255266906_8222af18b9.jpg
# counter -> 6445 309771854_952aabe3cc.jpg
# type .jpg
# 309771854_952aabe3cc.jpg
# counter -> 6446 498444334_a680d318a1.jpg
# type .jpg
# 498444334_a680d318a1.jpg
# counter -> 6447 2109479807_eec8d72ca7.jpg
# type .jpg
# 2109479807_eec8d72ca7.jpg
# counter -> 6448 3717531382_e1e05e22c5.jpg
# type .jpg
# 3717531382_e1e05e22c5.jpg
# counter -> 6449 2363006088_b3e3aa5c0b.jpg
# type .jpg
# 2363006088_b3e3aa5c0b.jpg
# counter -> 6450 2278110011_ba846e7795.jpg
# type .jpg
# 2278110011_ba846e7795.jpg
# counter -> 6451 428483413_b9370baf72.jpg
# type .jpg
# 428483413_b9370baf72.jpg
# counter -> 6452 1124448967_2221af8dc5.jpg
# type .jpg
# 1124448967_2221af8dc5.jpg
# counter -> 6453 3334300164_e75e0479ae.jpg
# type .jpg
# 3334300164_e75e0479ae.jpg
# counter -> 6454 2414710960_a4cde4af60.jpg
# type .jpg
# 2414710960_a4cde4af60.jpg
# counter -> 6455 2346402952_e47d0065b6.jpg
# type .jpg
# 2346402952_e47d0065b6.jpg
# counter -> 6456 3504940491_94c43792ed.jpg
# type .jpg
# 3504940491_94c43792ed.jpg
# counter -> 6457 3375843443_8d9b242aa5.jpg
# type .jpg
# 3375843443_8d9b242aa5.jpg
# counter -> 6458 3526897578_3cf77da99b.jpg
# type .jpg
# 3526897578_3cf77da99b.jpg
# counter -> 6459 2090997177_76d482b158.jpg
# type .jpg
# 2090997177_76d482b158.jpg
# counter -> 6460 1445123245_c7b9db0e0c.jpg
# type .jpg
# 1445123245_c7b9db0e0c.jpg
# counter -> 6461 3556485995_9cd40269e9.jpg
# type .jpg
# 3556485995_9cd40269e9.jpg
# counter -> 6462 1003163366_44323f5815.jpg
# type .jpg
# 1003163366_44323f5815.jpg
# counter -> 6463 1576185717_f841ddc3da.jpg
# type .jpg
# 1576185717_f841ddc3da.jpg
# counter -> 6464 483136916_16976f4902.jpg
# type .jpg
# 483136916_16976f4902.jpg
# counter -> 6465 3146355833_1b7fc80210.jpg
# type .jpg
# 3146355833_1b7fc80210.jpg
# counter -> 6466 2474047296_fd9179d438.jpg
# type .jpg
# 2474047296_fd9179d438.jpg
# counter -> 6467 3214885227_2be09e7cfb.jpg
# type .jpg
# 3214885227_2be09e7cfb.jpg
# counter -> 6468 3036971334_78187a9570.jpg
# type .jpg
# 3036971334_78187a9570.jpg
# counter -> 6469 2370481277_a3085614c9.jpg
# type .jpg
# 2370481277_a3085614c9.jpg
# counter -> 6470 1096097967_ac305887b4.jpg
# type .jpg
# 1096097967_ac305887b4.jpg
# counter -> 6471 3300679815_2c6c2301cb.jpg
# type .jpg
# 3300679815_2c6c2301cb.jpg
# counter -> 6472 424379231_23f1ade134.jpg
# type .jpg
# 424379231_23f1ade134.jpg
# counter -> 6473 2094810449_f8df9dcdf7.jpg
# type .jpg
# 2094810449_f8df9dcdf7.jpg
# counter -> 6474 2579572274_826598b14a.jpg
# type .jpg
# 2579572274_826598b14a.jpg
# counter -> 6475 446291803_2fd4641b99.jpg
# type .jpg
# 446291803_2fd4641b99.jpg
# counter -> 6476 3263141261_db3a4798b5.jpg
# type .jpg
# 3263141261_db3a4798b5.jpg
# counter -> 6477 3027397797_4f1d305ced.jpg
# type .jpg
# 3027397797_4f1d305ced.jpg
# counter -> 6478 2421446839_fe7d46c177.jpg
# type .jpg
# 2421446839_fe7d46c177.jpg
# counter -> 6479 3231596071_f0c522a639.jpg
# type .jpg
# 3231596071_f0c522a639.jpg
# counter -> 6480 3108378861_d2214d971e.jpg
# type .jpg
# 3108378861_d2214d971e.jpg
# counter -> 6481 2021671653_567395c7cf.jpg
# type .jpg
# 2021671653_567395c7cf.jpg
# counter -> 6482 2769731772_18c44c18e2.jpg
# type .jpg
# 2769731772_18c44c18e2.jpg
# counter -> 6483 3655964639_21e76383d0.jpg
# type .jpg
# 3655964639_21e76383d0.jpg
# counter -> 6484 241346402_5c070a0c6d.jpg
# type .jpg
# 241346402_5c070a0c6d.jpg
# counter -> 6485 3500139659_b2a60b0141.jpg
# type .jpg
# 3500139659_b2a60b0141.jpg
# counter -> 6486 511282305_dbab4bf4be.jpg
# type .jpg
# 511282305_dbab4bf4be.jpg
# counter -> 6487 469617651_278e586e46.jpg
# type .jpg
# 469617651_278e586e46.jpg
# counter -> 6488 3577235421_69e4efb8d1.jpg
# type .jpg
# 3577235421_69e4efb8d1.jpg
# counter -> 6489 701816897_221bbe761a.jpg
# type .jpg
# 701816897_221bbe761a.jpg
# counter -> 6490 3431194126_ca78f5fde6.jpg
# type .jpg
# 3431194126_ca78f5fde6.jpg
# counter -> 6491 3304712466_18cbdb85fe.jpg
# type .jpg
# 3304712466_18cbdb85fe.jpg
# counter -> 6492 2985679744_75a7102aab.jpg
# type .jpg
# 2985679744_75a7102aab.jpg
# counter -> 6493 3366571152_20afb88ac1.jpg
# type .jpg
# 3366571152_20afb88ac1.jpg
# counter -> 6494 3578841731_f775cab089.jpg
# type .jpg
# 3578841731_f775cab089.jpg
# counter -> 6495 3351586010_7ffaa90ea8.jpg
# type .jpg
# 3351586010_7ffaa90ea8.jpg
# counter -> 6496 3714551959_66ece78f27.jpg
# type .jpg
# 3714551959_66ece78f27.jpg
# counter -> 6497 3115174046_9e96b9ce47.jpg
# type .jpg
# 3115174046_9e96b9ce47.jpg
# counter -> 6498 2079110798_ad1370a646.jpg
# type .jpg
# 2079110798_ad1370a646.jpg
# counter -> 6499 2715289538_d77c8d0a85.jpg
# type .jpg
# 2715289538_d77c8d0a85.jpg
# counter -> 6500 3703035378_c6034cac51.jpg
# type .jpg
# 3703035378_c6034cac51.jpg
# counter -> 6501 945509052_740bb19bc3.jpg
# type .jpg
# 945509052_740bb19bc3.jpg
# counter -> 6502 2649850541_59a6c7f01c.jpg
# type .jpg
# 2649850541_59a6c7f01c.jpg
# counter -> 6503 3593222804_c187808ac3.jpg
# type .jpg
# 3593222804_c187808ac3.jpg
# counter -> 6504 381514859_b40418d9c3.jpg
# type .jpg
# 381514859_b40418d9c3.jpg
# counter -> 6505 3728695560_00ec1ca492.jpg
# type .jpg
# 3728695560_00ec1ca492.jpg
# counter -> 6506 3458211052_bb73084398.jpg
# type .jpg
# 3458211052_bb73084398.jpg
# counter -> 6507 1332208215_fa824f6659.jpg
# type .jpg
# 1332208215_fa824f6659.jpg
# counter -> 6508 2694178830_116be6a6a9.jpg
# type .jpg
# 2694178830_116be6a6a9.jpg
# counter -> 6509 293327462_20dee0de56.jpg
# type .jpg
# 293327462_20dee0de56.jpg
# counter -> 6510 576920249_df1bdc2068.jpg
# type .jpg
# 576920249_df1bdc2068.jpg
# counter -> 6511 2712787899_d85048eb6a.jpg
# type .jpg
# 2712787899_d85048eb6a.jpg
# counter -> 6512 306315650_e064f5c677.jpg
# type .jpg
# 306315650_e064f5c677.jpg
# counter -> 6513 3610836023_3a972b10b0.jpg
# type .jpg
# 3610836023_3a972b10b0.jpg
# counter -> 6514 3243591844_791cfa62eb.jpg
# type .jpg
# 3243591844_791cfa62eb.jpg
# counter -> 6515 171488318_fb26af58e2.jpg
# type .jpg
# 171488318_fb26af58e2.jpg
# counter -> 6516 2110898123_07729c1461.jpg
# type .jpg
# 2110898123_07729c1461.jpg
# counter -> 6517 3569667295_6e51db08ef.jpg
# type .jpg
# 3569667295_6e51db08ef.jpg
# counter -> 6518 2938120171_970564e3d8.jpg
# type .jpg
# 2938120171_970564e3d8.jpg
# counter -> 6519 209605542_ca9cc52e7b.jpg
# type .jpg
# 209605542_ca9cc52e7b.jpg
# counter -> 6520 241346709_23204cc2bc.jpg
# type .jpg
# 241346709_23204cc2bc.jpg
# counter -> 6521 3110649716_c17e14670e.jpg
# type .jpg
# 3110649716_c17e14670e.jpg
# counter -> 6522 3321956909_7b5ddf500f.jpg
# type .jpg
# 3321956909_7b5ddf500f.jpg
# counter -> 6523 2180886307_5156460b2c.jpg
# type .jpg
# 2180886307_5156460b2c.jpg
# counter -> 6524 3083016677_5782bc337c.jpg
# type .jpg
# 3083016677_5782bc337c.jpg
# counter -> 6525 894928353_002a3d5f06.jpg
# type .jpg
# 894928353_002a3d5f06.jpg
# counter -> 6526 439492931_a96d590e40.jpg
# type .jpg
# 439492931_a96d590e40.jpg
# counter -> 6527 3329777647_5e1fd503ac.jpg
# type .jpg
# 3329777647_5e1fd503ac.jpg
# counter -> 6528 824782868_a8f532f3a6.jpg
# type .jpg
# 824782868_a8f532f3a6.jpg
# counter -> 6529 2189995738_352607a63b.jpg
# type .jpg
# 2189995738_352607a63b.jpg
# counter -> 6530 1814391289_83a1eb71d3.jpg
# type .jpg
# 1814391289_83a1eb71d3.jpg
# counter -> 6531 3032790880_d216197d55.jpg
# type .jpg
# 3032790880_d216197d55.jpg
# counter -> 6532 3044746136_8b89da5f40.jpg
# type .jpg
# 3044746136_8b89da5f40.jpg
# counter -> 6533 241345905_5826a72da1.jpg
# type .jpg
# 241345905_5826a72da1.jpg
# counter -> 6534 3708266246_97a033fcc7.jpg
# type .jpg
# 3708266246_97a033fcc7.jpg
# counter -> 6535 3229519418_040f05ced1.jpg
# type .jpg
# 3229519418_040f05ced1.jpg
# counter -> 6536 2632111399_b3c1630f8e.jpg
# type .jpg
# 2632111399_b3c1630f8e.jpg
# counter -> 6537 2592019072_a6c0090da4.jpg
# type .jpg
# 2592019072_a6c0090da4.jpg
# counter -> 6538 618771382_459bb492e4.jpg
# type .jpg
# 618771382_459bb492e4.jpg
# counter -> 6539 3068407619_5207b26986.jpg
# type .jpg
# 3068407619_5207b26986.jpg
# counter -> 6540 3361990489_92244a58ef.jpg
# type .jpg
# 3361990489_92244a58ef.jpg
# counter -> 6541 551403320_dfdcf9fc3b.jpg
# type .jpg
# 551403320_dfdcf9fc3b.jpg
# counter -> 6542 2806632713_edd6f6c893.jpg
# type .jpg
# 2806632713_edd6f6c893.jpg
# counter -> 6543 2753531542_ace2c870b7.jpg
# type .jpg
# 2753531542_ace2c870b7.jpg
# counter -> 6544 3307147971_5b3abf61f9.jpg
# type .jpg
# 3307147971_5b3abf61f9.jpg
# counter -> 6545 2832487464_2d30634e1e.jpg
# type .jpg
# 2832487464_2d30634e1e.jpg
# counter -> 6546 3182558164_488b819f14.jpg
# type .jpg
# 3182558164_488b819f14.jpg
# counter -> 6547 2293149170_38fb2257ea.jpg
# type .jpg
# 2293149170_38fb2257ea.jpg
# counter -> 6548 408748500_e8dc8c0c4f.jpg
# type .jpg
# 408748500_e8dc8c0c4f.jpg
# counter -> 6549 3462454965_a481809cea.jpg
# type .jpg
# 3462454965_a481809cea.jpg
# counter -> 6550 2798880731_4f51634374.jpg
# type .jpg
# 2798880731_4f51634374.jpg
# counter -> 6551 3649384501_f1e06c58c0.jpg
# type .jpg
# 3649384501_f1e06c58c0.jpg
# counter -> 6552 3430287726_94a1825bbf.jpg
# type .jpg
# 3430287726_94a1825bbf.jpg
# counter -> 6553 3237760601_5334f3f3b5.jpg
# type .jpg
# 3237760601_5334f3f3b5.jpg
# counter -> 6554 2655647656_ee450446ed.jpg
# type .jpg
# 2655647656_ee450446ed.jpg
# counter -> 6555 485741580_ab523fa657.jpg
# type .jpg
# 485741580_ab523fa657.jpg
# counter -> 6556 2877511986_c965ced502.jpg
# type .jpg
# 2877511986_c965ced502.jpg
# counter -> 6557 3673970325_4e025069e9.jpg
# type .jpg
# 3673970325_4e025069e9.jpg
# counter -> 6558 1160441615_fe6b3c5277.jpg
# type .jpg
# 1160441615_fe6b3c5277.jpg
# counter -> 6559 3119913014_688d4997d7.jpg
# type .jpg
# 3119913014_688d4997d7.jpg
# counter -> 6560 1452361926_6d8c535e32.jpg
# type .jpg
# 1452361926_6d8c535e32.jpg
# counter -> 6561 3213622536_31da7f6682.jpg
# type .jpg
# 3213622536_31da7f6682.jpg
# counter -> 6562 3478084305_9e1219c3b6.jpg
# type .jpg
# 3478084305_9e1219c3b6.jpg
# counter -> 6563 1713248047_d03721456d.jpg
# type .jpg
# 1713248047_d03721456d.jpg
# counter -> 6564 2068465241_3bcabacfd7.jpg
# type .jpg
# 2068465241_3bcabacfd7.jpg
# counter -> 6565 3004290523_d1319dfdb4.jpg
# type .jpg
# 3004290523_d1319dfdb4.jpg
# counter -> 6566 1865794069_6e3a1e57bb.jpg
# type .jpg
# 1865794069_6e3a1e57bb.jpg
# counter -> 6567 2046222127_a6f300e202.jpg
# type .jpg
# 2046222127_a6f300e202.jpg
# counter -> 6568 216172386_9ac5356dae.jpg
# type .jpg
# 216172386_9ac5356dae.jpg
# counter -> 6569 1282392036_5a0328eb86.jpg
# type .jpg
# 1282392036_5a0328eb86.jpg
# counter -> 6570 2244613488_4d1f9edb33.jpg
# type .jpg
# 2244613488_4d1f9edb33.jpg
# counter -> 6571 3605676864_0fb491267e.jpg
# type .jpg
# 3605676864_0fb491267e.jpg
# counter -> 6572 2928152792_b16c73434a.jpg
# type .jpg
# 2928152792_b16c73434a.jpg
# counter -> 6573 3051341320_1d0166e775.jpg
# type .jpg
# 3051341320_1d0166e775.jpg
# counter -> 6574 3442242092_e579538d82.jpg
# type .jpg
# 3442242092_e579538d82.jpg
# counter -> 6575 1600208439_e94527b80f.jpg
# type .jpg
# 1600208439_e94527b80f.jpg
# counter -> 6576 140526327_3cb984de09.jpg
# type .jpg
# 140526327_3cb984de09.jpg
# counter -> 6577 3524914023_4e96edb09f.jpg
# type .jpg
# 3524914023_4e96edb09f.jpg
# counter -> 6578 3465396606_5ba1574128.jpg
# type .jpg
# 3465396606_5ba1574128.jpg
# counter -> 6579 2366421102_2d60d53a0e.jpg
# type .jpg
# 2366421102_2d60d53a0e.jpg
# counter -> 6580 2550011909_6b95f11330.jpg
# type .jpg
# 2550011909_6b95f11330.jpg
# counter -> 6581 356929855_6bbf33d933.jpg
# type .jpg
# 356929855_6bbf33d933.jpg
# counter -> 6582 3653764864_225958c9c1.jpg
# type .jpg
# 3653764864_225958c9c1.jpg
# counter -> 6583 1529044279_4922ead27c.jpg
# type .jpg
# 1529044279_4922ead27c.jpg
# counter -> 6584 3323661814_1e8e1ae88c.jpg
# type .jpg
# 3323661814_1e8e1ae88c.jpg
# counter -> 6585 1319634306_816f21677f.jpg
# type .jpg
# 1319634306_816f21677f.jpg
# counter -> 6586 3517040752_debec03376.jpg
# type .jpg
# 3517040752_debec03376.jpg
# counter -> 6587 421932359_edbf181f44.jpg
# type .jpg
# 421932359_edbf181f44.jpg
# counter -> 6588 3619381206_5bc8b406f9.jpg
# type .jpg
# 3619381206_5bc8b406f9.jpg
# counter -> 6589 566384456_97da3c7bd6.jpg
# type .jpg
# 566384456_97da3c7bd6.jpg
# counter -> 6590 3536561454_e75993d903.jpg
# type .jpg
# 3536561454_e75993d903.jpg
# counter -> 6591 294549892_babb130543.jpg
# type .jpg
# 294549892_babb130543.jpg
# counter -> 6592 260520547_944f9f4c91.jpg
# type .jpg
# 260520547_944f9f4c91.jpg
# counter -> 6593 2755952680_68a0a1fa42.jpg
# type .jpg
# 2755952680_68a0a1fa42.jpg
# counter -> 6594 450596617_ed37ec0fe4.jpg
# type .jpg
# 450596617_ed37ec0fe4.jpg
# counter -> 6595 241345596_91e0e2daf5.jpg
# type .jpg
# 241345596_91e0e2daf5.jpg
# counter -> 6596 421153376_d1d325568f.jpg
# type .jpg
# 421153376_d1d325568f.jpg
# counter -> 6597 1237985362_dbafc59280.jpg
# type .jpg
# 1237985362_dbafc59280.jpg
# counter -> 6598 2204550058_2707d92338.jpg
# type .jpg
# 2204550058_2707d92338.jpg
# counter -> 6599 496380034_d22aeeedb3.jpg
# type .jpg
# 496380034_d22aeeedb3.jpg
# counter -> 6600 447722389_4b51b7e13d.jpg
# type .jpg
# 447722389_4b51b7e13d.jpg
# counter -> 6601 3400186336_37043a2f5b.jpg
# type .jpg
# 3400186336_37043a2f5b.jpg
# counter -> 6602 576093768_e78f91c176.jpg
# type .jpg
# 576093768_e78f91c176.jpg
# counter -> 6603 2562166462_b43b141d40.jpg
# type .jpg
# 2562166462_b43b141d40.jpg
# counter -> 6604 3320356356_1497e53f80.jpg
# type .jpg
# 3320356356_1497e53f80.jpg
# counter -> 6605 2460799229_ce45a1d940.jpg
# type .jpg
# 2460799229_ce45a1d940.jpg
# counter -> 6606 2565350330_c7f305e7f7.jpg
# type .jpg
# 2565350330_c7f305e7f7.jpg
# counter -> 6607 2242178517_2325b85e5f.jpg
# type .jpg
# 2242178517_2325b85e5f.jpg
# counter -> 6608 3019609769_c7809177f6.jpg
# type .jpg
# 3019609769_c7809177f6.jpg
# counter -> 6609 2445283938_ff477c7952.jpg
# type .jpg
# 2445283938_ff477c7952.jpg
# counter -> 6610 2275253272_00f941366e.jpg
# type .jpg
# 2275253272_00f941366e.jpg
# counter -> 6611 485054073_fef8b80b4b.jpg
# type .jpg
# 485054073_fef8b80b4b.jpg
# counter -> 6612 2672354635_3a03f76486.jpg
# type .jpg
# 2672354635_3a03f76486.jpg
# counter -> 6613 2792212974_23b1ef05fa.jpg
# type .jpg
# 2792212974_23b1ef05fa.jpg
# counter -> 6614 3539817989_5353062a39.jpg
# type .jpg
# 3539817989_5353062a39.jpg
# counter -> 6615 418796494_bdb441de42.jpg
# type .jpg
# 418796494_bdb441de42.jpg
# counter -> 6616 2890075175_4bd32b201a.jpg
# type .jpg
# 2890075175_4bd32b201a.jpg
# counter -> 6617 3163563871_cef3cf33ea.jpg
# type .jpg
# 3163563871_cef3cf33ea.jpg
# counter -> 6618 2887103049_a867e74358.jpg
# type .jpg
# 2887103049_a867e74358.jpg
# counter -> 6619 2458269558_277012780d.jpg
# type .jpg
# 2458269558_277012780d.jpg
# counter -> 6620 2525270674_4ab536e7ec.jpg
# type .jpg
# 2525270674_4ab536e7ec.jpg
# counter -> 6621 2589308405_e208b5e745.jpg
# type .jpg
# 2589308405_e208b5e745.jpg
# counter -> 6622 3488087117_2719647989.jpg
# type .jpg
# 3488087117_2719647989.jpg
# counter -> 6623 2600386812_8790879d9a.jpg
# type .jpg
# 2600386812_8790879d9a.jpg
# counter -> 6624 2375924666_fee50f1cba.jpg
# type .jpg
# 2375924666_fee50f1cba.jpg
# counter -> 6625 952171414_2db16f846f.jpg
# type .jpg
# 952171414_2db16f846f.jpg
# counter -> 6626 3003612178_8230d65833.jpg
# type .jpg
# 3003612178_8230d65833.jpg
# counter -> 6627 400851260_5911898657.jpg
# type .jpg
# 400851260_5911898657.jpg
# counter -> 6628 2461372011_ebbf513766.jpg
# type .jpg
# 2461372011_ebbf513766.jpg
# counter -> 6629 2632381125_de32bdfdf6.jpg
# type .jpg
# 2632381125_de32bdfdf6.jpg
# counter -> 6630 241031254_0c6f30e3d1.jpg
# type .jpg
# 241031254_0c6f30e3d1.jpg
# counter -> 6631 2832978253_8fcc72da3b.jpg
# type .jpg
# 2832978253_8fcc72da3b.jpg
# counter -> 6632 689776124_07f560a920.jpg
# type .jpg
# 689776124_07f560a920.jpg
# counter -> 6633 2754271176_4a2cda8c15.jpg
# type .jpg
# 2754271176_4a2cda8c15.jpg
# counter -> 6634 1107471216_4336c9b328.jpg
# type .jpg
# 1107471216_4336c9b328.jpg
# counter -> 6635 3425061393_d093edb8da.jpg
# type .jpg
# 3425061393_d093edb8da.jpg
# counter -> 6636 3208571574_6dc1a461c5.jpg
# type .jpg
# 3208571574_6dc1a461c5.jpg
# counter -> 6637 3397259310_1ed1a346b5.jpg
# type .jpg
# 3397259310_1ed1a346b5.jpg
# counter -> 6638 3671851846_60c25269df.jpg
# type .jpg
# 3671851846_60c25269df.jpg
# counter -> 6639 2842439618_fb20fe2215.jpg
# type .jpg
# 2842439618_fb20fe2215.jpg
# counter -> 6640 3334537556_a2cf4e9b9a.jpg
# type .jpg
# 3334537556_a2cf4e9b9a.jpg
# counter -> 6641 418667611_b9995000f4.jpg
# type .jpg
# 418667611_b9995000f4.jpg
# counter -> 6642 3581451227_618854cea4.jpg
# type .jpg
# 3581451227_618854cea4.jpg
# counter -> 6643 3615239961_62b4dbc174.jpg
# type .jpg
# 3615239961_62b4dbc174.jpg
# counter -> 6644 802594049_289e3c8420.jpg
# type .jpg
# 802594049_289e3c8420.jpg
# counter -> 6645 3208074567_ac44aeb3f3.jpg
# type .jpg
# 3208074567_ac44aeb3f3.jpg
# counter -> 6646 3576259024_9c05b163aa.jpg
# type .jpg
# 3576259024_9c05b163aa.jpg
# counter -> 6647 3453284877_8866189055.jpg
# type .jpg
# 3453284877_8866189055.jpg
# counter -> 6648 3356369156_074750c6cc.jpg
# type .jpg
# 3356369156_074750c6cc.jpg
# counter -> 6649 2362481035_a7600875d0.jpg
# type .jpg
# 2362481035_a7600875d0.jpg
# counter -> 6650 2934121315_4969eeda1b.jpg
# type .jpg
# 2934121315_4969eeda1b.jpg
# counter -> 6651 2839932205_3c9c27cd99.jpg
# type .jpg
# 2839932205_3c9c27cd99.jpg
# counter -> 6652 2319197581_94f807b204.jpg
# type .jpg
# 2319197581_94f807b204.jpg
# counter -> 6653 3323498985_fd9d2803fd.jpg
# type .jpg
# 3323498985_fd9d2803fd.jpg
# counter -> 6654 1461329041_c623b06e5b.jpg
# type .jpg
# 1461329041_c623b06e5b.jpg
# counter -> 6655 264859622_f3a00ab409.jpg
# type .jpg
# 264859622_f3a00ab409.jpg
# counter -> 6656 3154886184_ac842655b6.jpg
# type .jpg
# 3154886184_ac842655b6.jpg
# counter -> 6657 3529211822_1dabdb3a9c.jpg
# type .jpg
# 3529211822_1dabdb3a9c.jpg
# counter -> 6658 3348384389_73b6647017.jpg
# type .jpg
# 3348384389_73b6647017.jpg
# counter -> 6659 1352398363_9cc8ffcce9.jpg
# type .jpg
# 1352398363_9cc8ffcce9.jpg
# counter -> 6660 2181117039_c4eea8036e.jpg
# type .jpg
# 2181117039_c4eea8036e.jpg
# counter -> 6661 2587846523_b177c9a3e3.jpg
# type .jpg
# 2587846523_b177c9a3e3.jpg
# counter -> 6662 3004823335_9b82cbd8a7.jpg
# type .jpg
# 3004823335_9b82cbd8a7.jpg
# counter -> 6663 968081289_cdba83ce2e.jpg
# type .jpg
# 968081289_cdba83ce2e.jpg
# counter -> 6664 3468346269_9d162aacfe.jpg
# type .jpg
# 3468346269_9d162aacfe.jpg
# counter -> 6665 2861100960_457ceda7fa.jpg
# type .jpg
# 2861100960_457ceda7fa.jpg
# counter -> 6666 2108799322_e25aa6e185.jpg
# type .jpg
# 2108799322_e25aa6e185.jpg
# counter -> 6667 3054200086_657d4398e8.jpg
# type .jpg
# 3054200086_657d4398e8.jpg
# counter -> 6668 310260324_7f941814bc.jpg
# type .jpg
# 310260324_7f941814bc.jpg
# counter -> 6669 2056930414_d2b0f1395a.jpg
# type .jpg
# 2056930414_d2b0f1395a.jpg
# counter -> 6670 1691573772_1adef8e40e.jpg
# type .jpg
# 1691573772_1adef8e40e.jpg
# counter -> 6671 3004359992_f6b3617706.jpg
# type .jpg
# 3004359992_f6b3617706.jpg
# counter -> 6672 2284239186_c827f4defa.jpg
# type .jpg
# 2284239186_c827f4defa.jpg
# counter -> 6673 2432709509_2a4d0c833f.jpg
# type .jpg
# 2432709509_2a4d0c833f.jpg
# counter -> 6674 3187096035_65dc416291.jpg
# type .jpg
# 3187096035_65dc416291.jpg
# counter -> 6675 337647771_3b819feaba.jpg
# type .jpg
# 337647771_3b819feaba.jpg
# counter -> 6676 465994762_1760e83c5d.jpg
# type .jpg
# 465994762_1760e83c5d.jpg
# counter -> 6677 2201222219_8d656b0633.jpg
# type .jpg
# 2201222219_8d656b0633.jpg
# counter -> 6678 3350614753_5624e181b3.jpg
# type .jpg
# 3350614753_5624e181b3.jpg
# counter -> 6679 3494723363_eaa6bc563b.jpg
# type .jpg
# 3494723363_eaa6bc563b.jpg
# counter -> 6680 219843859_94b6d0a580.jpg
# type .jpg
# 219843859_94b6d0a580.jpg
# counter -> 6681 3113769557_9edbb8275c.jpg
# type .jpg
# 3113769557_9edbb8275c.jpg
# counter -> 6682 2797185895_4d9e1e9508.jpg
# type .jpg
# 2797185895_4d9e1e9508.jpg
# counter -> 6683 369186134_5eef374112.jpg
# type .jpg
# 369186134_5eef374112.jpg
# counter -> 6684 261490838_2f3ac98b12.jpg
# type .jpg
# 261490838_2f3ac98b12.jpg
# counter -> 6685 2144050118_3e7d2e05b1.jpg
# type .jpg
# 2144050118_3e7d2e05b1.jpg
# counter -> 6686 3395173129_f0ac0a1ed4.jpg
# type .jpg
# 3395173129_f0ac0a1ed4.jpg
# counter -> 6687 2853811730_fbb8ab0878.jpg
# type .jpg
# 2853811730_fbb8ab0878.jpg
# counter -> 6688 3459419203_cd7c68ce4d.jpg
# type .jpg
# 3459419203_cd7c68ce4d.jpg
# counter -> 6689 3382679230_baef3d1eaa.jpg
# type .jpg
# 3382679230_baef3d1eaa.jpg
# counter -> 6690 3487015378_2e90a79f4b.jpg
# type .jpg
# 3487015378_2e90a79f4b.jpg
# counter -> 6691 2482629385_f370b290d1.jpg
# type .jpg
# 2482629385_f370b290d1.jpg
# counter -> 6692 873633312_a756d8b381.jpg
# type .jpg
# 873633312_a756d8b381.jpg
# counter -> 6693 3151492269_28d8edaa68.jpg
# type .jpg
# 3151492269_28d8edaa68.jpg
# counter -> 6694 502783522_3656f27014.jpg
# type .jpg
# 502783522_3656f27014.jpg
# counter -> 6695 2920516901_23d8571419.jpg
# type .jpg
# 2920516901_23d8571419.jpg
# counter -> 6696 2975018306_0e8da316f5.jpg
# type .jpg
# 2975018306_0e8da316f5.jpg
# counter -> 6697 3048380686_732db55281.jpg
# type .jpg
# 3048380686_732db55281.jpg
# counter -> 6698 3635911776_dbc2763f2c.jpg
# type .jpg
# 3635911776_dbc2763f2c.jpg
# counter -> 6699 3060969260_08f43e4f4f.jpg
# type .jpg
# 3060969260_08f43e4f4f.jpg
# counter -> 6700 3231237864_8cb1c6d863.jpg
# type .jpg
# 3231237864_8cb1c6d863.jpg
# counter -> 6701 109823394_83fcb735e1.jpg
# type .jpg
# 109823394_83fcb735e1.jpg
# counter -> 6702 2461990494_c5ece064cc.jpg
# type .jpg
# 2461990494_c5ece064cc.jpg
# counter -> 6703 3702038926_966fdaa311.jpg
# type .jpg
# 3702038926_966fdaa311.jpg
# counter -> 6704 3446762868_06e9d9d899.jpg
# type .jpg
# 3446762868_06e9d9d899.jpg
# counter -> 6705 255091930_aa2b5c0eb9.jpg
# type .jpg
# 255091930_aa2b5c0eb9.jpg
# counter -> 6706 2813588204_69fe7deb14.jpg
# type .jpg
# 2813588204_69fe7deb14.jpg
# counter -> 6707 103205630_682ca7285b.jpg
# type .jpg
# 103205630_682ca7285b.jpg
# counter -> 6708 3295452057_0c987f895f.jpg
# type .jpg
# 3295452057_0c987f895f.jpg
# counter -> 6709 2081141788_38fa84ce3c.jpg
# type .jpg
# 2081141788_38fa84ce3c.jpg
# counter -> 6710 300577375_26cc2773a1.jpg
# type .jpg
# 300577375_26cc2773a1.jpg
# counter -> 6711 1956678973_223cb1b847.jpg
# type .jpg
# 1956678973_223cb1b847.jpg
# counter -> 6712 3241892328_4ebf8b21ce.jpg
# type .jpg
# 3241892328_4ebf8b21ce.jpg
# counter -> 6713 2865703567_52de2444f2.jpg
# type .jpg
# 2865703567_52de2444f2.jpg
# counter -> 6714 161905204_247c6ca6de.jpg
# type .jpg
# 161905204_247c6ca6de.jpg
# counter -> 6715 2978394277_4572967b97.jpg
# type .jpg
# 2978394277_4572967b97.jpg
# counter -> 6716 578274277_652cae32ba.jpg
# type .jpg
# 578274277_652cae32ba.jpg
# counter -> 6717 3193335577_9bdbaf9f70.jpg
# type .jpg
# 3193335577_9bdbaf9f70.jpg
# counter -> 6718 3638631362_af29bbff01.jpg
# type .jpg
# 3638631362_af29bbff01.jpg
# counter -> 6719 2666179615_f05a9d8331.jpg
# type .jpg
# 2666179615_f05a9d8331.jpg
# counter -> 6720 3565021218_d2bc1aa644.jpg
# type .jpg
# 3565021218_d2bc1aa644.jpg
# counter -> 6721 3065560742_f6e266ccd9.jpg
# type .jpg
# 3065560742_f6e266ccd9.jpg
# counter -> 6722 381052465_722e00807b.jpg
# type .jpg
# 381052465_722e00807b.jpg
# counter -> 6723 215214751_e913b6ff09.jpg
# type .jpg
# 215214751_e913b6ff09.jpg
# counter -> 6724 2807177340_bc85291df5.jpg
# type .jpg
# 2807177340_bc85291df5.jpg
# counter -> 6725 3689355450_fd559b816d.jpg
# type .jpg
# 3689355450_fd559b816d.jpg
# counter -> 6726 2380464803_a64f05bfa9.jpg
# type .jpg
# 2380464803_a64f05bfa9.jpg
# counter -> 6727 798343627_7492fe0c12.jpg
# type .jpg
# 798343627_7492fe0c12.jpg
# counter -> 6728 3186863842_5832573c5e.jpg
# type .jpg
# 3186863842_5832573c5e.jpg
# counter -> 6729 244760301_5809214866.jpg
# type .jpg
# 244760301_5809214866.jpg
# counter -> 6730 2272491304_cb7c7ed16f.jpg
# type .jpg
# 2272491304_cb7c7ed16f.jpg
# counter -> 6731 56494233_1824005879.jpg
# type .jpg
# 56494233_1824005879.jpg
# counter -> 6732 469259974_bb03c15c42.jpg
# type .jpg
# 469259974_bb03c15c42.jpg
# counter -> 6733 1931690777_897a7d8ab6.jpg
# type .jpg
# 1931690777_897a7d8ab6.jpg
# counter -> 6734 2287023569_fd7a9c60b8.jpg
# type .jpg
# 2287023569_fd7a9c60b8.jpg
# counter -> 6735 2892992529_f3335d0a71.jpg
# type .jpg
# 2892992529_f3335d0a71.jpg
# counter -> 6736 3199460792_deef518c01.jpg
# type .jpg
# 3199460792_deef518c01.jpg
# counter -> 6737 2267923837_ae88678497.jpg
# type .jpg
# 2267923837_ae88678497.jpg
# counter -> 6738 2151300603_248a9fe715.jpg
# type .jpg
# 2151300603_248a9fe715.jpg
# counter -> 6739 2312731013_1a3a8e25c6.jpg
# type .jpg
# 2312731013_1a3a8e25c6.jpg
# counter -> 6740 2234702530_a265a4df22.jpg
# type .jpg
# 2234702530_a265a4df22.jpg
# counter -> 6741 3457604528_302396c08c.jpg
# type .jpg
# 3457604528_302396c08c.jpg
# counter -> 6742 2689163361_4939875be5.jpg
# type .jpg
# 2689163361_4939875be5.jpg
# counter -> 6743 3347666612_659e6e2207.jpg
# type .jpg
# 3347666612_659e6e2207.jpg
# counter -> 6744 3627290893_561e176e80.jpg
# type .jpg
# 3627290893_561e176e80.jpg
# counter -> 6745 309049466_1d7e7d5fc2.jpg
# type .jpg
# 309049466_1d7e7d5fc2.jpg
# counter -> 6746 278002947_3fd22a2cb6.jpg
# type .jpg
# 278002947_3fd22a2cb6.jpg
# counter -> 6747 2893238950_8a027be110.jpg
# type .jpg
# 2893238950_8a027be110.jpg
# counter -> 6748 542317719_ed4dd95dc2.jpg
# type .jpg
# 542317719_ed4dd95dc2.jpg
# counter -> 6749 468141298_3154d717e1.jpg
# type .jpg
# 468141298_3154d717e1.jpg
# counter -> 6750 2837808847_5407af1986.jpg
# type .jpg
# 2837808847_5407af1986.jpg
# counter -> 6751 1220401002_3f44b1f3f7.jpg
# type .jpg
# 1220401002_3f44b1f3f7.jpg
# counter -> 6752 927420680_6cba7c040a.jpg
# type .jpg
# 927420680_6cba7c040a.jpg
# counter -> 6753 757133580_ba974ef649.jpg
# type .jpg
# 757133580_ba974ef649.jpg
# counter -> 6754 1222322358_225067636e.jpg
# type .jpg
# 1222322358_225067636e.jpg
# counter -> 6755 3308997740_91765ecdcc.jpg
# type .jpg
# 3308997740_91765ecdcc.jpg
# counter -> 6756 3349968447_b5d4a477b2.jpg
# type .jpg
# 3349968447_b5d4a477b2.jpg
# counter -> 6757 1765164972_92dac06fa9.jpg
# type .jpg
# 1765164972_92dac06fa9.jpg
# counter -> 6758 3580375310_46ec3e476c.jpg
# type .jpg
# 3580375310_46ec3e476c.jpg
# counter -> 6759 2266142543_b2de18c081.jpg
# type .jpg
# 2266142543_b2de18c081.jpg
# counter -> 6760 513269597_c38308feaf.jpg
# type .jpg
# 513269597_c38308feaf.jpg
# counter -> 6761 166433861_70b66cd381.jpg
# type .jpg
# 166433861_70b66cd381.jpg
# counter -> 6762 3106562372_e349a27764.jpg
# type .jpg
# 3106562372_e349a27764.jpg
# counter -> 6763 2972929655_04233b5489.jpg
# type .jpg
# 2972929655_04233b5489.jpg
# counter -> 6764 2954525375_9d5ca97341.jpg
# type .jpg
# 2954525375_9d5ca97341.jpg
# counter -> 6765 3380643902_7e0670f80f.jpg
# type .jpg
# 3380643902_7e0670f80f.jpg
# counter -> 6766 425706089_f138118e12.jpg
# type .jpg
# 425706089_f138118e12.jpg
# counter -> 6767 2165461920_1a4144eb2b.jpg
# type .jpg
# 2165461920_1a4144eb2b.jpg
# counter -> 6768 295729735_8360f2e64c.jpg
# type .jpg
# 295729735_8360f2e64c.jpg
# counter -> 6769 466956675_a2fb6bf901.jpg
# type .jpg
# 466956675_a2fb6bf901.jpg
# counter -> 6770 2354829523_9542fc74ba.jpg
# type .jpg
# 2354829523_9542fc74ba.jpg
# counter -> 6771 2120383553_5825333a3f.jpg
# type .jpg
# 2120383553_5825333a3f.jpg
# counter -> 6772 2267682214_e1434d853b.jpg
# type .jpg
# 2267682214_e1434d853b.jpg
# counter -> 6773 314603661_51e05e0e24.jpg
# type .jpg
# 314603661_51e05e0e24.jpg
# counter -> 6774 3447876218_4ccf42d7a0.jpg
# type .jpg
# 3447876218_4ccf42d7a0.jpg
# counter -> 6775 2737729252_b3fd9c05b1.jpg
# type .jpg
# 2737729252_b3fd9c05b1.jpg
# counter -> 6776 533483374_86c5d4c13e.jpg
# type .jpg
# 533483374_86c5d4c13e.jpg
# counter -> 6777 890734502_a5ae67beac.jpg
# type .jpg
# 890734502_a5ae67beac.jpg
# counter -> 6778 3467843559_a457ce37b6.jpg
# type .jpg
# 3467843559_a457ce37b6.jpg
# counter -> 6779 3435035138_af32890a4c.jpg
# type .jpg
# 3435035138_af32890a4c.jpg
# counter -> 6780 445655284_c29e6d7323.jpg
# type .jpg
# 445655284_c29e6d7323.jpg
# counter -> 6781 267015208_d80b3eb94d.jpg
# type .jpg
# 267015208_d80b3eb94d.jpg
# counter -> 6782 3519815055_304dc8e8d6.jpg
# type .jpg
# 3519815055_304dc8e8d6.jpg
# counter -> 6783 3547524138_4157f660b0.jpg
# type .jpg
# 3547524138_4157f660b0.jpg
# counter -> 6784 527288854_f26127b770.jpg
# type .jpg
# 527288854_f26127b770.jpg
# counter -> 6785 102455176_5f8ead62d5.jpg
# type .jpg
# 102455176_5f8ead62d5.jpg
# counter -> 6786 1388346434_524d0b6dfa.jpg
# type .jpg
# 1388346434_524d0b6dfa.jpg
# counter -> 6787 2561341745_2d77d3ff7d.jpg
# type .jpg
# 2561341745_2d77d3ff7d.jpg
# counter -> 6788 239807547_4923efc821.jpg
# type .jpg
# 239807547_4923efc821.jpg
# counter -> 6789 3217187564_0ffd89dec1.jpg
# type .jpg
# 3217187564_0ffd89dec1.jpg
# counter -> 6790 33108590_d685bfe51c.jpg
# type .jpg
# 33108590_d685bfe51c.jpg
# counter -> 6791 3547499166_67fb4af4ea.jpg
# type .jpg
# 3547499166_67fb4af4ea.jpg
# counter -> 6792 624058168_f1c5e87e59.jpg
# type .jpg
# 624058168_f1c5e87e59.jpg
# counter -> 6793 3439331800_e71e1d808f.jpg
# type .jpg
# 3439331800_e71e1d808f.jpg
# counter -> 6794 2911552402_5166bc173b.jpg
# type .jpg
# 2911552402_5166bc173b.jpg
# counter -> 6795 3035118753_69287079dc.jpg
# type .jpg
# 3035118753_69287079dc.jpg
# counter -> 6796 950273886_88c324e663.jpg
# type .jpg
# 950273886_88c324e663.jpg
# counter -> 6797 2300920203_f29260b1db.jpg
# type .jpg
# 2300920203_f29260b1db.jpg
# counter -> 6798 374103776_0de490c1b0.jpg
# type .jpg
# 374103776_0de490c1b0.jpg
# counter -> 6799 3540416981_4e74f08cbb.jpg
# type .jpg
# 3540416981_4e74f08cbb.jpg
# counter -> 6800 241347760_d44c8d3a01.jpg
# type .jpg
# 241347760_d44c8d3a01.jpg
# counter -> 6801 2785108434_cd4a1c949c.jpg
# type .jpg
# 2785108434_cd4a1c949c.jpg
# counter -> 6802 2642475077_69d19deb74.jpg
# type .jpg
# 2642475077_69d19deb74.jpg
# counter -> 6803 3098707588_5096d20397.jpg
# type .jpg
# 3098707588_5096d20397.jpg
# counter -> 6804 3046430047_d7b10123d0.jpg
# type .jpg
# 3046430047_d7b10123d0.jpg
# counter -> 6805 3058627443_1d57ff0a2c.jpg
# type .jpg
# 3058627443_1d57ff0a2c.jpg
# counter -> 6806 297285273_688e44c014.jpg
# type .jpg
# 297285273_688e44c014.jpg
# counter -> 6807 468608014_09fd20eb9b.jpg
# type .jpg
# 468608014_09fd20eb9b.jpg
# counter -> 6808 2848266893_9693c66275.jpg
# type .jpg
# 2848266893_9693c66275.jpg
# counter -> 6809 2878190821_6e4e03dc5f.jpg
# type .jpg
# 2878190821_6e4e03dc5f.jpg
# counter -> 6810 3336361161_c06cdd160e.jpg
# type .jpg
# 3336361161_c06cdd160e.jpg
# counter -> 6811 3497106366_d1a256e723.jpg
# type .jpg
# 3497106366_d1a256e723.jpg
# counter -> 6812 2726301121_95a2fbd22b.jpg
# type .jpg
# 2726301121_95a2fbd22b.jpg
# counter -> 6813 1057251835_6ded4ada9c.jpg
# type .jpg
# 1057251835_6ded4ada9c.jpg
# counter -> 6814 3211199368_ca78387f72.jpg
# type .jpg
# 3211199368_ca78387f72.jpg
# counter -> 6815 319869052_08b000e4af.jpg
# type .jpg
# 319869052_08b000e4af.jpg
# counter -> 6816 2602679255_785b851b46.jpg
# type .jpg
# 2602679255_785b851b46.jpg
# counter -> 6817 3342272425_804316cb3d.jpg
# type .jpg
# 3342272425_804316cb3d.jpg
# counter -> 6818 2225241766_f1e7132e3e.jpg
# type .jpg
# 2225241766_f1e7132e3e.jpg
# counter -> 6819 3264337159_e1680a35ba.jpg
# type .jpg
# 3264337159_e1680a35ba.jpg
# counter -> 6820 3419238351_ac18b440c0.jpg
# type .jpg
# 3419238351_ac18b440c0.jpg
# counter -> 6821 1100214449_d10861e633.jpg
# type .jpg
# 1100214449_d10861e633.jpg
# counter -> 6822 2431470169_0eeba7d602.jpg
# type .jpg
# 2431470169_0eeba7d602.jpg
# counter -> 6823 2089555297_95cf001fa7.jpg
# type .jpg
# 2089555297_95cf001fa7.jpg
# counter -> 6824 3406409018_03de95181e.jpg
# type .jpg
# 3406409018_03de95181e.jpg
# counter -> 6825 300148649_72f7f0399c.jpg
# type .jpg
# 300148649_72f7f0399c.jpg
# counter -> 6826 2795352290_9209b214f3.jpg
# type .jpg
# 2795352290_9209b214f3.jpg
# counter -> 6827 3470303255_fbb41b8dd0.jpg
# type .jpg
# 3470303255_fbb41b8dd0.jpg
# counter -> 6828 3537474810_cf676b3259.jpg
# type .jpg
# 3537474810_cf676b3259.jpg
# counter -> 6829 2065875490_a46b58c12b.jpg
# type .jpg
# 2065875490_a46b58c12b.jpg
# counter -> 6830 2624044128_641b38c0cf.jpg
# type .jpg
# 2624044128_641b38c0cf.jpg
# counter -> 6831 3439382048_d2e23b2b4c.jpg
# type .jpg
# 3439382048_d2e23b2b4c.jpg
# counter -> 6832 3561130207_d1ed166daa.jpg
# type .jpg
# 3561130207_d1ed166daa.jpg
# counter -> 6833 3385956569_a849218e34.jpg
# type .jpg
# 3385956569_a849218e34.jpg
# counter -> 6834 3443460885_46115463b4.jpg
# type .jpg
# 3443460885_46115463b4.jpg
# counter -> 6835 2514581496_8f4102377e.jpg
# type .jpg
# 2514581496_8f4102377e.jpg
# counter -> 6836 481732592_b50194cb89.jpg
# type .jpg
# 481732592_b50194cb89.jpg
# counter -> 6837 406901451_7eafd7568a.jpg
# type .jpg
# 406901451_7eafd7568a.jpg
# counter -> 6838 3229442620_fd47d01b59.jpg
# type .jpg
# 3229442620_fd47d01b59.jpg
# counter -> 6839 3009644534_992e9ea2a7.jpg
# type .jpg
# 3009644534_992e9ea2a7.jpg
# counter -> 6840 3094317837_b31cbf969e.jpg
# type .jpg
# 3094317837_b31cbf969e.jpg
# counter -> 6841 3613175012_bcd063e7c9.jpg
# type .jpg
# 3613175012_bcd063e7c9.jpg
# counter -> 6842 524310507_51220580de.jpg
# type .jpg
# 524310507_51220580de.jpg
# counter -> 6843 488549693_a1f51d8c4a.jpg
# type .jpg
# 488549693_a1f51d8c4a.jpg
# counter -> 6844 3127888173_9a9a8ac3bd.jpg
# type .jpg
# 3127888173_9a9a8ac3bd.jpg
# counter -> 6845 3076928208_5763e9eb8c.jpg
# type .jpg
# 3076928208_5763e9eb8c.jpg
# counter -> 6846 1248734482_3038218f3b.jpg
# type .jpg
# 1248734482_3038218f3b.jpg
# counter -> 6847 3128514681_a51b415c31.jpg
# type .jpg
# 3128514681_a51b415c31.jpg
# counter -> 6848 413231421_43833a11f5.jpg
# type .jpg
# 413231421_43833a11f5.jpg
# counter -> 6849 2662890367_382eaf83bd.jpg
# type .jpg
# 2662890367_382eaf83bd.jpg
# counter -> 6850 3501313414_ae865b6fdf.jpg
# type .jpg
# 3501313414_ae865b6fdf.jpg
# counter -> 6851 888425986_e4b6c12324.jpg
# type .jpg
# 888425986_e4b6c12324.jpg
# counter -> 6852 1423997242_ea2189ec5e.jpg
# type .jpg
# 1423997242_ea2189ec5e.jpg
# counter -> 6853 2068403258_2669cf9763.jpg
# type .jpg
# 2068403258_2669cf9763.jpg
# counter -> 6854 3356284586_21c6f155a5.jpg
# type .jpg
# 3356284586_21c6f155a5.jpg
# counter -> 6855 3099923914_fd450f6d51.jpg
# type .jpg
# 3099923914_fd450f6d51.jpg
# counter -> 6856 3222250187_ef610f267e.jpg
# type .jpg
# 3222250187_ef610f267e.jpg
# counter -> 6857 2474918824_88660c7757.jpg
# type .jpg
# 2474918824_88660c7757.jpg
# counter -> 6858 3367053761_8ec5834bf3.jpg
# type .jpg
# 3367053761_8ec5834bf3.jpg
# counter -> 6859 2986671935_0c60bbb3fa.jpg
# type .jpg
# 2986671935_0c60bbb3fa.jpg
# counter -> 6860 3469711377_bc29d48737.jpg
# type .jpg
# 3469711377_bc29d48737.jpg
# counter -> 6861 469021173_aa31c07108.jpg
# type .jpg
# 469021173_aa31c07108.jpg
# counter -> 6862 2438085746_588dce8724.jpg
# type .jpg
# 2438085746_588dce8724.jpg
# counter -> 6863 3542425197_2ef81c6051.jpg
# type .jpg
# 3542425197_2ef81c6051.jpg
# counter -> 6864 2127209046_94711c747b.jpg
# type .jpg
# 2127209046_94711c747b.jpg
# counter -> 6865 3606355203_1260f43ec0.jpg
# type .jpg
# 3606355203_1260f43ec0.jpg
# counter -> 6866 3353328134_dd9ed0edab.jpg
# type .jpg
# 3353328134_dd9ed0edab.jpg
# counter -> 6867 3582066525_e9d6377f56.jpg
# type .jpg
# 3582066525_e9d6377f56.jpg
# counter -> 6868 3294209955_a1f1e2cc19.jpg
# type .jpg
# 3294209955_a1f1e2cc19.jpg
# counter -> 6869 3726076549_0efb38854b.jpg
# type .jpg
# 3726076549_0efb38854b.jpg
# counter -> 6870 1262454669_f1caafec2d.jpg
# type .jpg
# 1262454669_f1caafec2d.jpg
# counter -> 6871 3111897772_5211a37a02.jpg
# type .jpg
# 3111897772_5211a37a02.jpg
# counter -> 6872 3442272060_f9155194c2.jpg
# type .jpg
# 3442272060_f9155194c2.jpg
# counter -> 6873 1084040636_97d9633581.jpg
# type .jpg
# 1084040636_97d9633581.jpg
# counter -> 6874 438639005_208bc59b0b.jpg
# type .jpg
# 438639005_208bc59b0b.jpg
# counter -> 6875 405970010_8cebaa77d3.jpg
# type .jpg
# 405970010_8cebaa77d3.jpg
# counter -> 6876 3309578722_1765d7d1af.jpg
# type .jpg
# 3309578722_1765d7d1af.jpg
# counter -> 6877 2836703077_fa9c736203.jpg
# type .jpg
# 2836703077_fa9c736203.jpg
# counter -> 6878 3486154327_8be7c78569.jpg
# type .jpg
# 3486154327_8be7c78569.jpg
# counter -> 6879 3497237366_366997495d.jpg
# type .jpg
# 3497237366_366997495d.jpg
# counter -> 6880 3017220118_6a9212dfdb.jpg
# type .jpg
# 3017220118_6a9212dfdb.jpg
# counter -> 6881 3351360323_91bb341350.jpg
# type .jpg
# 3351360323_91bb341350.jpg
# counter -> 6882 3393152604_27bd1037f2.jpg
# type .jpg
# 3393152604_27bd1037f2.jpg
# counter -> 6883 1470061031_4cb59c12a8.jpg
# type .jpg
# 1470061031_4cb59c12a8.jpg
# counter -> 6884 3250076419_eb3de15063.jpg
# type .jpg
# 3250076419_eb3de15063.jpg
# counter -> 6885 3533394378_1513ec90db.jpg
# type .jpg
# 3533394378_1513ec90db.jpg
# counter -> 6886 1859941832_7faf6e5fa9.jpg
# type .jpg
# 1859941832_7faf6e5fa9.jpg
# counter -> 6887 1874617189_e85d3f4326.jpg
# type .jpg
# 1874617189_e85d3f4326.jpg
# counter -> 6888 3440724965_03d6ca5399.jpg
# type .jpg
# 3440724965_03d6ca5399.jpg
# counter -> 6889 166321294_4a5e68535f.jpg
# type .jpg
# 166321294_4a5e68535f.jpg
# counter -> 6890 400562847_e15aba0aac.jpg
# type .jpg
# 400562847_e15aba0aac.jpg
# counter -> 6891 3504158556_1d410c8ff7.jpg
# type .jpg
# 3504158556_1d410c8ff7.jpg
# counter -> 6892 3440952969_608eb5e42b.jpg
# type .jpg
# 3440952969_608eb5e42b.jpg
# counter -> 6893 3276895962_c053263d01.jpg
# type .jpg
# 3276895962_c053263d01.jpg
# counter -> 6894 2221818690_9003756d33.jpg
# type .jpg
# 2221818690_9003756d33.jpg
# counter -> 6895 2839890871_4b7c7dbd96.jpg
# type .jpg
# 2839890871_4b7c7dbd96.jpg
# counter -> 6896 3155365418_43df5486f9.jpg
# type .jpg
# 3155365418_43df5486f9.jpg
# counter -> 6897 2736902411_a0010f89ae.jpg
# type .jpg
# 2736902411_a0010f89ae.jpg
# counter -> 6898 2252403744_148fc11f68.jpg
# type .jpg
# 2252403744_148fc11f68.jpg
# counter -> 6899 2396669903_5217a83641.jpg
# type .jpg
# 2396669903_5217a83641.jpg
# counter -> 6900 887108308_2da97f15ef.jpg
# type .jpg
# 887108308_2da97f15ef.jpg
# counter -> 6901 3220200084_3ea129336e.jpg
# type .jpg
# 3220200084_3ea129336e.jpg
# counter -> 6902 3657016761_d553e514d9.jpg
# type .jpg
# 3657016761_d553e514d9.jpg
# counter -> 6903 2092870249_90e3f1855b.jpg
# type .jpg
# 2092870249_90e3f1855b.jpg
# counter -> 6904 3090957866_f1b2b7f214.jpg
# type .jpg
# 3090957866_f1b2b7f214.jpg
# counter -> 6905 3066491113_86569e15be.jpg
# type .jpg
# 3066491113_86569e15be.jpg
# counter -> 6906 3526805681_38461c0d5d.jpg
# type .jpg
# 3526805681_38461c0d5d.jpg
# counter -> 6907 2662537919_18a29fca8a.jpg
# type .jpg
# 2662537919_18a29fca8a.jpg
# counter -> 6908 2914800692_0c512d27b8.jpg
# type .jpg
# 2914800692_0c512d27b8.jpg
# counter -> 6909 2505465055_f1e6cf9b76.jpg
# type .jpg
# 2505465055_f1e6cf9b76.jpg
# counter -> 6910 3049649128_d83d847168.jpg
# type .jpg
# 3049649128_d83d847168.jpg
# counter -> 6911 2422302286_385725e3cf.jpg
# type .jpg
# 2422302286_385725e3cf.jpg
# counter -> 6912 3497485793_e36c1d2779.jpg
# type .jpg
# 3497485793_e36c1d2779.jpg
# counter -> 6913 3596428453_8cfdec4869.jpg
# type .jpg
# 3596428453_8cfdec4869.jpg
# counter -> 6914 460781612_6815c74d37.jpg
# type .jpg
# 460781612_6815c74d37.jpg
# counter -> 6915 3494394662_3edfd4a34c.jpg
# type .jpg
# 3494394662_3edfd4a34c.jpg
# counter -> 6916 361183669_52be9662b9.jpg
# type .jpg
# 361183669_52be9662b9.jpg
# counter -> 6917 3027850131_a7772e0ba0.jpg
# type .jpg
# 3027850131_a7772e0ba0.jpg
# counter -> 6918 524031846_28b11bc0e5.jpg
# type .jpg
# 524031846_28b11bc0e5.jpg
# counter -> 6919 344841963_8b0fa9784c.jpg
# type .jpg
# 344841963_8b0fa9784c.jpg
# counter -> 6920 3217620013_8b17873273.jpg
# type .jpg
# 3217620013_8b17873273.jpg
# counter -> 6921 2597873827_a5cb3e57ba.jpg
# type .jpg
# 2597873827_a5cb3e57ba.jpg
# counter -> 6922 1394599090_fe0ba238f0.jpg
# type .jpg
# 1394599090_fe0ba238f0.jpg
# counter -> 6923 2222498879_9e82a100ab.jpg
# type .jpg
# 2222498879_9e82a100ab.jpg
# counter -> 6924 2573625591_70291c894a.jpg
# type .jpg
# 2573625591_70291c894a.jpg
# counter -> 6925 1334892555_1beff092c3.jpg
# type .jpg
# 1334892555_1beff092c3.jpg
# counter -> 6926 2831217847_555b2f95ca.jpg
# type .jpg
# 2831217847_555b2f95ca.jpg
# counter -> 6927 1304961697_76b86b0c18.jpg
# type .jpg
# 1304961697_76b86b0c18.jpg
# counter -> 6928 494329594_6e751372a0.jpg
# type .jpg
# 494329594_6e751372a0.jpg
# counter -> 6929 368212336_bc19b0bb72.jpg
# type .jpg
# 368212336_bc19b0bb72.jpg
# counter -> 6930 233361142_d9d5f0cae9.jpg
# type .jpg
# 233361142_d9d5f0cae9.jpg
# counter -> 6931 3597326009_3678a98a43.jpg
# type .jpg
# 3597326009_3678a98a43.jpg
# counter -> 6932 3275065565_9e2a640fbc.jpg
# type .jpg
# 3275065565_9e2a640fbc.jpg
# counter -> 6933 539750844_02a07ec524.jpg
# type .jpg
# 539750844_02a07ec524.jpg
# counter -> 6934 1679617928_a73c1769be.jpg
# type .jpg
# 1679617928_a73c1769be.jpg
# counter -> 6935 3559781965_d4ec00e506.jpg
# type .jpg
# 3559781965_d4ec00e506.jpg
# counter -> 6936 2867845624_22e4fe0a23.jpg
# type .jpg
# 2867845624_22e4fe0a23.jpg
# counter -> 6937 3574244361_715ac347cd.jpg
# type .jpg
# 3574244361_715ac347cd.jpg
# counter -> 6938 2562463210_d0dfd545ca.jpg
# type .jpg
# 2562463210_d0dfd545ca.jpg
# counter -> 6939 3273325447_81c94000da.jpg
# type .jpg
# 3273325447_81c94000da.jpg
# counter -> 6940 3259231890_16fe167b31.jpg
# type .jpg
# 3259231890_16fe167b31.jpg
# counter -> 6941 3070011270_390e597783.jpg
# type .jpg
# 3070011270_390e597783.jpg
# counter -> 6942 3198962089_e647d1b0cd.jpg
# type .jpg
# 3198962089_e647d1b0cd.jpg
# counter -> 6943 2185793891_5a5e903ca6.jpg
# type .jpg
# 2185793891_5a5e903ca6.jpg
# counter -> 6944 3123463486_f5b36a3624.jpg
# type .jpg
# 3123463486_f5b36a3624.jpg
# counter -> 6945 3686078365_9e655e238f.jpg
# type .jpg
# 3686078365_9e655e238f.jpg
# counter -> 6946 241345427_ece0d186c2.jpg
# type .jpg
# 241345427_ece0d186c2.jpg
# counter -> 6947 2875658507_c0d9ceae90.jpg
# type .jpg
# 2875658507_c0d9ceae90.jpg
# counter -> 6948 2739332078_13d9acce59.jpg
# type .jpg
# 2739332078_13d9acce59.jpg
# counter -> 6949 3556792157_d09d42bef7.jpg
# type .jpg
# 3556792157_d09d42bef7.jpg
# counter -> 6950 3330007895_78303e8a40.jpg
# type .jpg
# 3330007895_78303e8a40.jpg
# counter -> 6951 292887910_f34ac101c8.jpg
# type .jpg
# 292887910_f34ac101c8.jpg
# counter -> 6952 3122579598_14841c038a.jpg
# type .jpg
# 3122579598_14841c038a.jpg
# counter -> 6953 3415165462_e1cb536d08.jpg
# type .jpg
# 3415165462_e1cb536d08.jpg
# counter -> 6954 2594336381_a93772823b.jpg
# type .jpg
# 2594336381_a93772823b.jpg
# counter -> 6955 1093737381_b313cd49ff.jpg
# type .jpg
# 1093737381_b313cd49ff.jpg
# counter -> 6956 2075041394_0b3ea1822d.jpg
# type .jpg
# 2075041394_0b3ea1822d.jpg
# counter -> 6957 1718184338_5968d88edb.jpg
# type .jpg
# 1718184338_5968d88edb.jpg
# counter -> 6958 2872806249_00bea3c4e7.jpg
# type .jpg
# 2872806249_00bea3c4e7.jpg
# counter -> 6959 2460823604_7f6f786b1c.jpg
# type .jpg
# 2460823604_7f6f786b1c.jpg
# counter -> 6960 3462396164_ba9849c14b.jpg
# type .jpg
# 3462396164_ba9849c14b.jpg
# counter -> 6961 957230475_48f4285ffe.jpg
# type .jpg
# 957230475_48f4285ffe.jpg
# counter -> 6962 2280354512_c0d035d53f.jpg
# type .jpg
# 2280354512_c0d035d53f.jpg
# counter -> 6963 3544573946_e03aebbfde.jpg
# type .jpg
# 3544573946_e03aebbfde.jpg
# counter -> 6964 3737711435_113ccd0a52.jpg
# type .jpg
# 3737711435_113ccd0a52.jpg
# counter -> 6965 3725177385_62d5e13634.jpg
# type .jpg
# 3725177385_62d5e13634.jpg
# counter -> 6966 2390369143_6523253a73.jpg
# type .jpg
# 2390369143_6523253a73.jpg
# counter -> 6967 1287920676_d21a0b289b.jpg
# type .jpg
# 1287920676_d21a0b289b.jpg
# counter -> 6968 3174453534_fcc927c647.jpg
# type .jpg
# 3174453534_fcc927c647.jpg
# counter -> 6969 3538527033_df13112d51.jpg
# type .jpg
# 3538527033_df13112d51.jpg
# counter -> 6970 2524084967_a5e011b73d.jpg
# type .jpg
# 2524084967_a5e011b73d.jpg
# counter -> 6971 2446601467_a35841cb1d.jpg
# type .jpg
# 2446601467_a35841cb1d.jpg
# counter -> 6972 1721637099_93e9ec2a2f.jpg
# type .jpg
# 1721637099_93e9ec2a2f.jpg
# counter -> 6973 3323076458_3ce72a1dae.jpg
# type .jpg
# 3323076458_3ce72a1dae.jpg
# counter -> 6974 694496803_f2a05869cf.jpg
# type .jpg
# 694496803_f2a05869cf.jpg
# counter -> 6975 368954110_821ccf005c.jpg
# type .jpg
# 368954110_821ccf005c.jpg
# counter -> 6976 2685752892_9d5cd7f274.jpg
# type .jpg
# 2685752892_9d5cd7f274.jpg
# counter -> 6977 3585487286_ef9a8d4c56.jpg
# type .jpg
# 3585487286_ef9a8d4c56.jpg
# counter -> 6978 3426789838_8771f0ed56.jpg
# type .jpg
# 3426789838_8771f0ed56.jpg
# counter -> 6979 3195040792_a03954a19f.jpg
# type .jpg
# 3195040792_a03954a19f.jpg
# counter -> 6980 3493479159_609ebe1b35.jpg
# type .jpg
# 3493479159_609ebe1b35.jpg
# counter -> 6981 2778290592_1910bb0431.jpg
# type .jpg
# 2778290592_1910bb0431.jpg
# counter -> 6982 3294179574_4f67e67d6f.jpg
# type .jpg
# 3294179574_4f67e67d6f.jpg
# counter -> 6983 3294717824_3bb7b5d1c8.jpg
# type .jpg
# 3294717824_3bb7b5d1c8.jpg
# counter -> 6984 3638374272_444f5e0457.jpg
# type .jpg
# 3638374272_444f5e0457.jpg
# counter -> 6985 3383545083_1d7c95b003.jpg
# type .jpg
# 3383545083_1d7c95b003.jpg
# counter -> 6986 1523984678_edd68464da.jpg
# type .jpg
# 1523984678_edd68464da.jpg
# counter -> 6987 1348891916_ebd4413033.jpg
# type .jpg
# 1348891916_ebd4413033.jpg
# counter -> 6988 2894008505_a445ccaaff.jpg
# type .jpg
# 2894008505_a445ccaaff.jpg
# counter -> 6989 566921157_07c18a41e2.jpg
# type .jpg
# 566921157_07c18a41e2.jpg
# counter -> 6990 3404906655_bc51c69c1e.jpg
# type .jpg
# 3404906655_bc51c69c1e.jpg
# counter -> 6991 200771289_31902164a7.jpg
# type .jpg
# 200771289_31902164a7.jpg
# counter -> 6992 2309327462_82a24538d4.jpg
# type .jpg
# 2309327462_82a24538d4.jpg
# counter -> 6993 3486831913_2b9390ebbc.jpg
# type .jpg
# 3486831913_2b9390ebbc.jpg
# counter -> 6994 581419370_30485f3580.jpg
# type .jpg
# 581419370_30485f3580.jpg
# counter -> 6995 2860040276_eac0aca4fc.jpg
# type .jpg
# 2860040276_eac0aca4fc.jpg
# counter -> 6996 888517718_3d5b4b7b43.jpg
# type .jpg
# 888517718_3d5b4b7b43.jpg
# counter -> 6997 2856699493_65edef80a1.jpg
# type .jpg
# 2856699493_65edef80a1.jpg
# counter -> 6998 2301867590_98c0ecb0cb.jpg
# type .jpg
# 2301867590_98c0ecb0cb.jpg
# counter -> 6999 444481722_690d0cadcf.jpg
# type .jpg
# 444481722_690d0cadcf.jpg
# counter -> 7000 3444974984_963fb441a0.jpg
# type .jpg
# 3444974984_963fb441a0.jpg
# counter -> 7001 3608400551_d6f7965308.jpg
# type .jpg
# 3608400551_d6f7965308.jpg
# counter -> 7002 2056042552_f59e338533.jpg
# type .jpg
# 2056042552_f59e338533.jpg
# counter -> 7003 47870024_73a4481f7d.jpg
# type .jpg
# 47870024_73a4481f7d.jpg
# counter -> 7004 2286235203_af3cd8f243.jpg
# type .jpg
# 2286235203_af3cd8f243.jpg
# counter -> 7005 2195887578_3ba2f29b48.jpg
# type .jpg
# 2195887578_3ba2f29b48.jpg
# counter -> 7006 2335634931_7e9e8c2959.jpg
# type .jpg
# 2335634931_7e9e8c2959.jpg
# counter -> 7007 2192026581_b782d1355a.jpg
# type .jpg
# 2192026581_b782d1355a.jpg
# counter -> 7008 698107542_3aa0ba78b4.jpg
# type .jpg
# 698107542_3aa0ba78b4.jpg
# counter -> 7009 2814406547_a237ef0122.jpg
# type .jpg
# 2814406547_a237ef0122.jpg
# counter -> 7010 2393410666_b8c20fff61.jpg
# type .jpg
# 2393410666_b8c20fff61.jpg
# counter -> 7011 3159447439_c1496cbaea.jpg
# type .jpg
# 3159447439_c1496cbaea.jpg
# counter -> 7012 2096771662_984441d20d.jpg
# type .jpg
# 2096771662_984441d20d.jpg
# counter -> 7013 2182050469_1edac0bc60.jpg
# type .jpg
# 2182050469_1edac0bc60.jpg
# counter -> 7014 244443352_d7636e1253.jpg
# type .jpg
# 244443352_d7636e1253.jpg
# counter -> 7015 2068960566_21e85ae0dc.jpg
# type .jpg
# 2068960566_21e85ae0dc.jpg
# counter -> 7016 3027399066_ca85495775.jpg
# type .jpg
# 3027399066_ca85495775.jpg
# counter -> 7017 2934801096_230ae78d7e.jpg
# type .jpg
# 2934801096_230ae78d7e.jpg
# counter -> 7018 2905948395_ca3e6b3c9a.jpg
# type .jpg
# 2905948395_ca3e6b3c9a.jpg
# counter -> 7019 2836360729_6500249fe6.jpg
# type .jpg
# 2836360729_6500249fe6.jpg
# counter -> 7020 1414820925_3504c394e1.jpg
# type .jpg
# 1414820925_3504c394e1.jpg
# counter -> 7021 3484841598_e26ee96aab.jpg
# type .jpg
# 3484841598_e26ee96aab.jpg
# counter -> 7022 3102363657_dc95fe6850.jpg
# type .jpg
# 3102363657_dc95fe6850.jpg
# counter -> 7023 3601803640_5f3cb05acf.jpg
# type .jpg
# 3601803640_5f3cb05acf.jpg
# counter -> 7024 3352697012_751b079bbb.jpg
# type .jpg
# 3352697012_751b079bbb.jpg
# counter -> 7025 2268729848_d418451226.jpg
# type .jpg
# 2268729848_d418451226.jpg
# counter -> 7026 2660480624_45f88b3022.jpg
# type .jpg
# 2660480624_45f88b3022.jpg
# counter -> 7027 2057306459_2f52ce648e.jpg
# type .jpg
# 2057306459_2f52ce648e.jpg
# counter -> 7028 3208999896_dab42dc40b.jpg
# type .jpg
# 3208999896_dab42dc40b.jpg
# counter -> 7029 3174156702_95a1cda2d9.jpg
# type .jpg
# 3174156702_95a1cda2d9.jpg
# counter -> 7030 2140182410_8e2a06fbda.jpg
# type .jpg
# 2140182410_8e2a06fbda.jpg
# counter -> 7031 2661294481_b86058b504.jpg
# type .jpg
# 2661294481_b86058b504.jpg
# counter -> 7032 1884727806_d84f209868.jpg
# type .jpg
# 1884727806_d84f209868.jpg
# counter -> 7033 411011549_1298d2b4d2.jpg
# type .jpg
# 411011549_1298d2b4d2.jpg
# counter -> 7034 1572286502_64e5c4b920.jpg
# type .jpg
# 1572286502_64e5c4b920.jpg
# counter -> 7035 3074617663_2f2634081d.jpg
# type .jpg
# 3074617663_2f2634081d.jpg
# counter -> 7036 472661386_723aae880b.jpg
# type .jpg
# 472661386_723aae880b.jpg
# counter -> 7037 3330019493_fd36fbc2ea.jpg
# type .jpg
# 3330019493_fd36fbc2ea.jpg
# counter -> 7038 324208502_674488bcea.jpg
# type .jpg
# 324208502_674488bcea.jpg
# counter -> 7039 3189521080_133777bce5.jpg
# type .jpg
# 3189521080_133777bce5.jpg
# counter -> 7040 3562001359_65c63aeda3.jpg
# type .jpg
# 3562001359_65c63aeda3.jpg
# counter -> 7041 3331009729_d3b14738e6.jpg
# type .jpg
# 3331009729_d3b14738e6.jpg
# counter -> 7042 242324909_06d5a6c44b.jpg
# type .jpg
# ...
# type .jpg
# 460195978_fc522a4979.jpg
# counter -> 7886 1253264731_e7c689eca5.jpg
# type .jpg
# 1253264731_e7c689eca5.jpg
# counter -> 7887 2873445888_8764699246.jpg
# type .jpg
# 2873445888_8764699246.jpg
# counter -> 7888 3354489242_dd529ffa1f.jpg
# type .jpg
# 3354489242_dd529ffa1f.jpg
# counter -> 7889 2749124446_d4432787b5.jpg
# type .jpg
# 2749124446_d4432787b5.jpg
# counter -> 7890 624742559_ff467d8ebc.jpg
# type .jpg
# 624742559_ff467d8ebc.jpg
# counter -> 7891 3649382413_58a4b1efe8.jpg
# type .jpg
# 3649382413_58a4b1efe8.jpg
# counter -> 7892 3258391809_38fc6211f7.jpg
# type .jpg
# 3258391809_38fc6211f7.jpg
# counter -> 7893 778885185_3f6905370b.jpg
# type .jpg
# 778885185_3f6905370b.jpg
# counter -> 7894 3006093003_c211737232.jpg
# type .jpg
# 3006093003_c211737232.jpg
# counter -> 7895 2347921097_f2e35753c0.jpg
# type .jpg
# 2347921097_f2e35753c0.jpg
# counter -> 7896 2661489896_cc3425777e.jpg
# type .jpg
# 2661489896_cc3425777e.jpg
# counter -> 7897 3595992258_6f192e6ae7.jpg
# type .jpg
# 3595992258_6f192e6ae7.jpg
# counter -> 7898 3289893683_d4cc3ce208.jpg
# type .jpg
# 3289893683_d4cc3ce208.jpg
# counter -> 7899 3091962081_194f2f3bd4.jpg
# type .jpg
# 3091962081_194f2f3bd4.jpg
# counter -> 7900 2414384480_096867d695.jpg
# type .jpg
# 2414384480_096867d695.jpg
# counter -> 7901 529198549_5cd9fedf3f.jpg
# type .jpg
# 529198549_5cd9fedf3f.jpg
# counter -> 7902 2525455265_f84ba72bd7.jpg
# type .jpg
# 2525455265_f84ba72bd7.jpg
# counter -> 7903 2657484284_daa07a3a1b.jpg
# type .jpg
# 2657484284_daa07a3a1b.jpg
# counter -> 7904 2972864304_481aeffe50.jpg
# type .jpg
# 2972864304_481aeffe50.jpg
# counter -> 7905 874665322_9ad05c4065.jpg
# type .jpg
# 874665322_9ad05c4065.jpg
# counter -> 7906 751109943_2a7f8e117f.jpg
# type .jpg
# 751109943_2a7f8e117f.jpg
# counter -> 7907 3336211088_4c294a870b.jpg
# type .jpg
# 3336211088_4c294a870b.jpg
# counter -> 7908 2847859796_4d9cb0d31f.jpg
# type .jpg
# 2847859796_4d9cb0d31f.jpg
# counter -> 7909 2896298341_92d718366a.jpg
# type .jpg
# 2896298341_92d718366a.jpg
# counter -> 7910 3066429707_842e50b8f7.jpg
# type .jpg
# 3066429707_842e50b8f7.jpg
# counter -> 7911 2647062476_5ef31ba867.jpg
# type .jpg
# 2647062476_5ef31ba867.jpg
# counter -> 7912 97105139_fae46fe8ef.jpg
# type .jpg
# 97105139_fae46fe8ef.jpg
# counter -> 7913 3682277595_55f8b16975.jpg
# type .jpg
# 3682277595_55f8b16975.jpg
# counter -> 7914 2822148499_eaa46c99d4.jpg
# type .jpg
# 2822148499_eaa46c99d4.jpg
# counter -> 7915 2130203183_49bae96b96.jpg
# type .jpg
# 2130203183_49bae96b96.jpg
# counter -> 7916 233327292_3bcbc3783f.jpg
# type .jpg
# 233327292_3bcbc3783f.jpg
# counter -> 7917 3159995270_17334ccb5b.jpg
# type .jpg
# 3159995270_17334ccb5b.jpg
# counter -> 7918 2271890493_da441718ba.jpg
# type .jpg
# 2271890493_da441718ba.jpg
# counter -> 7919 566446626_9793890f95.jpg
# type .jpg
# 566446626_9793890f95.jpg
# counter -> 7920 3294830188_e46bd9b93c.jpg
# type .jpg
# 3294830188_e46bd9b93c.jpg
# counter -> 7921 3725353555_75c346d7ec.jpg
# type .jpg
# 3725353555_75c346d7ec.jpg
# counter -> 7922 2424976964_98f58a0618.jpg
# type .jpg
# 2424976964_98f58a0618.jpg
# counter -> 7923 2251747182_6b67a3ab8b.jpg
# type .jpg
# 2251747182_6b67a3ab8b.jpg
# counter -> 7924 488416045_1c6d903fe0.jpg
# type .jpg
# 488416045_1c6d903fe0.jpg
# counter -> 7925 3412822878_5d961492e5.jpg
# type .jpg
# 3412822878_5d961492e5.jpg
# counter -> 7926 2528489543_546c1ca81f.jpg
# type .jpg
# 2528489543_546c1ca81f.jpg
# counter -> 7927 2541901399_0a57f4cc76.jpg
# type .jpg
# 2541901399_0a57f4cc76.jpg
# counter -> 7928 2709275718_73fcf08c23.jpg
# type .jpg
# 2709275718_73fcf08c23.jpg
# counter -> 7929 3372340429_91c4f4af30.jpg
# type .jpg
# 3372340429_91c4f4af30.jpg
# counter -> 7930 3273091032_98f724b36b.jpg
# type .jpg
# 3273091032_98f724b36b.jpg
# counter -> 7931 3025546819_ce031d2fc3.jpg
# type .jpg
# 3025546819_ce031d2fc3.jpg
# counter -> 7932 3648097366_706c8a57a1.jpg
# type .jpg
# 3648097366_706c8a57a1.jpg
# counter -> 7933 3341084434_db5e7d1fdc.jpg
# type .jpg
# 3341084434_db5e7d1fdc.jpg
# counter -> 7934 241347391_4fcd4639f4.jpg
# type .jpg
# 241347391_4fcd4639f4.jpg
# counter -> 7935 3214381315_b54f5c9be4.jpg
# type .jpg
# 3214381315_b54f5c9be4.jpg
# counter -> 7936 1187435567_18173c148b.jpg
# type .jpg
# 1187435567_18173c148b.jpg
# counter -> 7937 2260369648_e21ae6494a.jpg
# type .jpg
# 2260369648_e21ae6494a.jpg
# counter -> 7938 350529848_9569a3bcbc.jpg
# type .jpg
# 350529848_9569a3bcbc.jpg
# counter -> 7939 3457364788_3514a52091.jpg
# type .jpg
# 3457364788_3514a52091.jpg
# counter -> 7940 118309463_a532b75be9.jpg
# type .jpg
# 118309463_a532b75be9.jpg
# counter -> 7941 1402843760_d30f1dbf0f.jpg
# type .jpg
# 1402843760_d30f1dbf0f.jpg
# counter -> 7942 1034276567_49bb87c51c.jpg
# type .jpg
# 1034276567_49bb87c51c.jpg
# counter -> 7943 391020801_aaaae1e42b.jpg
# type .jpg
# 391020801_aaaae1e42b.jpg
# counter -> 7944 3204712107_5a06a81002.jpg
# type .jpg
# 3204712107_5a06a81002.jpg
# counter -> 7945 1731546544_9fbf14617b.jpg
# type .jpg
# 1731546544_9fbf14617b.jpg
# counter -> 7946 3094064787_aed1666fc9.jpg
# type .jpg
# 3094064787_aed1666fc9.jpg
# counter -> 7947 2043427251_83b746da8e.jpg
# type .jpg
# 2043427251_83b746da8e.jpg
# counter -> 7948 127450902_533ceeddfc.jpg
# type .jpg
# 127450902_533ceeddfc.jpg
# counter -> 7949 247704641_d883902277.jpg
# type .jpg
# 247704641_d883902277.jpg
# counter -> 7950 2559114800_17310f3015.jpg
# type .jpg
# 2559114800_17310f3015.jpg
# counter -> 7951 2558312618_13d362df66.jpg
# type .jpg
# 2558312618_13d362df66.jpg
# counter -> 7952 3293751640_d81a6f3a0c.jpg
# type .jpg
# 3293751640_d81a6f3a0c.jpg
# counter -> 7953 246508774_1e9885f1b7.jpg
# type .jpg
# 246508774_1e9885f1b7.jpg
# counter -> 7954 2652522323_9218afd8c2.jpg
# type .jpg
# 2652522323_9218afd8c2.jpg
# counter -> 7955 3084011664_76d37c6559.jpg
# type .jpg
# 3084011664_76d37c6559.jpg
# counter -> 7956 241347700_ef2451d256.jpg
# type .jpg
# 241347700_ef2451d256.jpg
# counter -> 7957 2944836001_b38b516286.jpg
# type .jpg
# 2944836001_b38b516286.jpg
# counter -> 7958 222369445_5b6af347dd.jpg
# type .jpg
# 222369445_5b6af347dd.jpg
# counter -> 7959 1670592963_39731a3dac.jpg
# type .jpg
# 1670592963_39731a3dac.jpg
# counter -> 7960 408233586_f2c1be3ce1.jpg
# type .jpg
# 408233586_f2c1be3ce1.jpg
# counter -> 7961 2687529141_edee32649e.jpg
# type .jpg
# 2687529141_edee32649e.jpg
# counter -> 7962 2148916767_644ea6a7fa.jpg
# type .jpg
# 2148916767_644ea6a7fa.jpg
# counter -> 7963 3124838157_7ef96745b7.jpg
# type .jpg
# 3124838157_7ef96745b7.jpg
# counter -> 7964 106490881_5a2dd9b7bd.jpg
# type .jpg
# 106490881_5a2dd9b7bd.jpg
# counter -> 7965 3205754736_32c29b5208.jpg
# type .jpg
# 3205754736_32c29b5208.jpg
# counter -> 7966 422763475_0bc814dac6.jpg
# type .jpg
# 422763475_0bc814dac6.jpg
# counter -> 7967 1253275679_e955fb7304.jpg
# type .jpg
# 1253275679_e955fb7304.jpg
# counter -> 7968 3557295488_600d387347.jpg
# type .jpg
# 3557295488_600d387347.jpg
# counter -> 7969 390987167_2d5905b459.jpg
# type .jpg
# 390987167_2d5905b459.jpg
# counter -> 7970 248994078_a9257f448b.jpg
# type .jpg
# 248994078_a9257f448b.jpg
# counter -> 7971 3042380610_c5ea61eef8.jpg
# type .jpg
# 3042380610_c5ea61eef8.jpg
# counter -> 7972 2346401538_f5e8da66fc.jpg
# type .jpg
# 2346401538_f5e8da66fc.jpg
# counter -> 7973 2786299623_a3c48bd318.jpg
# type .jpg
# 2786299623_a3c48bd318.jpg
# counter -> 7974 3532782283_341f0381a3.jpg
# type .jpg
# 3532782283_341f0381a3.jpg
# counter -> 7975 3146937399_8c046b7b1a.jpg
# type .jpg
# 3146937399_8c046b7b1a.jpg
# counter -> 7976 3513265399_a32e8cfd18.jpg
# type .jpg
# 3513265399_a32e8cfd18.jpg
# counter -> 7977 2916009941_34a0013803.jpg
# type .jpg
# 2916009941_34a0013803.jpg
# counter -> 7978 2249865945_f432c8e5da.jpg
# type .jpg
# 2249865945_f432c8e5da.jpg
# counter -> 7979 3393343330_b13df4d8ec.jpg
# type .jpg
# 3393343330_b13df4d8ec.jpg
# counter -> 7980 2856456013_335297f587.jpg
# type .jpg
# 2856456013_335297f587.jpg
# counter -> 7981 2396746868_0727e06983.jpg
# type .jpg
# 2396746868_0727e06983.jpg
# counter -> 7982 2968693931_52d161b8e7.jpg
# type .jpg
# 2968693931_52d161b8e7.jpg
# counter -> 7983 3126225245_96cd2c053f.jpg
# type .jpg
# 3126225245_96cd2c053f.jpg
# counter -> 7984 911795495_342bb15b97.jpg
# type .jpg
# 911795495_342bb15b97.jpg
# counter -> 7985 693164706_9624582e69.jpg
# type .jpg
# 693164706_9624582e69.jpg
# counter -> 7986 2046778775_0dd7cac6ab.jpg
# type .jpg
# 2046778775_0dd7cac6ab.jpg
# counter -> 7987 2924884899_f512c84332.jpg
# type .jpg
# 2924884899_f512c84332.jpg
# counter -> 7988 2342478660_faef1afea8.jpg
# type .jpg
# 2342478660_faef1afea8.jpg
# counter -> 7989 2208055895_37cd8e1edf.jpg
# type .jpg
# 2208055895_37cd8e1edf.jpg
# counter -> 7990 3434526008_02359881a0.jpg
# type .jpg
# 3434526008_02359881a0.jpg
# counter -> 7991 2969380952_9f1eb7f93b.jpg
# type .jpg
# 2969380952_9f1eb7f93b.jpg
# counter -> 7992 3208032657_27b9d6c4f3.jpg
# type .jpg
# 3208032657_27b9d6c4f3.jpg
# counter -> 7993 3143765063_a7761b16d3.jpg
# type .jpg
# 3143765063_a7761b16d3.jpg
# counter -> 7994 2295216243_0712928988.jpg
# type .jpg
# 2295216243_0712928988.jpg
# counter -> 7995 1917203130_fcaff8b10e.jpg
# type .jpg
# 1917203130_fcaff8b10e.jpg
# counter -> 7996 229951087_4c20600c32.jpg
# type .jpg
# 229951087_4c20600c32.jpg
# counter -> 7997 3461106572_920c8c0112.jpg
# type .jpg
# 3461106572_920c8c0112.jpg
# counter -> 7998 2780105274_52360c4cca.jpg
# type .jpg
# 2780105274_52360c4cca.jpg
# counter -> 7999 133189853_811de6ab2a.jpg
# type .jpg
# 133189853_811de6ab2a.jpg
# counter -> 8000 2854234756_8c0e472f51.jpg
# type .jpg
# 2854234756_8c0e472f51.jpg
# counter -> 8001 2534652796_c8a23288ab.jpg
# type .jpg
# 2534652796_c8a23288ab.jpg
# counter -> 8002 3208188198_2b271d2a2e.jpg
# type .jpg
# 3208188198_2b271d2a2e.jpg
# counter -> 8003 3636632926_09f39f2629.jpg
# type .jpg
# 3636632926_09f39f2629.jpg
# counter -> 8004 2900274587_f2cbca4c58.jpg
# type .jpg
# 2900274587_f2cbca4c58.jpg
# counter -> 8005 3409740108_1505489537.jpg
# type .jpg
# 3409740108_1505489537.jpg
# counter -> 8006 3662871327_b128d25f04.jpg
# type .jpg
# 3662871327_b128d25f04.jpg
# counter -> 8007 2272548482_0b4aec5cdd.jpg
# type .jpg
# 2272548482_0b4aec5cdd.jpg
# counter -> 8008 3475005101_6f6e437459.jpg
# type .jpg
# 3475005101_6f6e437459.jpg
# counter -> 8009 3665987581_5e6b0a65f2.jpg
# type .jpg
# 3665987581_5e6b0a65f2.jpg
# counter -> 8010 3228069008_edb2961fc4.jpg
# type .jpg
# 3228069008_edb2961fc4.jpg
# counter -> 8011 1884065356_c6c34b4568.jpg
# type .jpg
# 1884065356_c6c34b4568.jpg
# counter -> 8012 3116731299_6139b25c18.jpg
# type .jpg
# 3116731299_6139b25c18.jpg
# counter -> 8013 2485467050_1d5e2696d4.jpg
# type .jpg
# 2485467050_1d5e2696d4.jpg
# counter -> 8014 3212085754_35fdc9ccaa.jpg
# type .jpg
# 3212085754_35fdc9ccaa.jpg
# counter -> 8015 3215108916_0473007b47.jpg
# type .jpg
# 3215108916_0473007b47.jpg
# counter -> 8016 1117972841_2b9261f95f.jpg
# type .jpg
# 1117972841_2b9261f95f.jpg
# counter -> 8017 2698666984_13e17236ae.jpg
# type .jpg
# 2698666984_13e17236ae.jpg
# counter -> 8018 2208310655_a3d83080c5.jpg
# type .jpg
# 2208310655_a3d83080c5.jpg
# counter -> 8019 3421706363_a3e22a4908.jpg
# type .jpg
# 3421706363_a3e22a4908.jpg
# counter -> 8020 3100442775_6e2659b973.jpg
# type .jpg
# 3100442775_6e2659b973.jpg
# counter -> 8021 3135826945_f7c741e5b7.jpg
# type .jpg
# 3135826945_f7c741e5b7.jpg
# counter -> 8022 3357708906_fb3a54dd78.jpg
# type .jpg
# 3357708906_fb3a54dd78.jpg
# counter -> 8023 3148193539_de9dd48fc8.jpg
# type .jpg
# 3148193539_de9dd48fc8.jpg
# counter -> 8024 3432637363_3ba357e2da.jpg
# type .jpg
# 3432637363_3ba357e2da.jpg
# counter -> 8025 1752454466_723790dbd6.jpg
# type .jpg
# 1752454466_723790dbd6.jpg
# counter -> 8026 1465666502_de289b3b9c.jpg
# type .jpg
# 1465666502_de289b3b9c.jpg
# counter -> 8027 2661437618_ca7a15f3cb.jpg
# type .jpg
# 2661437618_ca7a15f3cb.jpg
# counter -> 8028 3524436870_7670df68e8.jpg
# type .jpg
# 3524436870_7670df68e8.jpg
# counter -> 8029 720208977_f44c2bba5b.jpg
# type .jpg
# 720208977_f44c2bba5b.jpg
# counter -> 8030 3624676866_8f6d0efcc9.jpg
# type .jpg
# 3624676866_8f6d0efcc9.jpg
# counter -> 8031 410413536_11f1127c46.jpg
# type .jpg
# 410413536_11f1127c46.jpg
# counter -> 8032 2710416789_555180e399.jpg
# type .jpg
# 2710416789_555180e399.jpg
# counter -> 8033 3269661567_faf190885a.jpg
# type .jpg
# 3269661567_faf190885a.jpg
# counter -> 8034 3133044777_8cc930a4ec.jpg
# type .jpg
# 3133044777_8cc930a4ec.jpg
# counter -> 8035 2800990525_a1f8427272.jpg
# type .jpg
# 2800990525_a1f8427272.jpg
# counter -> 8036 514222303_cb98584536.jpg
# type .jpg
# 514222303_cb98584536.jpg
# counter -> 8037 3477315700_52a4d740a5.jpg
# type .jpg
# 3477315700_52a4d740a5.jpg
# counter -> 8038 3437107047_715c60e9c8.jpg
# type .jpg
# 3437107047_715c60e9c8.jpg
# counter -> 8039 2594459477_8ca0121a9a.jpg
# type .jpg
# 2594459477_8ca0121a9a.jpg
# counter -> 8040 3401333624_4b6af8c1d7.jpg
# type .jpg
# 3401333624_4b6af8c1d7.jpg
# counter -> 8041 3270691950_88583c3524.jpg
# type .jpg
# 3270691950_88583c3524.jpg
# counter -> 8042 3081363964_d404eccae8.jpg
# type .jpg
# 3081363964_d404eccae8.jpg
# counter -> 8043 2097403787_77a154f5b9.jpg
# type .jpg
# 2097403787_77a154f5b9.jpg
# counter -> 8044 1904112245_549e47c8aa.jpg
# type .jpg
# 1904112245_549e47c8aa.jpg
# counter -> 8045 1932161768_996eadac87.jpg
# type .jpg
# 1932161768_996eadac87.jpg
# counter -> 8046 2568656919_6e49d2a82b.jpg
# type .jpg
# 2568656919_6e49d2a82b.jpg
# counter -> 8047 3442622076_c3abe955e5.jpg
# type .jpg
# 3442622076_c3abe955e5.jpg
# counter -> 8048 530888330_a18343e38d.jpg
# type .jpg
# 530888330_a18343e38d.jpg
# counter -> 8049 1827560917_c8d3c5627f.jpg
# type .jpg
# 1827560917_c8d3c5627f.jpg
# counter -> 8050 1526181215_c1a94325ae.jpg
# type .jpg
# 1526181215_c1a94325ae.jpg
# counter -> 8051 375384566_254c2362d4.jpg
# type .jpg
# 375384566_254c2362d4.jpg
# counter -> 8052 1252787177_4b08625897.jpg
# type .jpg
# 1252787177_4b08625897.jpg
# counter -> 8053 3148647065_2d6cd88cf6.jpg
# type .jpg
# 3148647065_2d6cd88cf6.jpg
# counter -> 8054 439569646_c917f1bc78.jpg
# type .jpg
# 439569646_c917f1bc78.jpg
# counter -> 8055 3168123064_d1983b8f92.jpg
# type .jpg
# 3168123064_d1983b8f92.jpg
# counter -> 8056 3354414391_a3908bd4ff.jpg
# type .jpg
# 3354414391_a3908bd4ff.jpg
# counter -> 8057 2609900643_c07bcb0bae.jpg
# type .jpg
# 2609900643_c07bcb0bae.jpg
# counter -> 8058 2325386353_1f1a05e1ce.jpg
# type .jpg
# 2325386353_1f1a05e1ce.jpg
# counter -> 8059 435739506_2daf7f4887.jpg
# type .jpg
# 435739506_2daf7f4887.jpg
# counter -> 8060 3358380484_b99b48f0c9.jpg
# type .jpg
# 3358380484_b99b48f0c9.jpg
# counter -> 8061 3670918456_68631d362a.jpg
# type .jpg
# 3670918456_68631d362a.jpg
# counter -> 8062 3439982121_0afc6d5973.jpg
# type .jpg
# 3439982121_0afc6d5973.jpg
# counter -> 8063 3537920947_6c5a956f47.jpg
# type .jpg
# 3537920947_6c5a956f47.jpg
# counter -> 8064 536537638_f5ee42410b.jpg
# type .jpg
# 536537638_f5ee42410b.jpg
# counter -> 8065 180094434_b0f244832d.jpg
# type .jpg
# 180094434_b0f244832d.jpg
# counter -> 8066 3134385454_4f1d55333f.jpg
# type .jpg
# 3134385454_4f1d55333f.jpg
# counter -> 8067 3429641260_2f035c1813.jpg
# type .jpg
# 3429641260_2f035c1813.jpg
# counter -> 8068 3535768334_a3924bcccd.jpg
# type .jpg
# 3535768334_a3924bcccd.jpg
# counter -> 8069 528500099_7be78a0ca5.jpg
# type .jpg
# 528500099_7be78a0ca5.jpg
# counter -> 8070 2884252132_5d8e776893.jpg
# type .jpg
# 2884252132_5d8e776893.jpg
# counter -> 8071 480607352_65614ab348.jpg
# type .jpg
# 480607352_65614ab348.jpg
# counter -> 8072 2963573792_dd51b5fbfb.jpg
# type .jpg
# 2963573792_dd51b5fbfb.jpg
# counter -> 8073 3286620180_4b00e93e8e.jpg
# type .jpg
# 3286620180_4b00e93e8e.jpg
# counter -> 8074 3172280520_e7655fb596.jpg
# type .jpg
# 3172280520_e7655fb596.jpg
# counter -> 8075 3672057606_cb6393dbd9.jpg
# type .jpg
# 3672057606_cb6393dbd9.jpg
# counter -> 8076 3732728142_86364a706e.jpg
# type .jpg
# 3732728142_86364a706e.jpg
# counter -> 8077 990890291_afc72be141.jpg
# type .jpg
# 990890291_afc72be141.jpg
# counter -> 8078 1155138244_859fd6e079.jpg
# type .jpg
# 1155138244_859fd6e079.jpg
# counter -> 8079 3190677999_60bbd330fd.jpg
# type .jpg
# 3190677999_60bbd330fd.jpg
# counter -> 8080 3532539748_795d16ef07.jpg
# type .jpg
# 3532539748_795d16ef07.jpg
# counter -> 8081 1897025969_0c41688fa6.jpg
# type .jpg
# 1897025969_0c41688fa6.jpg
# counter -> 8082 405615014_03be7ef618.jpg
# type .jpg
# 405615014_03be7ef618.jpg
# counter -> 8083 1557451043_f5c91ff6f4.jpg
# type .jpg
# 1557451043_f5c91ff6f4.jpg
# counter -> 8084 407678652_1f475acd65.jpg
# type .jpg
# 407678652_1f475acd65.jpg
# counter -> 8085 3101796900_59c15e0edc.jpg
# type .jpg
# 3101796900_59c15e0edc.jpg
# counter -> 8086 3322200641_c2e51ff37b.jpg
# type .jpg
# 3322200641_c2e51ff37b.jpg
# counter -> 8087 1280320287_b2a4b9b7bd.jpg
# type .jpg
# 1280320287_b2a4b9b7bd.jpg
# counter -> 8088 2070831281_dc04b3e15d.jpg
# type .jpg
# 2070831281_dc04b3e15d.jpg
# counter -> 8089 3287963317_186491ee78.jpg
# type .jpg
# 3287963317_186491ee78.jpg
# counter -> 8090 308307853_5a51fbdecc.jpg
# type .jpg
# 308307853_5a51fbdecc.jpg
# extracted features : 8091

# %%
import pandas as pd
import nltk
import re
from nltk.stem import WordNetLemmatizer

# %%
lemma = WordNetLemmatizer()

def load_decriptions(doc):
    mapping = dict()
    
    for i in range(len(doc)):
        image_id = doc['image_id'][i]
        image_desc = doc['desc'][i]
        
        if image_id not in mapping:
            mapping[image_id] = list()
        
        mapping[image_id].append(image_desc)
        
    return mapping

def clean_text(desc):
    
    # clean punctuation
    desc = re.sub(r'[^\w\s]' ,'', desc)
    
    # tokenize the words
    desc = desc.split()
    
    # convert to lower case
    desc = [token.lower() for token in desc]
    
    # lemmatization
    desc = [lemma.lemmatize(token) for token in desc]
    
    # remove numerical values
    desc = [token for token in desc if token.isalpha()]
    
    # join whole token
    desc = ' '.join(desc)
    
    return desc

# %%
# convert loaded descriptions into vocablury
def to_vocabluary(descriptions):
    all_desc = set()
    
    for key in descriptions.keys():
        [all_desc.update(d.split()) for d in descriptions[key]]
        
    return all_desc

def save_descriptions(descriptions , filename):
    lines = list()
    
    for key , desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key +' '+ desc)
            
    data = '\n'.join(lines)
    file = open(filename , 'w')
    file.write(data)
    file.close()

# %%
descriptions = pd.read_csv("/content/flickr8k/captions.txt",delimiter  = ',')

# %%
descriptions.columns = ['image_id','desc']

# %%
descriptions.head(5)
# Out:
#                     image_id  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                                 desc
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
import nltk 
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
descriptions['desc'] = descriptions['desc'].apply(lambda x : clean_text(str(x)))

# %%
descriptions
# Out:
#                         image_id  \
# 0      1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg
# 3      1000268201_693b08cb0e.jpg
# 4      1000268201_693b08cb0e.jpg
# ...                          ...
# 40450   997722733_0cb5439472.jpg
# 40451   997722733_0cb5439472.jpg
# 40452   997722733_0cb5439472.jpg
# 40453   997722733_0cb5439472.jpg
# 40454   997722733_0cb5439472.jpg
#
#                                                     desc
# 0      a child in a pink dress is climbing up a set o...
# 1                    a girl going into a wooden building
# 2         a little girl climbing into a wooden playhouse
# 3      a little girl climbing the stair to her playhouse
# 4      a little girl in a pink dress going into a woo...
# ...                                                  ...
# 40450            a man in a pink shirt climb a rock face
# 40451             a man is rock climbing high in the air
# 40452  a person in a red shirt climbing up a rock fac...
# 40453                      a rock climber in a red shirt
# 40454    a rock climber practice on a rock climbing wall
#
# [40455 rows x 2 columns]

# %%
desc_map = load_decriptions(descriptions) # image name with Its captions

# %%
desc_map
# Out:
# {'1000268201_693b08cb0e.jpg': ['a child in a pink dress is climbing up a set of stair in an entry way',
#   'a girl going into a wooden building',
#   'a little girl climbing into a wooden playhouse',
#   'a little girl climbing the stair to her playhouse',
#   'a little girl in a pink dress going into a wooden cabin'],
#  '1001773457_577c3a7d70.jpg': ['a black dog and a spotted dog are fighting',
#   'a black dog and a tricolored dog playing with each other on the road',
#   'a black dog and a white dog with brown spot are staring at each other in the street',
#   'two dog of different breed looking at each other on the road',
#   'two dog on pavement moving toward each other'],
#  '1002674143_1b742ab4b8.jpg': ['a little girl covered in paint sits in front of a painted rainbow with her hand in a bowl',
#   'a little girl is sitting in front of a large painted rainbow',
#   'a small girl in the grass play with fingerpaint in front of a white canvas with a rainbow on it',
#   'there is a girl with pigtail sitting in front of a rainbow painting',
#   'young girl with pigtail painting outside in the grass'],
#  '1003163366_44323f5815.jpg': ['a man lay on a bench while his dog sits by him',
#   'a man lay on the bench to which a white dog is also tied',
#   'a man sleeping on a bench outside with a white and black dog sitting next to him',
#   'a shirtless man lie on a park bench with his dog',
#   'man laying on bench holding leash of dog sitting on ground'],
#  '1007129816_e794419615.jpg': ['a man in an orange hat starring at something',
#   'a man wear an orange hat and glass',
#   'a man with gauge and glass is wearing a blitz hat',
#   'a man with glass is wearing a beer can crocheted hat',
#   'the man with pierced ear is wearing glass and an orange hat'],
#  '1007320043_627395c3d8.jpg': ['a child playing on a rope net',
#   'a little girl climbing on red roping',
#   'a little girl in pink climb a rope bridge at the park',
#   'a small child grip onto the red rope at the playground',
#   'the small child climb on a red rope on a playground'],
#  '1009434119_febe49276a.jpg': ['a black and white dog is running in a grassy garden surrounded by a white fence',
#   'a black and white dog is running through the grass',
#   'a boston terrier is running in the grass',
#   'a boston terrier is running on lush green grass in front of a white fence',
#   'a dog run on the green grass near a wooden fence'],
#  '1012212859_01547e3f17.jpg': ['a dog shake it head near the shore a red ball next to it',
#   'a white dog shake on the edge of a beach with an orange ball',
#   'dog with orange ball at foot stand on shore shaking off water',
#   'white dog playing with a red ball on the shore near the water',
#   'white dog with brown ear standing near water with head turned to one side'],
#  '1015118661_980735411b.jpg': ['a boy smile in front of a stony wall in a city',
#   'a little boy is standing on the street while a man in overall is working on a stone wall',
#   'a young boy run aross the street',
#   'a young child is walking on a stone paved street with a metal pole and a man behind him',
#   'smiling boy in white shirt and blue jean in front of rock wall with man in overall behind him'],
#  '1015584366_dfcec3c85a.jpg': ['a black dog leap over a log',
#   'a grey dog is leaping over a fallen tree',
#   'a large black dog leap a fallen log',
#   'a mottled black and grey dog in a blue collar jumping over a fallen tree',
#   'the black dog jumped the tree stump'],
#  '101654506_8eb26cfb60.jpg': ['a brown and white dog is running through the snow',
#   'a dog is running in the snow',
#   'a dog running through snow',
#   'a white and brown dog is running through a snow covered field',
#   'the white and brown dog is running over the surface of the snow'],
#  '101669240_b2d3e7f17b.jpg': ['a man in a hat is displaying picture next to a skier in a blue hat',
#   'a man ski past another man displaying painting in the snow',
#   'a person wearing ski looking at framed picture set up in the snow',
#   'a skier look at framed picture in the snow next to tree',
#   'man on ski looking at artwork for sale in the snow'],
#  '1016887272_03199f49c4.jpg': ['a collage of one person climbing a cliff',
#   'a group of people are rock climbing on a rock climbing wall',
#   'a group of people climbing a rock while one man belay',
#   'seven climber are ascending a rock face whilst another man stand holding the rope',
#   'several climber in a row are climbing the rock while the man in red watch and hold the line'],
#  '1019077836_6fc9b15408.jpg': ['a brown dog chase the water from a sprinkler on a lawn',
#   'a brown dog play with the hose',
#   'a brown dog running on a lawn near a garden hose',
#   'a dog is playing with a hose',
#   'large brown dog running away from the sprinkler in the grass'],
#  '1019604187_d087bf9a5f.jpg': ['a dog prepares to catch a thrown object in a field with nearby car',
#   'a white dog is about to catch a yellow ball in it mouth',
#   'a white dog is about to catch a yellow dog toy',
#   'a white dog is ready to catch a yellow ball flying through the air',
#   'a white dog running after a yellow ball'],
#  '1020651753_06077ec457.jpg': ['a black and white dog jumping in the air to get a toy',
#   'a black and white dog jump up towards a yellow toy',
#   'a dog leap to catch a ball in a field',
#   'a white dog is trying to catch a ball in midair over a grassy field',
#   'the white dog is playing in a green field with a yellow toy'],
#  '1022454332_6af2c1449a.jpg': ['a child and a woman are at water edge in a big city',
#   'a large lake with a lone duck swimming in it with several people around the edge of it',
#   'a little boy at a lake watching a duck',
#   'a young boy wave his hand at the duck in the water surrounded by a green park',
#   'two people are at the edge of a lake facing the water and the city skyline'],
#  '1022454428_b6b660a67b.jpg': ['a couple and an infant being held by the male sitting next to a pond with a near by stroller',
#   'a couple sit on the grass with a baby and stroller',
#   'a couple with their newborn baby sitting under a tree facing a lake',
#   'a man and woman care for an infant along the side of a body of water',
#   'couple with a baby sit outdoors next to their stroller'],
#  '1022975728_75515238d8.jpg': ['a black dog running in the surf',
#   'a black lab with tag frolicks in the water',
#   'a dog splash in the water',
#   'the black dog run through the water',
#   'this is a black dog splashing in the water'],
#  '102351840_323e3de834.jpg': ['a man drilling a hole in the ice',
#   'a man is drilling through the frozen ice of a pond',
#   'a person in the snow drilling a hole in the ice',
#   'a person standing on a frozen lake',
#   'two men are ice fishing'],
#  '1024138940_f1fefbdce1.jpg': ['two different breed of brown and white dog play on the beach',
#   'two dog are making a turn on a soft sand beach',
#   'two dog playing in the sand at the beach',
#   'two dog playing together on a beach',
#   'two large tan dog play along a sandy beach'],
#  '102455176_5f8ead62d5.jpg': ['a man us ice pick and crampon to scale ice',
#   'an ice climber in a blue jacket and black pant is scaling a frozen ice wall',
#   'an ice climber scaling a frozen waterfall',
#   'a person in blue and red ice climbing with two pick',
#   'climber climbing an ice wall'],
#  '1026685415_0431cbf574.jpg': ['a black dog carry a green toy in his mouth a he walk through the grass',
#   'a black dog carrying something through the grass',
#   'a black dog ha a blue toy in it mouth',
#   'a dog in grass with a blue item in his mouth',
#   'a wet black dog is carrying a green toy through the grass'],
#  '1028205764_7e8df9a2ea.jpg': ['a man and a baby are in a yellow kayak on water',
#   'a man and a little boy in blue life jacket are rowing a yellow canoe',
#   'a man and child kayak through gentle water',
#   'a man and young boy ride in a yellow kayak',
#   'man and child in yellow kayak'],
#  '1030985833_b0902ea560.jpg': ['a black dog and a brown dog are jumping up to catch a red toy',
#   'a black dog and a brown dog play with a red toy on a courtyard',
#   'a brown and black lab are outside and the black lab is catching a toy in it mouth',
#   'black dog snap at red and black object a brown dog lunge',
#   'the chocolate lab jump too late to get the toy a the black lab capture it in the driveway'],
#  '103106960_e8a41d64f8.jpg': ['a boy with a stick kneeling in front of a goalie net',
#   'a child in a red jacket playing street hockey guarding a goal',
#   'a young kid playing the goalie in a hockey rink',
#   'a young male kneeling in front of a hockey goal with a hockey stick in his right hand',
#   'hockey goalie boy in red jacket crouch by goal with stick'],
#  '103195344_5d2dc613a3.jpg': ['a man in black is sitting next to a modern art structure in front of a glass building',
#   'a man sits and read a newspaper by a sculpture outside of an office building',
#   'a man sits near a large statue',
#   'a man sitting in front of a metal sculpture in front of a building',
#   'the man with the backpack is sitting in a building courtyard in front of an art sculpture reading'],
#  '103205630_682ca7285b.jpg': ['a tent is being set up on the ice',
#   'two men are about to enter an ice fishing tent on a snow covered lake',
#   'two men setting up a blue ice fishing hut on an iced over lake',
#   'two men standing on an ice looking into something covered with a blue tarp',
#   'two people standing outside a blue tent structure on a snowy surface'],
#  '1032122270_ea6f0beedb.jpg': ['a woman crouch near three dog in a field',
#   'three dog are playing on grassy hill with a blue sky',
#   'three dog are standing in the grass and a person is sitting next to them',
#   'three dog on a grassy hill',
#   'three dog stand in a grassy field while a person kneel nearby'],
#  '1032460886_4a598ed535.jpg': ['a man is standing in front of a skyscraper',
#   'a man stand in front of a skyscraper',
#   'a man stand in front of a very tall building',
#   'behind the man in a red shirt stand a large skyscraper',
#   'there is a skyscraper in the distance with a man walking in front of the camera'],
#  '1034276567_49bb87c51c.jpg': ['a boy bite hard into a treat while he sits outside',
#   'a child biting into a baked good',
#   'a small boy putting something in his mouth with both hand',
#   'the boy eats his food outside at the table',
#   'the boy is eating pizza over a tin dish'],
#  '104136873_5b5d41be75.jpg': ['people sit on the mountainside and check out the view',
#   'three people are on a hilltop overlooking a green valley',
#   'three people hang out on top of a big hill',
#   'three people overlook a green valley',
#   'three people rest on a ledge above the moutains'],
#  '1042020065_fb3d3ba5ba.jpg': ['a boy in a green shirt is looking down at many inflatable boat',
#   'a boy in a green shirt watch kayakers',
#   'a boy look over a railing at the many boat and raft below in the water',
#   'a young boy overlooking a crowd of inflatable boat',
#   'a young boy wearing a jersey look down over a ledge at many boat in the water'],
#  '1042590306_95dea0916c.jpg': ['a man and woman pose for the camera while another man look on',
#   'a man is holding the hand of a woman up to his mouth in front of some building while another man look on',
#   'a multiracial couple posing for a picture',
#   'asian man and blond woman holding hand outdoors man in background watch',
#   'guy in blue shirt biting hand of girl in black striped jacket while another guy watch'],
#  '1045521051_108ebc19be.jpg': ['a person eats takeout while watching a small television',
#   'a person sits on the floor and eats in front of a television',
#   'a television with a picture of a girl on it',
#   'a young man sits on the floor by the television with a fast food meal in front of him',
#   'someone is laying in front of the tv eating food'],
#  '1048710776_bb5b0a5c7c.jpg': ['a couple of several people sitting on a ledge overlooking the beach',
#   'a group of people sit on a wall at the beach',
#   'a group of teen sit on a wall by a beach',
#   'crowd of people at the beach',
#   'several young people sitting on a rail above a crowded beach'],
#  '1052358063_eae6744153.jpg': ['a boy take a jump on his skateboard while another boy with a skateboard watch',
#   'a child is performing a skateboard trick while another child with a skateboard lean on a wall',
#   'a little boy skateboarder is doing a trick on his board while another young skateboarder watch',
#   'a young boy skateboarder jumping on a platform on a skateboard',
#   'two skateboarder'],
#  '105342180_4d4a40b47f.jpg': ['a girl paddling down a large river a seen from behind her',
#   'a woman kayaking down a river',
#   'a woman paddle a boat down a river',
#   'a woman with a paddle',
#   'a woman with a paddle sits in a boat on the water'],
#  '1053804096_ad278b25f1.jpg': ['a girl in pigtail splash in the shallow water',
#   'a girl play in the surf',
#   'a girl with pigtail is playing in the ocean by the beach',
#   'a girl with pigtail play in the water',
#   'a young girl in pigtail play in the water'],
#  '1055623002_8195a43714.jpg': ['a group of four child wearing pajama have a pillow fight',
#   'a group of kid have a pillowfight',
#   'a group of young child playing pillow fight on a bed',
#   'child having a pillow fight',
#   'four child are having a pillow fight'],
#  '1055753357_4fa3d8d693.jpg': ['two construction worker sit on a beam taking a break',
#   'two construction worker are sitting up on the side of a building',
#   'two construction worker sitting on an ibeam',
#   'two construction worker take a seat on a steel beam',
#   'two men take a break from construction'],
#  '1056249424_ef2a2e041c.jpg': ['the child are playing in the water',
#   'two boy one with a yellow and orange ball play in some water in front of a field',
#   'two boy play in a puddle',
#   'two child play with a balloon in mud on a sunny day',
#   'two kid are running and playing in some water'],
#  '1056338697_4f7d7ce270.jpg': ['a blond woman in a blue shirt appears to wait for a ride',
#   'a blond woman is on the street hailing a taxi',
#   'a woman is signaling is to traffic a seen from behind',
#   'a woman with blonde hair wearing a blue tube top is waving on the side of the street',
#   'the woman in the blue dress is holding out her arm at oncoming traffic'],
#  '1056359656_662cee0814.jpg': ['a little girl looking at a brochure on train ride',
#   'a young blond girl with a magizine in her hand',
#   'a young girl on a train read a book about train ride',
#   'a young girl sits on a seat and look at a train pamphlet',
#   'child sitting down looking at train ride brochure'],
#  '1056873310_49c665eb22.jpg': ['a brown dog is running after a black dog on a rocky shore',
#   'a brown dog is running after the black dog',
#   'two dog playing on a beach',
#   'two dog run across stone near a body of water',
#   'two dog run towards each other on a rocky area with water in the background'],
#  '1057089366_ca83da0877.jpg': ['a boy descends off the end of a high diving board',
#   'a child jump off a high diving board into the pool',
#   'a kid jump off the diving board and into the swimming pool below',
#   'a little kid is jumping off a high dive at the pool',
#   'the boy is jumping off a high diving board into the pool'],
#  '1057210460_09c6f4c6c1.jpg': ['a guy stand by a window taking his overshirt off',
#   'a man in a tank top stand next to a chrome door',
#   'a man put his shirt on near an elevator',
#   'a man stand by an elevator with his head down',
#   'the man is putting on his shirt near an elevator'],
#  '1057251835_6ded4ada9c.jpg': ['a lightcolored dog run on the beach',
#   'a small yellow dog run on a beach',
#   'a tan dog run on a sandy beach',
#   'a white dog is running down a rocky beach',
#   'light brown dog running along the beach'],
#  '106490881_5a2dd9b7bd.jpg': ['a boy in his blue swim short at the beach',
#   'a boy smile for the camera at a beach',
#   'a young boy in swimming trunk is walking with his arm outstretched on the beach',
#   'child playing on the beach',
#   'the boy is playing on the shore of an ocean'],
#  '106514190_bae200f463.jpg': ['a hiker standing high on a bluff overlooking the mountain below',
#   'a person on ski s look from hill over snow covered landscape',
#   'a skier is overlooking a snowcovered mountain',
#   'a skier is overlooking the beautiful white snow covered landscape',
#   'a skier pause on a mountaintop'],
#  '1067180831_a59dc64344.jpg': ['a black and white dog is attempting to catch a yellow and purple object in a low cut yard',
#   'a black and white dog jump after a yellow toy',
#   'a black and white dog jump to get the frisbee',
#   'a black dog is jumping up to catch a purple and green toy',
#   'a dog jump to catch a toy'],
#  '1067675215_7336a694d6.jpg': ['a man in blue short is laying in the street',
#   'a man in blue short lay down outside in a parking lot',
#   'a man laying down in middle of street during heavy traffic',
#   'a man lie on a mat in a parking lot between a brown suv and a yellow pickup with an open door',
#   'a shirtless man is laying down in the middle of a busy street'],
#  '1067790824_f3cc97239b.jpg': ['a white and black dog and a brown dog in sandy terrain',
#   'a woolly dog chase a doberman on a beach',
#   'one dog is chasing another one on the beach',
#   'the two large dog are running through sand',
#   'two large dog chasing each other at the beach'],
#  '1072153132_53d2bb1b60.jpg': ['a black and white dog catch a toy in midair',
#   'a dog and a tennis ball',
#   'a dog is jumping to catch a object thrown at it',
#   'a dog leap while chasing a tennis ball through a grassy field',
#   'a multicolor dog jumping to catch a tennis ball in a grassy field'],
#  '107318069_e9f2ef32de.jpg': ['a crowd watching air balloon at night',
#   'a group of hot air balloon lit up at night',
#   'people are watching hot air balloon in the park',
#   'people watching hot air balloon',
#   'seven large balloon are lined up at nighttime near a crowd'],
#  '1075716537_62105738b4.jpg': ['a child with a helmet on his head ride a bike',
#   'a little boy ride a bike down a hill on a miniature dirt bike',
#   'a young boy in a helmet ride a bike on the road',
#   'the little boy ride his bicycle in a race',
#   'the young boy pedal quickly at a bmx race'],
#  '107582366_d86f2d3347.jpg': ['a group of eight people are gathered around a table at night',
#   'a group of people gathered around in the dark',
#   'a group of people sit around a table outside on a porch at night',
#   'a group of people sit outdoors together at night',
#   'a group of people sitting at a table in a darkened room'],
#  '1075867198_27ca2e7efe.jpg': ['a man in a brown shirt and dark short play on the beach with his two black dog',
#   'a man in short with two black dog hold a ball throwing toy at the beach',
#   'a man playing with two black dog on the beach',
#   'a man with two dog on a beach',
#   'man at the beach with two dog'],
#  '1075881101_d55c46bece.jpg': ['a boy clean the bubble off his face',
#   'a boy covered in suds ha his face wiped clean',
#   'a boy is covered in bubble',
#   'a child covered in foam is climbing on a black inflatable ramp',
#   'a person covered in soapy water is getting cleaned off'],
#  '1077546505_a4f6c4daa9.jpg': ['a boy in blue short slide down a slide into a pool',
#   'a boy in blue swimming trunk slide down a yellow slide into a wading pool with inflatable toy floating in the water',
#   'a boy ride down a slide into a small backyard pool',
#   'a boy sliding down a slide into a pool with colorful tube',
#   'a child is falling off a slide onto colored balloon floating on a pool of water'],
#  '1077931201_1e0bb83105.jpg': ['a man in a wetsuit is throwing a baby wearing a wetsuit up into the air',
#   'a man in a wetsuit is throwing a toddler up in the air and is ready to catch him',
#   'a man in water throwing a little boy up in the air and waiting for him to come down so he can catch him',
#   'the man is in the pool and throwing a small boy into the air',
#   'while water droplet fly a man throw a little boy up in the air'],
#  '1079274291_9aaf896cc1.jpg': ['a little boy stick his tongue out for the camera another boy look on',
#   'two boy make face',
#   'two young boy are looking at the camera one smiling the other sticking his tongue out',
#   'two young boy look up at the camera a one stick out his tongue',
#   'two young boy making silly face'],
#  '10815824_2997e03d76.jpg': ['a blonde horse and a blonde girl in a black sweatshirt are staring at a fire in a barrel',
#   'a girl and her horse stand by a fire',
#   'a girl holding a horse s lead behind a fire',
#   'a man and girl and two horse are near a contained fire',
#   'two people and two horse watching a fire'],
#  '1082252566_8c79beef93.jpg': ['a bulldog a sheep dog and a boxer standing in a yard',
#   'a large brown dog is pushing a small boston terrier with his face while anouther dog watch',
#   'a large skinny dog stand near two smaller dog int the dirt',
#   'there are three dog starring at a ball in the middle of them',
#   'three dog of various size'],
#  '1082379191_ec1e53f996.jpg': ['a lady and a man with no shirt sit on a dock',
#   'a man and a woman are sitting on a dock together',
#   'a man and a woman sitting on a dock',
#   'a man and woman sitting on a deck next to a lake',
#   'a shirtless man and a woman sitting on a dock'],
#  '1084040636_97d9633581.jpg': ['a closeup of a white dog that is laying it head on it paw',
#   'a large white dog lying on the floor',
#   'a white dog ha it head on the ground',
#   'a white dog is resting it head on a tiled floor with it eye open',
#   'a white dog rest it head on the patio brick'],
#  '1084104085_3b06223afe.jpg': ['a woman in a yellow shirt and green short is climbing an artificial red wall whilst wearing a safety harness',
#   'a woman in blue short and a white shirt is indoor rock climbing',
#   'the girl is climbing a rock wall',
#   'the girl is in a harness climbing rock',
#   'woman climbing an artificial rock wall'],
#  '1087168168_70280d024a.jpg': ['a boy is jumping on an inflatable ring and a girl is watching him',
#   'a boy jumping on a water jumphouse',
#   'a teenage boy is jumping on an inflatable slide',
#   'a young boy jumping and a young girl seating in an inflatable pool',
#   'two young kid are playing in the water on an inflated toy'],
#  '1087539207_9f77ab3aaf.jpg': ['a family playing on a tractor on a beautiful day',
#   'child ride a tractor in a field',
#   'several child playing on a polaris vehicle outdoors',
#   'the child played on the four wheeler in the field',
#   'the four kid are riding on an atv in a field'],
#  '1088767354_2acee738cf.jpg': ['a woman in a red costume to the left of a man and woman standing together',
#   'a woman wearing a red costume look at two other people standing on a street',
#   'a young woman in a red sequined costume and feather stand on the sidewalk',
#   'the girl in the salmon colored bikini is standing next to two young people one is wearing a black outfit and the other is drinking pop',
#   'two young people are approached by a flamboyant young woman dressed in a red bikini and a red feathered headress'],
#  '108898978_7713be88fc.jpg': ['skiiers walking up the hill through a forest',
#   'two men are skiing in the snow in a wooded area',
#   'two people wearing yellow jacket crosscountry skiing',
#   'two skier are making their way through woodland',
#   'two skier are sliding down a trail in the wood'],
#  '108899015_bf36131a57.jpg': ['a lone skier is making their way up a mountain',
#   'skiiers at the top of a snow covered hill',
#   'two hiker climbing a snowy hill',
#   'two people are on a snowcovered mountain',
#   'two people climbing up a snowy mountain'],
#  '1089181217_ee1167f7af.jpg': ['a brown dog running down a paved pathway',
#   'a brown dog running next to grass',
#   'a dog is running down a road',
#   'a light brown dog run down a path happily',
#   'energetic brown dog running'],
#  '1089755335_0bfbfd30e6.jpg': ['a mother and child is fishing on a boardwalk at night',
#   'a woman and three child stand on a deck with a fishing pole',
#   'a woman stand with child on a boardwalk at night overlooking the sea',
#   'some people on a pier at night with one girl fishing off it',
#   'woman with three child fishing over boardwalk in the evening'],
#  '109202756_b97fcdc62c.jpg': ['a woman dressed in a blue jacket and blue jean ride a brown horse near a frozen lake and snowcovered mountain',
#   'a woman in a blue jacket ride a brown pony near water',
#   'a woman ride a horse near a frozen lake in the wintertime',
#   'a young blond woman sitting atop a brown draft horse in the snowy mountain',
#   'woman n blue jacket sits on daft horse near a frozen lake'],
#  '109202801_c6381eef15.jpg': ['two draft horse pull a cart through the snow',
#   'two golden brown horse pull a sleigh driven by a woman in a blue coat',
#   'two horse are pulling a woman in a cart',
#   'two horse pull a carriage driven by a woman over snow covered ground',
#   'two horse pulling a sled steered by a smiling blond woman'],
#  '109260216_85b0be5378.jpg': ['a person climbing down a sheer rock cliff using a rope',
#   'a person climb a tall flat mountain while holding onto a safety rope',
#   'a person is climbing a rock while holding onto a white rope',
#   'a person rappel down a steep incline',
#   'a person wearing a red vest climb up a steep rock'],
#  '109260218_fca831f933.jpg': ['people stand inside a rock dome',
#   'shaft of light in a cave show three spelunker',
#   'spelunker pose inside a rock cavern while bathed in sunlight from the surface',
#   'three people sit in a cave',
#   'three rock climber are posing on big rock'],
#  '1093716555_801aacef79.jpg': ['a group of backpacker lay on the dry ground',
#   'a group of hiker are resting on the ground in front of some mountain',
#   'people camp with the mountain in the background',
#   'several hiker rest with their gear in front of a mountain',
#   'the group of hiker is resting in front of a mountain'],
#  '1093737381_b313cd49ff.jpg': ['a woman in a blue dress stand with a chalk portrait of two child playing by a stream',
#   'a woman standing in front of a chalk drawing',
#   'a woman stand next to a chalk drawing in front of a barnlike structure',
#   'a woman stand outside near an elaborate chalk illustration',
#   'a woman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalk'],
#  '1094462889_f9966dafa6.jpg': ['a brown dog play in a deep pile of snow',
#   'a dog looking at the camera in snow',
#   'a dog run through the snow',
#   'a tan dog stand in the snow and look up',
#   'the brown dog is out in the snow'],
#  '1095476286_87d4f8664e.jpg': ['a boy jumping in a fountain',
#   'a boy play in the fountain',
#   'a child play in a fountain',
#   'a little boy playing in the water',
#   'a young boy is jumping through water being sprayed up from the ground'],
#  '1095580424_76f0aa8a3e.jpg': ['a corgi run out of a tunnel',
#   'a dog run out of a tunnel on a course',
#   'dog running out of tunnel on obstacle course',
#   'the dog is running out of the tunnel on a dog obedience course',
#   'the small brown and white dog is running out of a small tunnel'],
#  '1095590286_c654f7e5a9.jpg': ['a blond dog and a black and white dog run in a dirt field',
#   'a dog chase another dog',
#   'a yellow dog and a black and white dog are running in the dirt',
#   'two dog are running in a field',
#   'two dog running around'],
#  '1095980313_3c94799968.jpg': ['a little girl in a blue swimsuit is walking along a wooden fence next to a sandy beach',
#   'a little girl with arm outstretched is posing at the beach',
#   'a young girl walk on a railing in front of the beach',
#   'little girl in blue swimsuit standing on a handrail near a beach',
#   'the little girl in the blue bathing suit is posing at the beach'],
#  '1096097967_ac305887b4.jpg': ['a black and white dog drinking water from a water spray',
#   'a black and white dog is being soaked with a jet of water in a blue paddling pool',
#   'a dog sticking it face into the shower from a garden hose',
#   'a small white dog get sprayed by water',
#   'a white and black dog is jumping into a pool'],
#  '1096165011_cc5eb16aa6.jpg': ['a boy smile underwater',
#   'a redheaded boy swimming underwater',
#   'a small boy swimming underwater',
#   'a smiling boy swim underwater in a pool',
#   'the boy smile underwater at the pool'],
#  '1096395242_fc69f0ae5a.jpg': ['a boy with a toy gun',
#   'a little boy in orange short playing with a toy',
#   'a young boy with his foot outstretched aim a toy at the camera in front of a fireplace',
#   'a young child play with his new lightup toy',
#   'boy with toy gun pointed at the camera'],
#  '109671650_f7bbc297fa.jpg': ['a boy in yellow short is standing on top of a cliff',
#   'a boy wearing blue and yellow walking on a cliff edge',
#   'a little boy standing high in the air on a rock',
#   'a young child is standing alone on some jagged rock',
#   'child stand near edge of cliff'],
#  '109738763_90541ef30d.jpg': ['a person on a snowmobile in mid jump',
#   'a snowmobiler fly through the air',
#   'a snowmobile rider fly through the air on his or her machine in front of tall pine tree',
#   'rider jump snowmobile high in rural area',
#   'the man is up in the air'],
#  '109738916_236dc456ac.jpg': ['people are riding around on snowmobile',
#   'people pose with helmet and goggles on while riding snowmobile',
#   'several people are taking a break while on a snowmobiling ride',
#   'three people and two snowmobile',
#   'two helmeted men sit on yellow snowmobile while another man stand behind watching'],
#  '109823394_83fcb735e1.jpg': ['three people drive atvs',
#   'three people on atvs in a brown field turn their head to look at the camera',
#   'three people on atv s outside',
#   'three people on four wheel atv s in a field',
#   'three people ride their four wheeler through the field'],
#  '109823395_6fb423a90f.jpg': ['a four wheeler jumping in an empty field',
#   'a man on a four wheeler is flying through the air',
#   'a person is riding an orange atv in a large empty field',
#   'man jumping with all terrain vehicle',
#   'man on an atv catching air'],
#  '109823397_e35154645f.jpg': ['a man jump gin the air while riding an atv',
#   'a man on a fourwheeler jump near a small building',
#   'an atv is airborne over a field in front of a white structure',
#   'a person dressed in a tan jacket jump a quad over a harvested cornfield in front of a small out building',
#   'man on four wheeler in the air'],
#  '1100214449_d10861e633.jpg': ['a boy in s striped shirt is jumping in front of a water fountain',
#   'a boy is jumping off the side of a running stone water fountain in front of a building',
#   'a happy boy is jumping in front od city fountain',
#   'a little boy is jumping in front of a fountain',
#   'a little boy is playfully jumping off the side of a fountain'],
#  '1104133405_c04a00707f.jpg': ['a boy carrying a soccer ball',
#   'a boy walk with a ball tucked under his arm',
#   'a boy walk with a soccer ball near a fence',
#   'a boy wearing a white tshirt walk on the grass and carry a soccer ball',
#   'small boy carry a soccer ball on a field'],
#  '1105959054_9c3a738096.jpg': ['a child painting a picture',
#   'an artist paint cloud onto a canvas',
#   'a young girl painting a picture',
#   'a young girl with braid is painting with water color on a white paper on the wall',
#   'the child paint on a large paper with water color'],
#  '110595925_f3395c8bd6.jpg': ['a cyclist is riding a bicycle on a curved road up a hill',
#   'a man in aerodynamic gear riding a bicycle down a road around a sharp curve',
#   'a man on a mountain bike is pedaling up a hill',
#   'man bicycle up a road while cow graze on a hill nearby',
#   'the biker is riding around a curve in the road'],
#  '1107246521_d16a476380.jpg': ['a black dog jumping to catch a rope toy',
#   'a black dog playing fetch with a ball of rope',
#   'a black dog pounce to get a rope toy',
#   'a black dog running after his rope toy',
#   'a large black dog is playing in a grassy yard'],
#  '1107471216_4336c9b328.jpg': ['a little girl is holding a cine camera in front of her face',
#   'a young girl is looking through an old fashioned video camera',
#   'a young girl steady her aim with a camera',
#   'girl with rosy cheek and lip holding black toy gun',
#   'there is a kid with a gun'],
#  '1110208841_5bb6806afe.jpg': ['a black and white border collie catch a frisbee in front of an audience',
#   'a brown and white dog catch a frisbee in it mouth in front of a group of people',
#   'a brown and white dug jumping up to catch a frisbee while an audience watch',
#   'a dog jump to catch a frisbee while many people watch',
#   'an agile dog catch a frisbee while a crowd of onlooker watch closely'],
#  '1112212364_0c48235fc2.jpg': ['a baby is sitting on and playing with smooth rock',
#   'a baby is stacking rock on the beach',
#   'a small boy is playing with rock',
#   'a toddler sitting on a pile of rock holding a rock at a beach',
#   'toddler sits on a pile of rock'],
#  '111497985_38e9f88856.jpg': ['a kid rock climbing against the backdrop of a green valley',
#   'a woman in a striped shirt climb up a mountain',
#   'a young man climb a rocky hill',
#   'the person ha a striped shirt on and is holding on to a rope on a mountain',
#   'the person in the striped shirt is mountain climbing'],
#  '111537217_082a4ba060.jpg': ['a man climbing a rock wall',
#   'a man climbing the side of a cliff',
#   'a man is rock climbing',
#   'man with red shoe white shirt and grey pant climbing',
#   'the young man with the white tshirt and jean is rappeling up the rock wall'],
#  '111537222_07e56d5a30.jpg': ['a climber wearing a blue helmet and headlamp is attached to a rope on the rock face',
#   'a man climb a rocky wall',
#   'a rock climber climb a large rock',
#   'a woman in purple snakeskin pant climb a rock',
#   'person with blue helmet and purple pant is rock climbing'],
#  '1115565519_d976d4b1f1.jpg': ['a child playing with a fountain at the beach',
#   'a child play with a fountain',
#   'a girl look at a fountain that spray water',
#   'a little girl playing in water on a frog sculpture',
#   'the little girl is playing with a toy in a public fountain'],
#  '1115679311_245eff2f4b.jpg': ['a black dog is jumping over a log along a beach',
#   'a black dog run along the beach and jump over a wood barrior',
#   'a dog is running on the beach',
#   'a dog jumping over a small wall at a beach near the water',
#   'an animal is running on the beach'],
#  '111766423_4522d36e56.jpg': ['a black and white bird eating seed out of someone s hand',
#   'a black and white bird standing on a hand',
#   'a small bird sits in a person s hand and eats seed',
#   'black and white bird standing on hand of someone holding sunflower seed',
#   'the small bird is clinging to a finger of the hand holding the seed'],
#  '1117972841_2b9261f95f.jpg': ['a brown dog is running in the sand',
#   'a brown dog playing in the sand',
#   'a brown dog play at the beach',
#   'a dog is standing in the sand',
#   'a dog running fast in the sand'],
#  '1118557877_736f339752.jpg': ['a little boy stand in the surf',
#   'a small child wade through the water while being guided by another person',
#   'a young boy laugh while splashing in the ocean',
#   'a young boy wearing a colorful bathing suit splashing in the ocean',
#   'a young child splashing in water'],
#  '1119015538_e8e796281e.jpg': ['a little tan dog with large ear running through the grass',
#   'a playful dog is running through the grass',
#   'a small dog ear stick up a it run in the grass',
#   'the small dog is running across the lawn',
#   'this is a small beige dog running through a grassy field'],
#  '1119418776_58e4b93eac.jpg': ['a black and white dog is running through the field',
#   'a black brown and white dog running through a field',
#   'a brown black and white dog is running through a large field with it mouth open',
#   'a dog running in a field',
#   'a dog with it mouth open running through a field torwards the camera'],
#  '1119463452_69d4eecd08.jpg': ['a girl in a pink swimsuit in a pool',
#   'a girl swimming in a pool',
#   'a little girl in a pink bathing suit swimming in a pool',
#   'a little girl swimming in a pool',
#   'smiling little girl swimming in outdoor pool'],
#  '1121416483_c7902d0d49.jpg': ['a child is standing on her head',
#   'a little girl standing on her head',
#   'a small child doing a handstand on a bed',
#   'a young girl doe a handstand on a bed with blue sheet',
#   'the girl is upside down on a bed'],
#  '112178718_87270d9b4d.jpg': ['a guy stand in the sand with a snowboard behind him',
#   'a man hold a surfboard on the beach',
#   'a man hold his snowboard in the sand',
#   'a man with his surfboard stand in the sand',
#   'man is standing on white sand and holding a snowboard'],
#  '112243673_fd68255217.jpg': ['people on atvs and dirt bike are traveling along a worn path in a field surrounded by tree',
#   'three people are riding around on atv s and motorcycle',
#   'three people on motorbike follow a trail through dry grass',
#   'three people on two dirtbikes and one fourwheeler are riding through brown grass',
#   'three people ride offroad bike through a field surrounded by tree'],
#  '1122944218_8eb3607403.jpg': ['a baby in a white garment hold a flag with crescent moon and star',
#   'a baby is holding a small black flag with a moon and a star on it',
#   'a baby wearing a white gown wave a muslim flag',
#   'a little toddler dressed in white is smiling while a lady help him wave a flag',
#   'baby in white outfit holding black and white flag'],
#  '1124448967_2221af8dc5.jpg': ['a half naked man is sleeping on his chair outdoors',
#   'an older man sits back and relaxes on a patio outside an adobe building where many bicycle are propped',
#   'a shirtless man in a white cap relaxes in a deck chair close to three parked bicycle',
#   'man relaxing in a folding chair on the street',
#   'topless old man wearing slipper navy blue pant and a white hat while reclining in a chair outside'],
#  '1129704496_4a61441f2c.jpg': ['a brown and white and a black and white dog hauling in a floating toy from the ocean',
#   'both dog retrieve the play toy from the water',
#   'two dog in the ocean playing with a toy',
#   'two dog run through the water with a rope in their mouth',
#   'two dog tug at a chew toy in the surf'],
#  '1130017585_1a219257ac.jpg': ['there are three young people one dark haired holding a bottled drink one with head tilted back and finger in her mouth and one with spiked hair',
#   'the young people party in the street',
#   'three girl make face a one take a drink while they stand in a busy street',
#   'three woman on the street drinking and posing',
#   'three young woman pose for the camera at a parade'],
#  '1130369873_d80a1aa59c.jpg': ['a brown dog is running through neckdeep water carrying a tennis ball',
#   'a brown dog splash in the water while carrying a ball in it mouth',
#   'a brown dog swim through water outdoors with a tennis ball in it mouth',
#   'a red dog holding a ball splash through vegetation filled water',
#   'brown dog with tennis ball in mouth in water and bush'],
#  '1130401779_8c30182e3e.jpg': ['two brown dog are creating large splash a they run in a river',
#   'two brown dog in the water',
#   'two brown dog running through water',
#   'two brown dog run through the water',
#   'two dog splash through the water'],
#  '1131155939_b4b457b05e.jpg': ['a black dog run into the ocean next to a pile of seaweed',
#   'a black lav run into the water on the beach with swimmer in the distance and sea kelp in the foreground',
#   'a dog at the shore of an ocean with seaweed in foreground',
#   'a dog is running in the wave at the beach',
#   'a pile of seaweed sits on the sand behind it a big black dog is running in the water'],
#  '1131340021_83f46b150a.jpg': ['a young boy run while wearing sandal',
#   'little boy in a striped shirt and brown short is running',
#   'the little boy in a short sleeved shirt and short is running outside',
#   'the little boy is wearing a black pinstripe shirt and walking on a deck',
#   'young boy running outside on the pavement'],
#  '1131800850_89c7ffd477.jpg': ['a brown and white dog stand outside while it snow',
#   'a dog is looking at something near the water',
#   'a furry dog attempt to dry itself by shaking the water off it coat',
#   'a white and brown dog shaking it self dry',
#   'the large brown and white dog shake off water'],
#  '1131804997_177c3c0640.jpg': ['two men are sitting on the ground and going through their backpack',
#   'two men sitting in front of a railing are looking at something',
#   'two men with backpack placed in front of them sitting in front of a railing',
#   'two men with backpack are sitting on cardboard along a railing',
#   'two older men with backpack sit at a bus station'],
#  '1131932671_c8d17751b3.jpg': ['a boy is jumping on a bed',
#   'a boy jumped up from the green bed',
#   'a boy jump from one bed to another',
#   'a small child is jumping on a bed',
#   'the boy in blue short is bouncing on the bed'],
#  '1132772170_600610c5df.jpg': ['a child leaping from bed to bed behind the back of a man',
#   'a man is standing with his arm folded looking at something while the person behind him is jumping onto one of the two bed in the room',
#   'a man wearing a yellow shirt standing in the middle of two bed that a boy is jumping on in the background',
#   'a young child jumping on the bed a a man look the other way',
#   'man standing in the bedroom with little boy jumping into bed'],
#  '113678030_87a6a6e42e.jpg': ['a snowboarder sits on a slope with skier and boarder nearby',
#   'a snowboarder take a rest on the mountainside',
#   'snowboarder sitting in the snow while skier take the hill',
#   'the snowboarder is sitting down',
#   'two skier stand two sit on slope'],
#  '1138784872_69ade3f2ab.jpg': ['a girl in green walk down a city street',
#   'a small child in green clothing walk past a store opening and a woman in pink pant',
#   'a small child walk down a sidewalk',
#   'a young boy is walking in front of some store',
#   'the child in the green one piece suit is walking past a store window'],
#  '114051287_dd85625a04.jpg': ['a boy dressed in soccer attire and holding his shoe getting out of a car',
#   'a boy in a red soccer strip is holding his boot in his hand whilst stepping out of a car',
#   'a boy in glass is wearing a red shirt',
#   'a child getting out of the car wearing soccer shoe',
#   'a young boy get out of the van and prepares his shoe for wear during a soccer game'],
#  '1141718391_24164bf1b1.jpg': ['a bridge through high green plant a man and a woman on it',
#   'a man and a woman are crossing over a rope bridge with greenery all over them',
#   'a man and a woman are walking across a rope bridge',
#   'a man and a woman crossing a suspension bridge in a tropical setting',
#   'woman and man walking across wooden rope bridge with a caution sign beside it'],
#  '1141739219_2c47195e4c.jpg': ['a family gathered at a painted van',
#   'a girl climbing down from the side of a bright blue truck while others watch',
#   'a man is helping a girl step down from a colorful truck whilst a woman and three child watch',
#   'a very colorful bus is pulled off to the side of the road a it passenger load',
#   'two woman and four child standing next to a brightly painted truck'],
#  '1142283988_6b227c5231.jpg': ['a blond woman pose with a person in a pink costume',
#   'a smiling woman hold a person dressed in a pig costume',
#   'a young woman hug a young man who s wearing a pink costume',
#   'blond embracing young man in pink costume at event',
#   'two people are hugging and one is wearing a pinkhooded stretch top'],
#  '1142847777_2a0c1c2551.jpg': ['a bicyclist riding on a city street',
#   'a woman in a blue helmet and brown short ride her bike on a busy street',
#   'a woman is riding a blue bike',
#   'a woman is riding her bicycle in traffic',
#   'a woman wearing a blue helmet ride her bicycle in a parking lot'],
#  '1143373711_2e90b7b799.jpg': ['a bicycle rider is crossing a street',
#   'a bicyclist getting ready to cross a street',
#   'a biker in spandex riding on a busy street',
#   'a man in blue and white biking gear ride down a busy street',
#   'a man wearing a helmet riding his bicycle down the street'],
#  '1143882946_1898d2eeb9.jpg': ['a lady wearing a helmet holding a bike',
#   'a woman in a blue vest and a sky blue helmet stand with her bicycle in traffic',
#   'a woman in a helmet ride her bike behind a car',
#   'a woman with a helmet and a backpack walk next to her bike',
#   'woman with bike and helmet wait for traffic'],
#  '1144288288_e5c9558b6a.jpg': ['a man in short is jogging along a street with a headset',
#   'a person in blue short and wearing a walkman jog',
#   'a woman in a white shirt and blue short is wearing headphone',
#   'a woman walk on a street wearing headphone',
#   'a woman wearing a white hat and shirt is jogging down a street with a plant store on the corner'],
#  '1148238960_f8cacec2fc.jpg': ['bicyclist are standing at an intersection',
#   'bicyclist waiting at an intersection',
#   'people on bicycle waiting at an intersection',
#   'people waiting at a light on bike',
#   'three bikers stop in town'],
#  '1149179852_acad4d7300.jpg': ['a man without a shirt on is guiding a large brown horse pulling a green and yellow wagon',
#   'a shirtless man escort a horse pulling a carriage along a paved road',
#   'a shirtless man leading a horse that is pulling a carriage',
#   'shirtless man leading a small horsedrawn covered wagon down a road',
#   'the shirtless man is walking the shetland pony and carriage down the street'],
#  '114949897_490ca7eaec.jpg': ['a boy hit a ball off of a tee ball into to net',
#   'a child practice hitting a baseball into a net while two adult men watch',
#   'a man hold a net while a boy bat a ball into it',
#   'the man is holding the net for the boy playing baseball',
#   'three people put up a batting cage'],
#  '1151466868_3bc4d9580b.jpg': ['a small girl spin in the wave in the bright sun',
#   'a young girl play in shallow water',
#   'a young girl wear a shirt and short a she play in the ocean s surf',
#   'girl running through the water near the shore',
#   'the little girl splash through the water'],
#  '1153704539_542f7aa3a5.jpg': ['a girl playing trumpet in a marching band',
#   'a teenager play her trumpet on the field at a game',
#   'a young girl wearing a blue shirt marching in a band playing a trumpet',
#   'girl playing the trumpet in a marching band',
#   'girl wearing blue shirt and black short play trumped outside'],
#  '1155138244_859fd6e079.jpg': ['a girl hand out starbucks sample at a street fair',
#   'an asian girl in a green hat and apron is serving drink on a tray',
#   'a starbucks barista offering up a tray of drink',
#   'the waitress offer complimentary tea to the patron',
#   'woman dressed in a green hat and apron is holding a try full of drink sample'],
#  '115684808_cb01227802.jpg': ['three men are setting up a sledge on a snowy plain',
#   'three men loading item on a sled',
#   'three people and a sled',
#   'three people are standing in the snow preparing an ice fishing boat',
#   'three people in the snow put their gear in order'],
#  '1159574340_99ba8c3c59.jpg': ['a child jumping into a lake in a wooded area while another child play on the shore',
#   'a child jump into the water with his sneaker on',
#   'a kid jumping into a pool of water',
#   'little boy in sneaker jumping into water',
#   'the man take a leap into the water with his shoe on'],
#  '1160034462_16b38174fe.jpg': ['a elderly man in a straw hat is sitting on a bench',
#   'a elderly man sits alone on a park bench',
#   'an old man in a straw hat sits on a park bench',
#   'the old man in the brown hat is sitting on the bench',
#   'white haired man in gray sweater and a straw hat sitting on a bench under a tree'],
#  '1160441615_fe6b3c5277.jpg': ['three girl are walking across a bridge covered with wood and surrounded by tree',
#   'three girl walking along an arched garden pathway',
#   'three girl walk under an arbor on a path surrounded by tree',
#   'three woman walking through a tunnel in a park',
#   'three woman walk through a plant covered atrium hallway'],
#  '1163282319_b729b24c46.jpg': ['a girl dressed in a red top a red cap and light colored short sits on a rock outside',
#   'a little girl in a red hat and yellow flip flop sits on a rock',
#   'a little girl with a red hood and shirt is sitting with leg sprawled on a rock her mouth open',
# ...
#  '2085400856_ae09df33a7.jpg': ['a dog in the snow',
#   'a dog laying in the snow',
#   'a dog lay on the snow',
#   'a golden dog play in the snow',
#   'a red dog crouch in the snow'],
#  '2085403342_a17b0654fe.jpg': ['a child in a bright red jacket run through a pile of hay',
#   'a little girl in a red sweater and blue skirt is in the hay',
#   'a young child dance on a straw surface',
#   'the boy is running through hay at a pumpkin patch',
#   'the child is walking through straw'],
#  '2085557551_7a88d01d4e.jpg': ['a boy holding kitchen utensil and making a threatening face',
#   'a boy is pulling a wild face whilst waving cooking implement in his hand',
#   'a girl in a tan shirt holding up a fork and knife in one hand and a pot in the other',
#   'a person with cooking utility pose menacingly in a dark environment',
#   'a woman with a knife and fork grimmaces'],
#  '2085726719_a57a75dbe5.jpg': ['two girl bundled up in winter coat pose for a picture',
#   'two girl holding drink and looking at something on a cellphone',
#   'two teen girl are looking at a small electronic device while wearing winter coat',
#   'two woman dressed for cold weather in jacket and glove look at something on a cellphone screen',
#   'two young girl huddle to look at a cellphone'],
#  '2086513494_dbbcb583e7.jpg': ['a girl in a white coat take picture',
#   'a girl in a white puffy jacket take a picture',
#   'a group of people looking into their camera',
#   'asian woman in white coat take photo',
#   'the woman in the white coat is holding a camera in her hand'],
#  '2086532897_b8714f2237.jpg': ['a kayaker falling down a waterfall',
#   'a man is kayaking down a waterfall',
#   'a man on a kayak coming down a raging waterfall',
#   'a person is on a small boat and going down some very strong water current',
#   'white water rafter go through a rough spot'],
#  '2086534745_1e4ab80078.jpg': ['a man in a yellow boat paddling down rough water',
#   'a rafter in a yellow raft in a steamy white river',
#   'a yellow kayak is descending quickly down a white water rapid',
#   'kayacker riding rough current downstream',
#   'the yellow kayak is in the middle of the rapid'],
#  '2086678529_b3301c2d71.jpg': ['a girl in a purple dress smiling a she climb an indoor rock wall',
#   'a girl is in a dress',
#   'a little girl wearing a purple dress look down at the camera',
#   'a young girl climb a rock wall in a purple dress',
#   'a young girl wear a purple dress'],
#  '2087317114_cf06df5aa5.jpg': ['a mani is kayaking down some calmer rapid',
#   'a man in a small kayak is floating down the river',
#   'a man in a yellow jacket is floating on the river in a green kayak',
#   'a man smile in his blue and green kayak',
#   'a man wearing a helmet in a pyranha kayak float down some river rapid'],
#  '2087640654_1a84577a44.jpg': ['a blonde dog is digging a deep hole in the ground and it tail is up in the air',
#   'a dog half way in a hole in the ground',
#   'a dog is digging a large hole in a yard to find something',
#   'a dog is digging in the ground and half of his body is under the ground',
#   'the rear end of an animal whose front end is underground'],
#  '2088120475_d6318364f5.jpg': ['a person dressed up a a snowman is walking through a crowd of people',
#   'five cold people in the snowstorm one wearing a snowman head',
#   'people pose for a picture in the snow',
#   'three young people pose by a snowman in a red tie',
#   'two couple pose with a snowman'],
#  '2088460083_42ee8a595a.jpg': ['a broken down hummer get towed on a truck bed',
#   'a damaged vehicle is carried by a repair truck in a nighttime scene',
#   'a flat bed truck in a parking lot with an army vehicle on it bed',
#   'an old beatup jeep being towed away',
#   'dirty suv sits on the bed of a tow truck at night'],
#  '2088532947_c628e44c4a.jpg': ['the girl in the white shirt ha a bracelet on and ha her arm around the girl in the peach shirt',
#   'the two girl laid on the grass together',
#   'two little girl are laying on the grass smiling',
#   'two young girl holding each other on the grassy ground',
#   'two young girl hug each other in the grass'],
#  '2088910854_c6f8d4f5f9.jpg': ['a large man is wearing a headband with mistletoe attached to it',
#   'a man in a sweatshirt and cap wear a flower on his head',
#   'a man wearing a black knit cap with a red and white striped headband with a flower on top',
#   'an man with a black ski cap and a red and white headband look into the distance',
#   'man wearing a black hat with a christmas theme'],
#  '2089122314_40d5739aef.jpg': ['a dog running with a newspaper in it mouth',
#   'a dog run down the street carrying a newspaper',
#   'a dog with a newspaper in his mouth run down a paved path',
#   'a fluffy tricolored dog is running down the road with a paper in it mouth',
#   'an australian shepherd dog carrying a newspaper in his mouth'],
#  '2089350172_dc2cf9fcf6.jpg': ['three black dog are swimming through some murky brown water one with a yellow object in it mouth',
#   'three black dog swimming in dirty water',
#   'three dark dog swimming and one of them ha a ball',
#   'three dog are up to their neck in water',
#   'three dog swim in the water'],
#  '2089426086_7acc98a3a8.jpg': ['a girl in a hooded jacket present a cake with candle',
#   'a girl in a hood jacket hold a birthday cake with many candle',
#   'a girl in a winter coat with a birthday cake',
#   'a girl is holding a birthday cake',
#   'a young girl holding a cake with candle dressed in a heavy coat'],
#  '2089442007_6fc798548c.jpg': ['a brown dog is walking in the water',
#   'a brown dog take cautious step in the calm water with a sandy bottom',
#   'a brown dog wade in the water',
#   'a dog with red fur stand in a body of water',
#   'a large golden colored dog is walking through water'],
#  '2089539651_9e518ec7de.jpg': ['a hiker with two hiking pole stand on a hillside with a view of the city below him',
#   'a hiker with two stick is a standing on a path that is high up on a hill',
#   'a hiking man stand on a cliff overlooking a city',
#   'a man hike on a dirt path high above a city',
#   'a person holding pole is standing on a rock ledge with bush on each side overlooking mountain'],
#  '2089542487_b4c1ee7025.jpg': ['a hiker is ready to take on a rugged outdoor trail',
#   'a lone hiker on a dirt hiking trail with a hat and sunglass on with tree in the background',
#   'a man in short is hiking in a dry region',
#   'a man stop for a picture with the scenery during his hike',
#   'the man is posing for a picture in the desert wearing a green shirt and hat and holding a metal detector'],
#  '2089555297_95cf001fa7.jpg': ['a man in a hat with long sleeve and long pant stand overlooking a city',
#   'a man stand on a cliff overlooking a city',
#   'a man with a backpack and hat is standing by a high cliff where you can see for mile',
#   'hiker standing on top of a rock overlooking a town',
#   'the man wearing a backpack and a hat stand on a ledge overlooking a city'],
#  '2090327868_9f99e2740d.jpg': ['a woman a little boy and a tiny baby are standing in front of a cow statue',
#   'a woman and two small child posing in front of a large cow statue',
#   'a woman give a baby to a small child to hold a they stand in front of a cow statue',
#   'a woman stand with two child near a decorated bull statue',
#   'the woman and child are standing next to a statue of a cow'],
#  '2090339522_d30d2436f9.jpg': ['a man in a green hat is someplace up high',
#   'a man in a green hat is taking a self portrait',
#   'a man in a hat at a scenic overlook',
#   'a man wearing a green canvas hat with a distnat city in the background',
#   'man with green hate and sunglass on a high up peak'],
#  '2090386465_b6ebb7df2c.jpg': ['a woman and man in winter gear stand',
#   'three adult wearing cold weather gear',
#   'two people are wearing heavy clothing',
#   'two people in winter clothing',
#   'two woman bundled up on a snowy day'],
#  '2090387793_274ab4cf7d.jpg': ['a boy wearing black walk down the street with his hand in fist',
#   'a teenage boy dressed in black stand on a snowy street',
#   'a teenage boy wearing all black try to look tough with cheap jewelry on',
#   'a young man wearing a black hat and jacket is walking outside',
#   'punk rock teenager walk with a mean look on his face'],
#  '2090545563_a4e66ec76b.jpg': ['the boy laying face down on a skateboard is being pushed along the ground by another boy',
#   'two girl play on a skateboard in a courtyard',
#   'two people play on a long skateboard',
#   'two small child in red shirt playing on a skateboard',
#   'two young child on a skateboard going across a sidewalk'],
#  '2090723611_318031cfa5.jpg': ['dog walking in the grassy field',
#   'large fluffy grey dog standing in grass in front of a brown dog',
#   'one dog standing in some grass with his tongue hanging out and a tan dog in the background',
#   'two dog of different breed are standing in a pasture',
#   'two dog stand in the grass'],
#  '2090997177_76d482b158.jpg': ['a black dog bound across the sand',
#   'a dog walking across the desert',
#   'a short black dog is walking over a barren landscape',
#   'a small black dog running across the sand',
#   'a small black dog walk in the sand'],
#  '2091171488_c8512fec76.jpg': ['a female wearing pink glove and a brown jacket is smiling in the snow',
#   'a woman standing in the snow with people in the background',
#   'a young woman in a spring coat and purple glove stand in falling snow',
#   'a young woman look happy in winter clothes while it snow',
#   'young asian woman with pink glove stand in the snow'],
#  '2092177624_13ab757e8b.jpg': ['a boy in african clothing run across a concrete wall',
#   'a little boy with a green shirt is running on a rock ledge',
#   'an african boy in large green shirt is running barefoot along a wall',
#   'a young boy dressed in green running along a smooth stone wall near a wooded area',
#   'boy in green tunic on rock wall'],
#  '2092419948_eea8001d0f.jpg': ['a long haired man walking away beside a canal whist holding onto a railing',
#   'a man walk down a path next to a waterway',
#   'a person walk by some bluegreen water while holding a rail',
#   'a person with a long ponytail walk along a waterway under a tunnel',
#   'the man with long hair is walking along a storm drain'],
#  '2092870249_90e3f1855b.jpg': ['a man lie on a street with his head and shoulder under a parked car that is jacked up',
#   'a man look under a car on a wet street',
#   'a man work on a car',
#   'a person lie half under a car facedown',
#   'a person underneath a car with a jack'],
#  '2094323311_27d58b1513.jpg': ['a dog place his head on a man s face',
#   'a dog snuggle with a man in sunglass',
#   'a dog with a blue collar is licking a man who s wearing large tinted sunglass',
#   'a large brown dog with a blue collar is resting his chin on a man s face',
#   'an orange dog is licking a man wearing red sunglass'],
#  '2094543127_46d2f1fedf.jpg': ['a girl holding a crocodile s mouth closed',
#   'a girl is posed over a statue of a dangerous animal',
#   'a girl sits on what appears to be a crocodile',
#   'a girl sitting on top of a crocodile',
#   'a girl with red hair is sitting on a crocodile holding it jaw'],
#  '2094810449_f8df9dcdf7.jpg': ['a boy stand in the ocean lifting up his short',
#   'a child in blue short is standing ankle deep in the water',
#   'a little boy in blue short glass and a coat stand in the surf',
#   'the kid is wearing a blue jacket and standing in shallow beach water',
#   'the small child wade ankle deep in the water on the shoreline'],
#  '2095007523_591f255708.jpg': ['a baby look through his crib',
#   'a baby surrounded by some toy look out of a playpen',
#   'baby in playpen with wide eye',
#   'baby looking through playpen bar at camera',
#   'the infant is laying on it stomach in a crib looking up at the camera'],
#  '2095078658_c14ba89bc2.jpg': ['a dog run through snow in front of the wood',
#   'large dog running in snow',
#   'the dog run through the snow',
#   'the german shepherd dog is running through the snow',
#   'the german shepherd is running through the white snow'],
#  '2095435987_1b7591d214.jpg': ['a dog lying on it back in the sand',
#   'a white and brown dog roll on it back in the sand',
#   'the dog roll over to scratch it back in the sand',
#   'the white and brown dog is rolling in the sand',
#   'the white dog is on it back in the sand with paw in the air'],
#  '2095444126_201ff9f222.jpg': ['a dog is shaking off water',
#   'a dog shake his head',
#   'a dog shake off water',
#   'a dog shake off water and get contorted',
#   'the dog is shaking water off of his body'],
#  '2095478050_736c4d2d28.jpg': ['a man and a boy play music a little girl watch',
#   'a man is playing a guitar with a child playing a harmonica while three young girl watch',
#   'three child watch a man onstage playing guitar',
#   'three little girl look on a a boy play the harmonica with an adult guiutarist sitting beside him',
#   'three little girl watch a band'],
#  '209605542_ca9cc52e7b.jpg': ['a climber wearing a red headband is pulling himself up some grey rock high above some green foliage',
#   'a man in a headband climbing a rock',
#   'a man with a red headband climbing a rock cliff looming over greenery',
#   'man climbing a sheet rock face',
#   'man in red headband climbing a rock'],
#  '2096771662_984441d20d.jpg': ['a man look through his binoculars while another man hold a drink',
#   'a man with a thermos is standing next to a man who is gazing through binoculars',
#   'two men are standing together while one look through binoculars',
#   'two men look out a one is holding binoculars',
#   'two people standing next to each other with mountain in the distance'],
#  '2097398349_ff178b3f1b.jpg': ['a hiker wave to the camera a he standing in front of snowcapped mountain',
#   'a man stand on the snow near the mountain',
#   'a person pose in the snow',
#   'a person stand in the snow at the top of a mountian arm raised',
#   'a skier in the mountain'],
#  '2097403787_77a154f5b9.jpg': ['a lone person standing on some rock with large snowy mountain in the background',
#   'a man is standing on the rocky ground in front of the mountain',
#   'a man standing in front of an icy mountain',
#   'the person is standing by the water in front of the snow topped mountain',
#   'the traveller pause in front of the mountain view'],
#  '2097407245_c798e0dcaf.jpg': ['a man in a winter jacket and knit cap stand with his arm up at his side in a snow landscape',
#   'a man is standing on dirt with his hand in the air with mountain and snow behind him',
#   'a man raise his arm on rocky beach',
#   'one lone man with fist in the air with large rocky mountain in the background',
#   'man with outstretched arm standing on snowcovered rock'],
#  '2097420505_439f63c863.jpg': ['a male hiker wearing a green jacket is posing next to a large glacier',
#   'a man with a camera and an ice structure behind him',
#   'a man with a camera crouching on ice',
#   'a man with a camera kneel in front of a giant hill of snow',
#   'the mountain climber prepares to take a photo'],
#  '2097489021_ca1b9f5c3b.jpg': ['a girl in a ballet fairy costume is touched by a wand',
#   'a young girl performing the nutcracker',
#   'the little girl is standing on a stage dressed up a a pink fairy',
#   'the tiny girl dressed in a butterfly ballet costume wave her wand near a nutcracker statue',
#   'young girl waving turquiose leotard and pink tutu with wing waving wand'],
#  '2098174172_e57d86ea03.jpg': ['a hiker is posing in front of snowy mountain',
#   'a hiker is standing in before the mountain holding two walking stick',
#   'a man stand in front of snow covered mountain',
#   'a man with two ski pole stand near a mountaintop',
#   'the man wear a green hat and jacket while standing in front of a mountain'],
#  '2098418613_85a0c9afea.jpg': ['a brown chow mix dog is standing in front of a van with euro plat in the middle of a messy yard',
#   'a brown dog standing in a muddy yard',
#   'a brown dog walk near a green van and some junk',
#   'a large brown dog stand in front of a green van in the yard of a house',
#   'a yellow dog is standing in front of a green car and next to a toilet'],
#  ...}

# %%
vocabulary = to_vocabluary(desc_map) #what are the unique words present in the 40k captions

# %%
vocabulary
# Out:
# {'observe',
#  'cowlike',
#  'least',
#  'heron',
#  'dust',
#  'stonesign',
#  'shawled',
#  'towards',
#  'headline',
#  'vampire',
#  'halfdressed',
#  'crouched',
#  'bleacher',
#  'saver',
#  'autumn',
#  'hear',
#  'stuntbicyclist',
#  'length',
#  'under',
#  'hoolahoops',
#  'squeezing',
#  'overlooking',
#  'accompanying',
#  'fitness',
#  'applauding',
#  'sprayed',
#  'persues',
#  'tissue',
#  'convert',
#  'rocket',
#  'crashing',
#  'taxi',
#  'mart',
#  'tribal',
#  'public',
#  'hurridly',
#  'brushland',
#  'launch',
#  'stomach',
#  'numbered',
#  'wife',
#  'serve',
#  'keffiyahs',
#  'athletics',
#  'smelled',
#  'bushy',
#  'human',
#  'remax',
#  'pinwheel',
#  'licking',
#  'snowboarder',
#  'backset',
#  'cache',
#  'hopping',
#  'shaking',
#  'padding',
#  'brownstone',
#  'finger',
#  'steak',
#  'steer',
#  'receive',
#  'wrecked',
#  'palmtree',
#  'peanut',
#  'relatively',
#  'stroll',
#  'magician',
#  'lake',
#  'main',
#  'darkskinned',
#  'chewing',
#  'are',
#  'noy',
#  'rummaging',
#  'windmill',
#  'crampon',
#  'ask',
#  'ensemble',
#  'gather',
#  'schoolchildren',
#  'wharf',
#  'collide',
#  'trooper',
#  'test',
#  'tablet',
#  'dome',
#  'elderly',
#  'down',
#  'sightseeing',
#  'canoe',
#  'scrolled',
#  'microphone',
#  'cockpit',
#  'armstand',
#  'dirtbike',
#  'celebrate',
#  'energetic',
#  'housekeeping',
#  'wishing',
#  'emty',
#  'coffin',
#  'thorugh',
#  'allmale',
#  'beack',
#  'zippered',
#  'plaid',
#  'wade',
#  'doorag',
#  'fashion',
#  'speak',
#  'swordfighting',
#  'banner',
#  'read',
#  'neck',
#  'dimly',
#  'texting',
#  'throught',
#  'surrounded',
#  'tractor',
#  'straddle',
#  'populated',
#  'hatchback',
#  'accelerates',
#  'winning',
#  'darkerskinned',
#  'bundle',
#  'gymnasium',
#  'line',
#  'how',
#  'cavort',
#  'carnival',
#  'david',
#  'competition',
#  'hardwood',
#  'darker',
#  'coaster',
#  'dirtyblonde',
#  'diveboard',
#  'blackshirt',
#  'detector',
#  'crucifixion',
#  'reflective',
#  'effort',
#  'sunbathing',
#  'universal',
#  'boundary',
#  'held',
#  'blame',
#  'crate',
#  'whitecolored',
#  'hoop',
#  'rockface',
#  'portion',
#  'people',
#  'toy',
#  'kickflip',
#  'camel',
#  'pavilion',
#  'barrette',
#  'build',
#  'juggler',
#  'nice',
#  'watched',
#  'onrushing',
#  'ten',
#  'cemetery',
#  'somersaulting',
#  'cutout',
#  'fireplace',
#  'helping',
#  'ultimate',
#  'tandem',
#  'faint',
#  'pianist',
#  'nugent',
#  'foggyday',
#  'gaurd',
#  'tiger',
#  'tape',
#  'bread',
#  'misspelled',
#  'steady',
#  'elementary',
#  'waterhole',
#  'drink',
#  'theme',
#  'did',
#  'chow',
#  'signal',
#  'cigar',
#  'fast',
#  'handinhand',
#  'rapid',
#  'tunic',
#  'helments',
#  'linked',
#  'serving',
#  'directly',
#  'is',
#  'hollywood',
#  'exit',
#  'waterline',
#  'puffy',
#  'calm',
#  'boat',
#  'greyishbrown',
#  'garden',
#  'robe',
#  'shorthaired',
#  'poor',
#  'tatoo',
#  'spit',
#  'startled',
#  'dimpled',
#  'snub',
#  'mother',
#  'mime',
#  'person',
#  'average',
#  'racket',
#  'sprawl',
#  'sink',
#  'fair',
#  'dart',
#  'intercept',
#  'sun',
#  'blue',
#  'master',
#  'sliding',
#  'diferent',
#  'portfolio',
#  'fingerhold',
#  'adventurer',
#  'bedspread',
#  'mma',
#  'spinart',
#  'korean',
#  'reindeer',
#  'rollerskater',
#  'u',
#  'hind',
#  'crevasse',
#  'rollerblading',
#  'china',
#  'final',
#  'cracked',
#  'amplifier',
#  'boardwalk',
#  'keeping',
#  'sect',
#  'only',
#  'making',
#  'wicket',
#  'going',
#  'muff',
#  'parasurfing',
#  'graffitifilled',
#  'onstage',
#  'od',
#  'back',
#  'rowboat',
#  'recoil',
#  'silky',
#  'midsized',
#  'midday',
#  'afican',
#  'mountainous',
#  'stairway',
#  'quarterpipe',
#  'passing',
#  'approach',
#  'jumping',
#  'reaching',
#  'hotair',
#  'breaded',
#  'melted',
#  'lonely',
#  'urge',
#  'jello',
#  'change',
#  'accross',
#  'jewelry',
#  'bellbottoms',
#  'prays',
#  'churn',
#  'nursing',
#  'clad',
#  'springtime',
#  'cargo',
#  'uncrowded',
#  'noisemaker',
#  'hike',
#  'entry',
#  'davison',
#  'applies',
#  'bald',
#  'tireswing',
#  'speaking',
#  'animal',
#  'chewedup',
#  'bakery',
#  'rottwieler',
#  'tee',
#  'slope',
#  'coal',
#  'sort',
#  'information',
#  'luggage',
#  'narby',
#  'stripe',
#  'skyscraper',
#  'spotted',
#  'spiderpatterned',
#  'kennel',
#  'canoers',
#  'fancy',
#  'whisper',
#  'cot',
#  'kicking',
#  'already',
#  'beckham',
#  'apparatus',
#  'backstroke',
#  'bangle',
#  'smiling',
#  'snowshovel',
#  'belay',
#  'floor',
#  'labrador',
#  'pouring',
#  'warily',
#  'daylight',
#  'wizard',
#  'occured',
#  'middle',
#  'hosed',
#  'swallow',
#  'close',
#  'navel',
#  'encouraged',
#  'army',
#  'guest',
#  'responding',
#  'bowed',
#  'through',
#  'pretending',
#  'scrimmage',
#  'gift',
#  'banana',
#  'crescent',
#  'drainage',
#  'beach',
#  'engage',
#  'rose',
#  'beard',
#  'graduation',
#  'brazilian',
#  'giggling',
#  'submissive',
#  'belongs',
#  'nap',
#  'spiderman',
#  'check',
#  'out',
#  'joking',
#  'champ',
#  'distorted',
#  'lifted',
#  'chemical',
#  'skimming',
#  'downwards',
#  'polkadot',
#  'brass',
#  'sleeping',
#  'discovers',
#  'mountaindew',
#  'greysuited',
#  'prize',
#  'corgie',
#  'tonge',
#  'converge',
#  'soldier',
#  'furry',
#  'lily',
#  'squint',
#  'playgroud',
#  'trash',
#  'allowing',
#  'coldweather',
#  'skating',
#  'campsite',
#  'identification',
#  'egytianlike',
#  'virtual',
#  'perch',
#  'yard',
#  'avoiding',
#  'feature',
#  'spash',
#  'shining',
#  'aveda',
#  'oxford',
#  'midclimb',
#  'multiprint',
#  'growling',
#  'baring',
#  'urban',
#  'work',
#  'kissed',
#  'dotted',
#  'admired',
#  'given',
#  'jumpos',
#  'advertizing',
#  'chief',
#  'brunette',
#  'clifftop',
#  'away',
#  'batting',
#  'windowsill',
#  'licked',
#  'slimy',
#  'thumb',
#  'blowup',
#  'midfield',
#  'rowing',
#  'wakeboard',
#  'entertain',
#  'dye',
#  'route',
#  'marsh',
#  'artist',
#  'overgrown',
#  'unspooled',
#  'side',
#  'arizona',
#  'cob',
#  'america',
#  'leafy',
#  'fluorecent',
#  'tout',
#  'kickboxing',
#  'finley',
#  'pumped',
#  'stork',
#  'flap',
#  'locomotive',
#  'lounging',
#  'stringed',
#  'joined',
#  'hang',
#  'motorist',
#  'oppsing',
#  'cattail',
#  'slurps',
#  'squabble',
#  'bicyler',
#  'medatative',
#  'gelled',
#  'thinner',
#  'tackle',
#  'signaling',
#  'mirror',
#  'interview',
#  'deeper',
#  'tooth',
#  'right',
#  'toilet',
#  'p',
#  'constructed',
#  'martial',
#  'sushi',
#  'concrete',
#  'windsurfers',
#  'keepaway',
#  'upperclass',
#  'raging',
#  'mug',
#  'oregon',
#  'foyer',
#  'anouther',
#  'mess',
#  'smartly',
#  'streetshot',
#  'curb',
#  'racetrack',
#  'fame',
#  'shielding',
#  'choke',
#  'boulder',
#  'blouse',
#  'cd',
#  'surf',
#  'bespectacled',
#  'flyaway',
#  'everybody',
#  'countryside',
#  'sings',
#  'shortstop',
#  'mallard',
#  'toward',
#  'll',
#  'throat',
#  'learn',
#  'subject',
#  'swampy',
#  'mock',
#  'bum',
#  'retreiver',
#  'powerful',
#  'buttoned',
#  'magenta',
#  'locker',
#  'desolate',
#  'railroad',
#  'softdrinks',
#  'shield',
#  'scored',
#  'ratty',
#  'scrubland',
#  'handler',
#  'order',
#  'sofa',
#  'donning',
#  'attempted',
#  'construction',
#  'derssed',
#  'princess',
#  'dryed',
#  'breaking',
#  'freefall',
#  'frolic',
#  'graffiti',
#  'posing',
#  'intensely',
#  'kick',
#  'pomeranian',
#  'summit',
#  'straggle',
#  'dappled',
#  'entitled',
#  'vast',
#  'overflowing',
#  'had',
#  'launching',
#  'colecting',
#  'note',
#  'bouncey',
#  'greyish',
#  'policeperson',
#  'pinstripe',
#  'facepainted',
#  'telephot',
#  'dragsters',
#  'awe',
#  'gauge',
#  'doll',
#  'meter',
#  'designed',
#  'multilple',
#  'shaving',
#  'pokemon',
#  'swan',
#  'kickboxer',
#  'rummage',
#  'emerging',
#  'henna',
#  'largeboned',
#  'bland',
#  'dropping',
#  'headresses',
#  'east',
#  'bean',
#  'playes',
#  'bloom',
#  'meet',
#  'outwards',
#  'spraying',
#  'hilly',
#  'boredom',
#  'know',
#  'motorbiker',
#  'shady',
#  'seating',
#  'brings',
#  'wrap',
#  'apparantly',
#  'treat',
#  'gith',
#  'mouse',
#  'serveral',
#  'triangular',
#  'examined',
#  'matchin',
#  'dumbbell',
#  'this',
#  'slate',
#  'refuse',
#  'performer',
#  'cappedhills',
#  'hoodies',
#  'landing',
#  'pensively',
#  'await',
#  'expose',
#  'bridesmaid',
#  'skim',
#  'paraphernalia',
#  'entertaining',
#  'real',
#  'fix',
#  'falling',
#  'catholic',
#  'african',
#  'cornfield',
#  'shrine',
#  'representing',
#  'tree',
#  'creek',
#  'cyclist',
#  'village',
#  'handle',
#  'running',
#  'dirtbikers',
#  'redbull',
#  'dangerous',
#  'soccor',
#  'beaver',
#  'temple',
#  'alike',
#  'bottle',
#  'overflow',
#  'unconventional',
#  'paint',
#  'sail',
#  'bib',
#  'bash',
#  'costume',
#  'isolated',
#  'stamds',
#  'playtoy',
#  'tag',
#  'scattered',
#  'outside',
#  'chatting',
#  'full',
#  'crane',
#  'overturn',
#  'kayer',
#  'videotape',
#  'slide',
#  'partition',
#  'view',
#  'loooking',
#  'easter',
#  'scary',
#  'scruffy',
#  'tourquoise',
#  'contemplates',
#  'mixed',
#  'freshly',
#  'poll',
#  'instrument',
#  'avoid',
#  'north',
#  'will',
#  'kaki',
#  'shoulderhigh',
#  'outstreached',
#  'plushie',
#  'scent',
#  'navigates',
#  'viewfinder',
#  'picure',
#  'shin',
#  'second',
#  'register',
#  'wintergear',
#  'salt',
#  'dirtcovered',
#  'recliner',
#  'handstand',
#  'midswing',
#  'pastel',
#  'snowgear',
#  'lush',
#  'tankini',
#  'accent',
#  'claus',
#  'breath',
#  'sync',
#  'giant',
#  'overhear',
#  'blackandwhite',
#  'gyro',
#  'cobblestone',
#  'offroad',
#  'yellowsuited',
#  'wodden',
#  'dizzy',
#  'muddy',
#  'iron',
#  'gas',
#  'persian',
#  'gondola',
#  'showerhead',
#  'seashore',
#  'bison',
#  'nightclub',
#  'kiss',
#  'midpitch',
#  'winding',
#  'military',
#  'knelt',
#  'clasped',
#  'treelined',
#  'rush',
#  'begin',
#  'folded',
#  'artsstyle',
#  'arrives',
#  'tight',
#  'belt',
#  'ahead',
#  'thank',
#  'suntan',
#  'mountainside',
#  'mouthpiece',
#  'beckons',
#  'flash',
#  'sillhouetted',
#  'dimlylit',
#  'casque',
#  'activity',
#  'bridal',
#  'craft',
#  'overhanging',
#  'blondeheaded',
#  'kept',
#  'diamond',
#  'muscle',
#  'adjusts',
#  'sweater',
#  'decorated',
#  'darkened',
#  'geological',
#  'underbrush',
#  'snoring',
#  'rockstar',
#  'crewman',
#  'fixing',
#  'favorite',
#  'content',
#  'coloring',
#  'ballons',
#  'begging',
#  'protester',
#  'orb',
#  'hop',
#  'outise',
#  'exhibit',
#  'column',
#  'pressure',
#  'bowled',
#  'filled',
#  'sub',
#  'reduniformed',
#  'prow',
#  'italian',
#  'terminal',
#  'foot',
#  'mate',
#  'sprawling',
#  'decorative',
#  'website',
#  'located',
#  'rounded',
#  'aquacolored',
#  'policewoman',
#  'judo',
#  'grilling',
#  'skilift',
#  'alcohol',
#  'arriving',
#  'stood',
#  'pearl',
#  'nervous',
#  'indigo',
#  'deciding',
#  'backgound',
#  'juggle',
#  'draft',
#  'stream',
#  'lodge',
#  'overhead',
#  'save',
#  'showing',
#  'vertical',
#  'ducky',
#  'bumper',
#  'twig',
#  'twelve',
#  'next',
#  'woooden',
#  'figurine',
#  'gound',
#  'producing',
#  'refreshment',
#  'pleadingly',
#  'dachshund',
#  'anchored',
#  'icing',
#  'create',
#  'goggles',
#  'quiet',
#  'rockclimber',
#  'take',
#  'she',
#  'dressed',
#  'underside',
#  'raceway',
#  'perfoms',
#  'dont',
#  'larger',
#  'goucho',
#  'cycling',
#  'booklet',
#  'philadelphia',
#  'sailboat',
#  'superhero',
#  'colored',
#  'upright',
#  'destination',
#  'motor',
#  'spurting',
#  'floppy',
#  'swordfight',
#  'stacking',
#  'spray',
#  'grin',
#  'replaced',
#  'arc',
#  'doughnut',
#  'google',
#  'an',
#  'golf',
#  'hoddie',
#  'spot',
#  'student',
#  'sword',
#  'spike',
#  'bouncy',
#  'pepco',
#  'mets',
#  'thinking',
#  'cup',
#  'cactus',
#  'chinatown',
#  'trows',
#  'affectionately',
#  'climbed',
#  'whipping',
#  'ninja',
#  'stubbled',
#  'preoccupied',
#  'lavish',
#  'goldenbrown',
#  'bull',
#  'possibly',
#  'bluetooth',
#  'additional',
#  'stringless',
#  'nursed',
#  'goodbye',
#  'fleecy',
#  'tend',
#  'election',
#  'alleyway',
#  'cheer',
#  'shorthair',
#  'backbend',
#  'wildebeest',
#  'midstride',
#  'pretend',
#  'eagle',
#  'sat',
#  'collecting',
#  'expanding',
#  'individual',
#  'inflating',
#  'commuter',
#  'poof',
#  'kiddie',
#  'bed',
#  'rub',
#  'towheaded',
#  'continue',
#  'antoher',
#  'enthusiastically',
#  'enterance',
#  'minnie',
#  'expanse',
#  'of',
#  'stonefilled',
#  'ceremonial',
#  'peircings',
#  'wetsuite',
#  'branded',
#  'shape',
#  'debris',
#  'garland',
#  'pay',
#  'waeribng',
#  'performed',
#  'browm',
#  'exiting',
#  'frown',
#  'child',
#  'pring',
#  'towel',
#  'daisy',
#  'lime',
#  'competitively',
#  'lighting',
#  'wed',
#  'soak',
#  'longhorn',
#  'gliding',
#  'tanktop',
#  'reception',
#  'travelling',
#  'halfway',
#  'living',
#  'dandylions',
#  'facedown',
#  'homeless',
#  'perspective',
#  'horro',
#  'cloud',
#  'tabby',
#  'sparse',
#  'furiously',
#  'stir',
#  'illuminated',
#  'saw',
#  'sunbather',
#  'scowl',
#  'thing',
#  'reported',
#  'bag',
#  'pacifier',
#  'he',
#  'labeled',
#  'fry',
#  'helped',
#  'segway',
#  'domino',
#  'scream',
#  'bmw',
#  'featuring',
#  'international',
#  'medium',
#  'slushies',
#  'highrise',
#  'ropeswinging',
#  'photograhi',
#  'whiel',
#  'graffiticovered',
#  'lay',
#  'fortune',
#  'ledge',
#  'pour',
#  'swiftly',
#  'ohio',
#  'snuggle',
#  'plungles',
#  'flotation',
#  'wii',
#  'cleaning',
#  'computer',
#  'marina',
#  'automobile',
#  'dark',
#  'sport',
#  'lunge',
#  'grappling',
#  'atm',
#  'clowds',
#  'hippy',
#  'sol',
#  'sits',
#  'piercings',
#  'swimsuites',
#  'foreigner',
#  'snowdrift',
#  'muzzled',
#  'monkey',
#  'supervising',
#  'rectangular',
#  'flooded',
#  ...}

# %%
len(vocabulary)
# Out:
# 7565

# %%
save_descriptions(desc_map , 'descriptions.txt')

# %%
from pickle import load

# %%
# loading the doc
def load_doc(filename):
    file = open(filename , 'r')
    text = file.read()
    file.close()
    return text

# this function is used for to get train image description from our dataset

def load_clean_descriptions(filename , dataset):
    doc = load_doc(filename)
    descriptions = dict()
    
    for line in doc.split('\n'):
        tokens = line.split()
        image_id , image_desc = tokens[0] , tokens[1:]
        
        if image_id in dataset:
            
            if image_id not in descriptions:
                descriptions[image_id] = list()
            
            # we add two tage at start and at end of the descitpion to identify to start and 
            # end of desc.
            desc = 'startseq '+ ' '.join(image_desc)+ ' endseq'
            descriptions[image_id].append(desc)
            
    return descriptions


# laod photo features
def load_photo_features(filename , dataset):
    all_features = load(open(filename,'rb'))
    features = {k+'.jpg' : all_features[k] for k in dataset}
    return features

# %%
train = set(descriptions['image_id'][:127125])
print('len of train image',len(train))
# Out:
# len of train image 8091

# %%
# traininset makinng and set startseq and endseq tag in descriptions
train_descriptions = load_clean_descriptions('descriptions.txt' , train)

# %%
print('len of train descriptions' , len(train_descriptions))
# Out:
# len of train descriptions 8091

# %%
train = pd.DataFrame(train)

# %%
train.head(5)
# Out:
#                            0
# 0  3528251308_481a28283a.jpg
# 1  3501781809_88429e3b83.jpg
# 2    72218201_e0e9c7d65b.jpg
# 3  3351360323_91bb341350.jpg
# 4  3216926094_bc975e84b9.jpg

# %%
train2 = train[0].apply(lambda x : x.replace('.jpg' , '')) # remove jpg sign

# %%
train2.head(5)
# Out:
# 0    3528251308_481a28283a
# 1    3501781809_88429e3b83
# 2      72218201_e0e9c7d65b
# 3    3351360323_91bb341350
# 4    3216926094_bc975e84b9
# Name: 0, dtype: object

# %%
# train features means feautures from training images
train_features = load_photo_features('/content/features.pkl' , train2)
print('photos train :',len(train_features))
# Out:
# photos train : 8091

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# convert dictonary to lis descriptions

def to_lines(descriptions):
    all_desc = list()
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
        
    return all_desc

# fit tokenizer on descriptions
def create_tokenizer(descriptions):
    lines = to_lines(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('vocab size' , vocab_size)
# Out:
# vocab size 7568

# %%
tokenizer.word_index
# Out:
# {'a': 1,
#  'startseq': 2,
#  'endseq': 3,
#  'in': 4,
#  'the': 5,
#  'on': 6,
#  'dog': 7,
#  'is': 8,
#  'and': 9,
#  'with': 10,
#  'man': 11,
#  'of': 12,
#  'two': 13,
#  'boy': 14,
#  'girl': 15,
#  'woman': 16,
#  'white': 17,
#  'black': 18,
#  'are': 19,
#  'to': 20,
#  'wearing': 21,
#  'at': 22,
#  'people': 23,
#  'water': 24,
#  'child': 25,
#  'red': 26,
#  'young': 27,
#  'brown': 28,
#  'an': 29,
#  'his': 30,
#  'blue': 31,
#  'running': 32,
#  'through': 33,
#  'playing': 34,
#  'while': 35,
#  'shirt': 36,
#  'ball': 37,
#  'down': 38,
#  'standing': 39,
#  'little': 40,
#  'grass': 41,
#  'person': 42,
#  'snow': 43,
#  'jumping': 44,
#  'over': 45,
#  'stand': 46,
#  'front': 47,
#  'three': 48,
#  'jump': 49,
#  'sitting': 50,
#  'it': 51,
#  'holding': 52,
#  'run': 53,
#  'field': 54,
#  'small': 55,
#  'play': 56,
#  'up': 57,
#  'by': 58,
#  'large': 59,
#  'green': 60,
#  'group': 61,
#  'one': 62,
#  'yellow': 63,
#  'her': 64,
#  'walking': 65,
#  'men': 66,
#  'into': 67,
#  'air': 68,
#  'beach': 69,
#  'mouth': 70,
#  'near': 71,
#  'player': 72,
#  'rock': 73,
#  'street': 74,
#  'another': 75,
#  'bike': 76,
#  'for': 77,
#  'from': 78,
#  'riding': 79,
#  'walk': 80,
#  'outside': 81,
#  'other': 82,
#  'look': 83,
#  'hat': 84,
#  'out': 85,
#  'mountain': 86,
#  'next': 87,
#  'jacket': 88,
#  'off': 89,
#  'looking': 90,
#  'orange': 91,
#  'pink': 92,
#  'ride': 93,
#  'camera': 94,
#  'their': 95,
#  'pool': 96,
#  'tree': 97,
#  'around': 98,
#  'behind': 99,
#  'toy': 100,
#  'some': 101,
#  'background': 102,
#  'dirt': 103,
#  'hand': 104,
#  'building': 105,
#  'soccer': 106,
#  'sits': 107,
#  'wall': 108,
#  'dressed': 109,
#  'ha': 110,
#  'hold': 111,
#  'face': 112,
#  'crowd': 113,
#  'stick': 114,
#  'along': 115,
#  'kid': 116,
#  'watch': 117,
#  'park': 118,
#  'climbing': 119,
#  'top': 120,
#  'swing': 121,
#  'car': 122,
#  'four': 123,
#  'catch': 124,
#  'picture': 125,
#  'trick': 126,
#  'football': 127,
#  'skateboard': 128,
#  'across': 129,
#  'grassy': 130,
#  'bicycle': 131,
#  'hill': 132,
#  'sand': 133,
#  'smiling': 134,
#  'ocean': 135,
#  'wave': 136,
#  'swimming': 137,
#  'short': 138,
#  'carrying': 139,
#  'doing': 140,
#  'baby': 141,
#  'each': 142,
#  'tennis': 143,
#  'dress': 144,
#  'head': 145,
#  'race': 146,
#  'snowy': 147,
#  'together': 148,
#  'hair': 149,
#  'back': 150,
#  'him': 151,
#  's': 152,
#  'area': 153,
#  'basketball': 154,
#  'helmet': 155,
#  'that': 156,
#  'arm': 157,
#  'slide': 158,
#  'bench': 159,
#  'tan': 160,
#  'road': 161,
#  'uniform': 162,
#  'sidewalk': 163,
#  'game': 164,
#  'sit': 165,
#  'pose': 166,
#  'ground': 167,
#  'something': 168,
#  'fence': 169,
#  'frisbee': 170,
#  'being': 171,
#  'lake': 172,
#  'ramp': 173,
#  'side': 174,
#  'skateboarder': 175,
#  'path': 176,
#  'horse': 177,
#  'city': 178,
#  'track': 179,
#  'boat': 180,
#  'several': 181,
#  'purple': 182,
#  'covered': 183,
#  'suit': 184,
#  'there': 185,
#  'coat': 186,
#  'baseball': 187,
#  'smile': 188,
#  'sign': 189,
#  'posing': 190,
#  'guy': 191,
#  'rope': 192,
#  'climb': 193,
#  'wooden': 194,
#  'long': 195,
#  'wood': 196,
#  'high': 197,
#  'big': 198,
#  'table': 199,
#  'motorcycle': 200,
#  'sunglass': 201,
#  'lady': 202,
#  'glass': 203,
#  'them': 204,
#  'pant': 205,
#  'couple': 206,
#  'jean': 207,
#  'watching': 208,
#  'snowboarder': 209,
#  'take': 210,
#  'dark': 211,
#  'grey': 212,
#  'towards': 213,
#  'beside': 214,
#  'under': 215,
#  'rocky': 216,
#  'team': 217,
#  'bird': 218,
#  'river': 219,
#  'leap': 220,
#  'doe': 221,
#  'adult': 222,
#  'above': 223,
#  'racing': 224,
#  'older': 225,
#  'outfit': 226,
#  'ice': 227,
#  'colorful': 228,
#  'striped': 229,
#  'rider': 230,
#  'who': 231,
#  'skier': 232,
#  'bag': 233,
#  'get': 234,
#  'onto': 235,
#  'cap': 236,
#  'collar': 237,
#  'midair': 238,
#  'pole': 239,
#  'he': 240,
#  'surfer': 241,
#  'flower': 242,
#  'taking': 243,
#  'costume': 244,
#  'open': 245,
#  'cliff': 246,
#  'asian': 247,
#  'light': 248,
#  'playground': 249,
#  'swim': 250,
#  'yard': 251,
#  'against': 252,
#  'chair': 253,
#  'performing': 254,
#  'blonde': 255,
#  'hockey': 256,
#  'fountain': 257,
#  'body': 258,
#  'leg': 259,
#  'backpack': 260,
#  'blond': 261,
#  'laying': 262,
#  'many': 263,
#  'step': 264,
#  'after': 265,
#  'chasing': 266,
#  'toddler': 267,
#  'ski': 268,
#  'wet': 269,
#  'surrounded': 270,
#  'flag': 271,
#  'brick': 272,
#  'guitar': 273,
#  'outdoors': 274,
#  'during': 275,
#  'inside': 276,
#  'flying': 277,
#  'old': 278,
#  'edge': 279,
#  'biker': 280,
#  'others': 281,
#  'shore': 282,
#  'colored': 283,
#  'away': 284,
#  'drink': 285,
#  'hanging': 286,
#  'wear': 287,
#  'trying': 288,
#  'very': 289,
#  'line': 290,
#  'someone': 291,
#  'forest': 292,
#  'object': 293,
#  'bed': 294,
#  'make': 295,
#  'five': 296,
#  'floor': 297,
#  'middle': 298,
#  'night': 299,
#  'sky': 300,
#  'talking': 301,
#  'puppy': 302,
#  'making': 303,
#  'nearby': 304,
#  'tshirt': 305,
#  'gray': 306,
#  'leaf': 307,
#  'whilst': 308,
#  'about': 309,
#  'trail': 310,
#  'climber': 311,
#  'surfboard': 312,
#  'leash': 313,
#  'bar': 314,
#  'going': 315,
#  'past': 316,
#  'window': 317,
#  'carry': 318,
#  'board': 319,
#  'house': 320,
#  'toward': 321,
#  'tall': 322,
#  'haired': 323,
#  'try': 324,
#  'swinging': 325,
#  'eating': 326,
#  'dancing': 327,
#  'bridge': 328,
#  'this': 329,
#  'fly': 330,
#  'jersey': 331,
#  'animal': 332,
#  'kick': 333,
#  'chase': 334,
#  'leaping': 335,
#  'day': 336,
#  'all': 337,
#  'outdoor': 338,
#  'stone': 339,
#  'course': 340,
#  'clothes': 341,
#  'shallow': 342,
#  'obstacle': 343,
#  'fighting': 344,
#  'lot': 345,
#  'room': 346,
#  'sweater': 347,
#  'foot': 348,
#  'plastic': 349,
#  'clothing': 350,
#  'male': 351,
#  'splashing': 352,
#  'throw': 353,
#  'ready': 354,
#  'bubble': 355,
#  'go': 356,
#  'greyhound': 357,
#  'set': 358,
#  'between': 359,
#  'sled': 360,
#  'stair': 361,
#  'railing': 362,
#  'trunk': 363,
#  'getting': 364,
#  'sliding': 365,
#  'bright': 366,
#  'dance': 367,
#  'tire': 368,
#  'they': 369,
#  'number': 370,
#  'skateboarding': 371,
#  'vest': 372,
#  'bathing': 373,
#  'store': 374,
#  'hit': 375,
#  'concrete': 376,
#  'female': 377,
#  'waiting': 378,
#  'tongue': 379,
#  'lawn': 380,
#  'trampoline': 381,
#  'train': 382,
#  'eye': 383,
#  'winter': 384,
#  'skate': 385,
#  'splash': 386,
#  'hiker': 387,
#  'skiing': 388,
#  'gear': 389,
#  'surf': 390,
#  'mud': 391,
#  'metal': 392,
#  'fire': 393,
#  'flip': 394,
#  'stream': 395,
#  'sandy': 396,
#  'scarf': 397,
#  'tent': 398,
#  'rail': 399,
#  'pulling': 400,
#  'catching': 401,
#  'throwing': 402,
#  'ear': 403,
#  'distance': 404,
#  'golden': 405,
#  'shoe': 406,
#  'fishing': 407,
#  'sun': 408,
#  'shirtless': 409,
#  'overlooking': 410,
#  'couch': 411,
#  'kayak': 412,
#  'skirt': 413,
#  'cellphone': 414,
#  'photo': 415,
#  'vehicle': 416,
#  'wooded': 417,
#  'busy': 418,
#  'drinking': 419,
#  'nose': 420,
#  'lying': 421,
#  'cart': 422,
#  'cyclist': 423,
#  'snowboard': 424,
#  'umbrella': 425,
#  'puddle': 426,
#  'truck': 427,
#  'performs': 428,
#  'pond': 429,
#  'right': 430,
#  'reading': 431,
#  'upside': 432,
#  'laughing': 433,
#  'mask': 434,
#  'surfing': 435,
#  'leaning': 436,
#  'dock': 437,
#  'bat': 438,
#  'sunset': 439,
#  'shopping': 440,
#  'huge': 441,
#  'hurdle': 442,
#  'stunt': 443,
#  'she': 444,
#  'food': 445,
#  'harness': 446,
#  'turn': 447,
#  'waterfall': 448,
#  'talk': 449,
#  'american': 450,
#  'hang': 451,
#  'left': 452,
#  'sport': 453,
#  'show': 454,
#  'paper': 455,
#  'coming': 456,
#  'view': 457,
#  'no': 458,
#  'family': 459,
#  'or': 460,
#  'bicyclist': 461,
#  'restaurant': 462,
#  'life': 463,
#  'lean': 464,
#  'wait': 465,
#  'book': 466,
#  'bus': 467,
#  'equipment': 468,
#  'wetsuit': 469,
#  'elderly': 470,
#  'canoe': 471,
#  'goal': 472,
#  'biting': 473,
#  'both': 474,
#  'deep': 475,
#  'slope': 476,
#  'bottle': 477,
#  'cigarette': 478,
#  'lone': 479,
#  'structure': 480,
#  'setting': 481,
#  'raft': 482,
#  'sweatshirt': 483,
#  'fall': 484,
#  'skating': 485,
#  'fight': 486,
#  'ring': 487,
#  'bikini': 488,
#  'muddy': 489,
#  'like': 490,
#  'shoulder': 491,
#  'hoop': 492,
#  'falling': 493,
#  'dry': 494,
#  'pile': 495,
#  'court': 496,
#  'ledge': 497,
#  'closeup': 498,
#  'swimsuit': 499,
#  'wheel': 500,
#  'bucket': 501,
#  'lay': 502,
#  'crowded': 503,
#  'bmx': 504,
#  'six': 505,
#  'be': 506,
#  'tank': 507,
#  'airborne': 508,
#  'cat': 509,
#  'driving': 510,
#  'cement': 511,
#  'german': 512,
#  'paddle': 513,
#  'have': 514,
#  'door': 515,
#  'cross': 516,
#  'paint': 517,
#  'sprinkler': 518,
#  'inflatable': 519,
#  'diving': 520,
#  'goggles': 521,
#  'attempt': 522,
#  'point': 523,
#  'box': 524,
#  'balloon': 525,
#  'parking': 526,
#  'teenage': 527,
#  'cow': 528,
#  'blanket': 529,
#  'subway': 530,
#  'kicking': 531,
#  'shaking': 532,
#  'statue': 533,
#  'piece': 534,
#  'motorcyclist': 535,
#  'fallen': 536,
#  'seat': 537,
#  'parade': 538,
#  'band': 539,
#  'fish': 540,
#  'microphone': 541,
#  'shepherd': 542,
#  'log': 543,
#  'boot': 544,
#  'bull': 545,
#  'gathered': 546,
#  'pull': 547,
#  'duck': 548,
#  'backyard': 549,
#  'smaller': 550,
#  'tunnel': 551,
#  'finger': 552,
#  'full': 553,
#  'silver': 554,
#  'block': 555,
#  'smoking': 556,
#  'surface': 557,
#  'held': 558,
#  'sunny': 559,
#  'low': 560,
#  'event': 561,
#  'racer': 562,
#  'cowboy': 563,
#  'beard': 564,
#  'stage': 565,
#  'smoke': 566,
#  'leather': 567,
#  'wrestler': 568,
#  'art': 569,
#  'scooter': 570,
#  'reach': 571,
#  'fluffy': 572,
#  'graffiti': 573,
#  'bite': 574,
#  'pushing': 575,
#  'using': 576,
#  'hiking': 577,
#  'cup': 578,
#  'branch': 579,
#  'rugby': 580,
#  'painted': 581,
#  'tube': 582,
#  'corner': 583,
#  'wrestle': 584,
#  'stuffed': 585,
#  'push': 586,
#  'pointing': 587,
#  'glove': 588,
#  'end': 589,
#  'steep': 590,
#  'teenager': 591,
#  'bald': 592,
#  'shot': 593,
#  'blowing': 594,
#  'blow': 595,
#  'net': 596,
#  'drive': 597,
#  'laugh': 598,
#  'sleeping': 599,
#  'read': 600,
#  'put': 601,
#  'gold': 602,
#  'gather': 603,
#  'volleyball': 604,
#  'furry': 605,
#  'plant': 606,
#  'hugging': 607,
#  'wrestling': 608,
#  'muzzle': 609,
#  'crossing': 610,
#  'same': 611,
#  'shop': 612,
#  'hind': 613,
#  'staring': 614,
#  'attempting': 615,
#  'police': 616,
#  'kissing': 617,
#  'spectator': 618,
#  'runner': 619,
#  'sheep': 620,
#  'party': 621,
#  'photograph': 622,
#  'few': 623,
#  'bunch': 624,
#  'facing': 625,
#  'below': 626,
#  'wading': 627,
#  'onlooker': 628,
#  'beige': 629,
#  'instrument': 630,
#  'snowboarding': 631,
#  'garden': 632,
#  'clear': 633,
#  'phone': 634,
#  'base': 635,
#  'bottom': 636,
#  'desert': 637,
#  'beautiful': 638,
#  'sticking': 639,
#  'underwater': 640,
#  'attached': 641,
#  'friend': 642,
#  'softball': 643,
#  'racket': 644,
#  'bride': 645,
#  'competition': 646,
#  'way': 647,
#  'row': 648,
#  'eats': 649,
#  'fast': 650,
#  'waving': 651,
#  'bush': 652,
#  'hug': 653,
#  'wide': 654,
#  'gym': 655,
#  'poodle': 656,
#  'racetrack': 657,
#  'headband': 658,
#  'which': 659,
#  'naked': 660,
#  'rain': 661,
#  'gravel': 662,
#  'rolling': 663,
#  'cone': 664,
#  'beer': 665,
#  'prepares': 666,
#  'gun': 667,
#  'empty': 668,
#  'handstand': 669,
#  'motocross': 670,
#  'wing': 671,
#  'neck': 672,
#  'do': 673,
#  'kite': 674,
#  'can': 675,
#  'snowcovered': 676,
#  'help': 677,
#  'stop': 678,
#  'display': 679,
#  'seated': 680,
#  'plaid': 681,
#  'mohawk': 682,
#  'tattoo': 683,
#  'market': 684,
#  'downhill': 685,
#  'pavement': 686,
#  'painting': 687,
#  'platform': 688,
#  'paddling': 689,
#  'having': 690,
#  'spray': 691,
#  'public': 692,
#  'close': 693,
#  'just': 694,
#  'fenced': 695,
#  'african': 696,
#  'drum': 697,
#  'lie': 698,
#  'rest': 699,
#  'traffic': 700,
#  'rough': 701,
#  'float': 702,
#  'scene': 703,
#  'kiss': 704,
#  'among': 705,
#  'hose': 706,
#  'cloud': 707,
#  'motorbike': 708,
#  'say': 709,
#  'chewing': 710,
#  'school': 711,
#  'raise': 712,
#  'cream': 713,
#  'different': 714,
#  'thrown': 715,
#  'landscape': 716,
#  'rural': 717,
#  'purse': 718,
#  'lap': 719,
#  'barefoot': 720,
#  'tie': 721,
#  'urban': 722,
#  'plate': 723,
#  'kitchen': 724,
#  'teeth': 725,
#  'goalie': 726,
#  'newspaper': 727,
#  'resting': 728,
#  'mother': 729,
#  'filled': 730,
#  'headphone': 731,
#  'give': 732,
#  'dirty': 733,
#  'carnival': 734,
#  'before': 735,
#  'cricket': 736,
#  'paved': 737,
#  'lit': 738,
#  'paw': 739,
#  'indoor': 740,
#  'carpet': 741,
#  'wire': 742,
#  'creek': 743,
#  'younger': 744,
#  'bearded': 745,
#  'land': 746,
#  'move': 747,
#  'rapid': 748,
#  'wedding': 749,
#  'match': 750,
#  'opposing': 751,
#  'spot': 752,
#  'showing': 753,
#  'balance': 754,
#  'formation': 755,
#  'owner': 756,
#  'bend': 757,
#  'speed': 758,
#  'stadium': 759,
#  'santa': 760,
#  'moving': 761,
#  'parked': 762,
#  'bank': 763,
#  'chain': 764,
#  'reaching': 765,
#  'third': 766,
#  'onstage': 767,
#  'shake': 768,
#  'seen': 769,
#  'video': 770,
#  'where': 771,
#  'foreground': 772,
#  'retriever': 773,
#  'bandanna': 774,
#  'jeep': 775,
#  'covering': 776,
#  'singing': 777,
#  'tackle': 778,
#  'hula': 779,
#  'bowl': 780,
#  'break': 781,
#  'deck': 782,
#  'atv': 783,
#  'fetch': 784,
#  'pulled': 785,
#  'pipe': 786,
#  'funny': 787,
#  'matching': 788,
#  'parachute': 789,
#  'giant': 790,
#  'cheerleader': 791,
#  'officer': 792,
#  'shooting': 793,
#  'stroller': 794,
#  'hole': 795,
#  'outstretched': 796,
#  'floating': 797,
#  'lead': 798,
#  'machine': 799,
#  'audience': 800,
#  'hitting': 801,
#  'fair': 802,
#  'unicycle': 803,
#  'amusement': 804,
#  'pack': 805,
#  'lift': 806,
#  'skater': 807,
#  'multicolored': 808,
#  'basket': 809,
#  'hay': 810,
#  'shadow': 811,
#  'staircase': 812,
#  'christmas': 813,
#  'clown': 814,
#  'spotted': 815,
#  'terrier': 816,
#  'atop': 817,
#  'chew': 818,
#  'preparing': 819,
#  'alongside': 820,
#  'necklace': 821,
#  'martial': 822,
#  'curly': 823,
#  'wheelie': 824,
#  'round': 825,
#  'roll': 826,
#  'grinding': 827,
#  'flight': 828,
#  'appears': 829,
#  'lined': 830,
#  'computer': 831,
#  'direction': 832,
#  'bear': 833,
#  'grab': 834,
#  'follows': 835,
#  'digging': 836,
#  'larger': 837,
#  'rowing': 838,
#  'putting': 839,
#  'worker': 840,
#  'terrain': 841,
#  'come': 842,
#  'handrail': 843,
#  'alone': 844,
#  'swimmer': 845,
#  'denim': 846,
#  'enjoys': 847,
#  'hike': 848,
#  'hoodie': 849,
#  'gate': 850,
#  'music': 851,
#  'balancing': 852,
#  'perform': 853,
#  'muzzled': 854,
#  'rodeo': 855,
#  'kneeling': 856,
#  'dive': 857,
#  'half': 858,
#  'station': 859,
#  'giving': 860,
#  'shaggy': 861,
#  'picnic': 862,
#  'backwards': 863,
#  'dune': 864,
#  'touch': 865,
#  'indoors': 866,
#  'spinning': 867,
#  'ribbon': 868,
#  'himself': 869,
#  'string': 870,
#  'tricycle': 871,
#  'mound': 872,
#  'member': 873,
#  'camel': 874,
#  'jumped': 875,
#  'crouch': 876,
#  'pier': 877,
#  'tug': 878,
#  'hooded': 879,
#  'cold': 880,
#  'barrier': 881,
#  'roller': 882,
#  'counter': 883,
#  'pigeon': 884,
#  'fan': 885,
#  'item': 886,
#  'construction': 887,
#  'safety': 888,
#  'playfully': 889,
#  'brightly': 890,
#  'makeup': 891,
#  'writing': 892,
#  'knee': 893,
#  'frame': 894,
#  'ladder': 895,
#  'cover': 896,
#  'sword': 897,
#  'referee': 898,
#  'cloth': 899,
#  'enjoying': 900,
#  'shoot': 901,
#  'competing': 902,
#  'patch': 903,
#  'violin': 904,
#  'sniffing': 905,
#  'licking': 906,
#  'rollerblade': 907,
#  'policeman': 908,
#  'sooner': 909,
#  'seven': 910,
#  'kneel': 911,
#  'cut': 912,
#  'sea': 913,
#  'color': 914,
#  'collie': 915,
#  'bikers': 916,
#  'stare': 917,
#  'underneath': 918,
#  'driver': 919,
#  'doorway': 920,
#  'passing': 921,
#  'robe': 922,
#  'stump': 923,
#  'rink': 924,
#  'quickly': 925,
#  'camouflage': 926,
#  'begin': 927,
#  'these': 928,
#  'splashed': 929,
#  'jungle': 930,
#  'hillside': 931,
#  'taken': 932,
#  'made': 933,
#  'walkway': 934,
#  'fur': 935,
#  'headscarf': 936,
#  'professional': 937,
#  'chest': 938,
#  'decorated': 939,
#  'wheelchair': 940,
#  'jockey': 941,
#  'kayaking': 942,
#  'bouncing': 943,
#  'straw': 944,
#  'tail': 945,
#  'homeless': 946,
#  'opposite': 947,
#  'photographer': 948,
#  'home': 949,
#  'work': 950,
#  'caught': 951,
#  'rollerblading': 952,
#  'military': 953,
#  'courtyard': 954,
#  'biking': 955,
#  'without': 956,
#  'wagon': 957,
#  'plain': 958,
#  'post': 959,
#  'landing': 960,
#  'coffee': 961,
#  'shown': 962,
#  'peace': 963,
#  'mirror': 964,
#  'screen': 965,
#  'karate': 966,
#  'watched': 967,
#  'overall': 968,
#  'lab': 969,
#  'us': 970,
#  'mat': 971,
#  'hot': 972,
#  'redheaded': 973,
#  'cardboard': 974,
#  'strip': 975,
#  'helping': 976,
#  'war': 977,
#  'eat': 978,
#  'suspended': 979,
#  'blurry': 980,
#  'candle': 981,
#  'monkey': 982,
#  'formal': 983,
#  'peak': 984,
#  'forward': 985,
#  'see': 986,
#  'cry': 987,
#  'fetching': 988,
#  'square': 989,
#  'grocery': 990,
#  'range': 991,
#  'indian': 992,
#  'barking': 993,
#  'banner': 994,
#  'frozen': 995,
#  'mountainside': 996,
#  'heavy': 997,
#  'boxer': 998,
#  'happily': 999,
#  'cheek': 1000,
#  ...}

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import numpy as np

# %%
# calculate the length with most words
def max_length(descriptions):
    lines = to_lines(descriptions)
    return max([len(line.split())for line in lines])
    
# create sequences of images,input sequences and output sequences
def create_sequences(tokenizer , max_length , desc_list , photo):
    X1 , X2 , y = list() , list() , list()
    
    for desc in desc_list:
        # convert words to number value
        seq = tokenizer.texts_to_sequences([desc])[0]
        
        for i in range(1, len(seq)):
            
            in_seq , output_seq = seq[:i] , seq[i]
            in_seq = pad_sequences([in_seq] , maxlen = max_length)[0]
            output_seq = to_categorical([output_seq] , num_classes = vocab_size)[0]
            
            X1.append(photo)
            X2.append(in_seq)
            y.append(output_seq)
            
    return np.array(X1) , np.array(X2) , np.array(y)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input , Dense , LSTM , Embedding , Dropout
from tensorflow.keras.layers import add
from tensorflow.keras.callbacks import EarlyStopping

# %%
def define_Model(vocab_size , max_length):
    
    # feature extractor model
    inputs1 = Input(shape=(1000 , ))
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(512 , activation='relu')(fe1)
    fe3 = Dense(256 , activation = 'relu')(fe2)
    
    # sequence model
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size,512,mask_zero=True )(inputs2) # mask_zero = ignore padding
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(512 , return_sequences=True)(se2)
    se4 = Dropout(0.5)(se3)
    se5 = LSTM(256)(se4)
    
    
    #decoder Model
    decoder1 = add([fe3 , se5])
    decoder2 = Dense(256 , activation='relu')(decoder1)
    decoder3 = Dense(512 , activation='relu')(decoder2)
    outputs = Dense(vocab_size , activation='softmax')(decoder3)
    
    # combine both image and text
    model = Model([inputs1 , inputs2] , outputs)
    model.compile(loss='categorical_crossentropy' , optimizer = 'adam')
    
    # summary
    print(model.summary())
    
    return model

# %%
# below code progressivly load the code in batches
def data_generator(descriptions , photos , tokenizer , max_length):
    while 1:
        for key , desc_list in descriptions.items():
            photo = photos[key][0]
            in_img , in_seq , out_seq = create_sequences(tokenizer , max_length , desc_list , photo)
            
            yield[[in_img , in_seq] , out_seq]

# %%
print('len :', len(train))
print('Descriptions :',len(train_descriptions))
print('photos train :',len(train_features))
print('Vocabulary size :',vocab_size)
max_len = max_length(train_descriptions)
print('Description max length :', max_len)
# Out:
# len : 8091
# Descriptions : 8091
# photos train : 8091
# Vocabulary size : 7568
# Description max length : 37

# %%
from keras.models import load_model

# %%
model = define_Model(vocab_size , max_len)
epochs = 1 #chnage epochs here also and in training also 
steps = len(train_descriptions) #this was missing 


generator = data_generator(train_descriptions , train_features , tokenizer , max_len)

model.fit_generator(generator , epochs = 1 , steps_per_epoch = steps , verbose = 1)

model.save('model_'+ str(epochs) + '.h5')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 37)]         0           []
#
#  embedding (Embedding)          (None, 37, 512)      3874816     ['input_3[0][0]']
#
#  input_2 (InputLayer)           [(None, 1000)]       0           []
#
#  dropout_1 (Dropout)            (None, 37, 512)      0           ['embedding[0][0]']
#
#  dropout (Dropout)              (None, 1000)         0           ['input_2[0][0]']
#
#  lstm (LSTM)                    (None, 37, 512)      2099200     ['dropout_1[0][0]']
#
#  dense (Dense)                  (None, 512)          512512      ['dropout[0][0]']
#
#  dropout_2 (Dropout)            (None, 37, 512)      0           ['lstm[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dense[0][0]']
#
#  lstm_1 (LSTM)                  (None, 256)          787456      ['dropout_2[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense_1[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          65792       ['add[0][0]']
#
#  dense_3 (Dense)                (None, 512)          131584      ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 7568)         3882384     ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 11,485,072
# Trainable params: 11,485,072
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# <ipython-input-47-75667e5261aa>:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator , epochs = 1 , steps_per_epoch = steps , verbose = 1)
# 8091/8091 [==============================] - 1713s 210ms/step - loss: 3.9841

# %%
tokenizer
dump(tokenizer , open('tokenizer.pkl','wb'))

# %%
import numpy as np
import pandas as pd

# %%
from keras.models import load_model
from pickle import load
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
def word_for_id(integer , tokenizer):
    for word,index in tokenizer.word_index.items():
        if index == integer:
            return word
        
def generate_desc(model , tokenizer , photo , max_length):
    
    input_text = 'startseq'
    print(11)
    for i in range(max_length):
        #print(12)
        sequence = tokenizer.texts_to_sequences([input_text])[0]
        sequence = pad_sequences([sequence] , maxlen=max_length)
        #print(13)
        # predict the next word
        next_word_id = model.predict([photo,sequence],verbose = 0)
        #print(14)
        # get highest probality word from list of words
        next_word_id = np.argmax(next_word_id)
        #print(15)
        # get word from id
        word = word_for_id(next_word_id , tokenizer)
        #print(word)
        if word is None:
            break
            
        # update input text
        input_text += ' '+ word
        
        if word == 'endseq':
            break
            
    return input_text

# %%
def get_image_caption(filename,model):
    tokenizer = load(open('tokenizer.pkl','rb'))
    #print(1)
    photo = extract_features_for_one_image(filename)
    #print(2)
    desc = generate_desc(model , tokenizer , photo , 37)
    #print(3)
    desc = desc.replace('startseq','')
    #print(4)
    desc = desc.replace('endseq','')
    return desc.title()

# %%
def extract_features_for_one_image(filename):
    model = VGG16()
    model.layers.pop()
    
    model = Model(inputs = model.inputs , outputs = model.layers[-1].output)
    
    image = load_img(filename , target_size=(224,224))
    
    image = img_to_array(image)
    
    image = image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
    
    image = preprocess_input(image)
    
    feature = model.predict(image , verbose = 0)
    
    return feature

# %%
model2 = load_model('model_1.h5')

# %%
from IPython.display import Image,display

# %%
filename = '/content/1000268201_693b08cb0e.jpg'

# %%
#print(get_image_caption(filename,model2))
display(Image(filename))

# %%
print(get_image_caption(filename,model2))
# Out:
# 11
#  A Man In A Red Shirt Is Playing On A Rock
